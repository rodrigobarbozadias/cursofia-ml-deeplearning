# %% [markdown]
# # Instalando o Pycaret no Colab
#
# Vamos instalar a versão completa pycaret de acordo com as instruções na [installation page](https://pycaret.readthedocs.io/en/latest/installation.html)

# %%
# !pip install joblib==1.3
# Out:
# ...
#   Using cached joblib-1.3.0-py3-none-any.whl (301 kB)
# ...
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.0
#     Uninstalling joblib-1.4.0:
#       Successfully uninstalled joblib-1.4.0
# ...

# %%
# !pip install pycaret # Será necessário reinicializar o ambiente
# Out:
# ...
#   Using cached pycaret-3.3.1-py3-none-any.whl (486 kB)
# ...
#   Using cached category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
# ...
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# ...
#   Using cached imbalanced_learn-0.12.2-py3-none-any.whl (257 kB)
# ...
#   Using cached kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
# ...
#   Using cached plotly_resampler-0.10.0-py3-none-any.whl (80 kB)
# ...
#   Using cached pmdarima-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.1 MB)
# ...
#   Using cached pyod-1.1.3.tar.gz (160 kB)
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 27.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 26.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.2 MB/s eta 0:00:00
# ...

# %%
import pycaret
pycaret.__version__
# Out:
# '3.3.1'

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Carregando a Base

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_orders = pd.read_csv('/content/drive/MyDrive/datasets/ifood/df_orders.csv')
df_orders.head(3)
# Out:
#                                order_id  order_number  \
# 0  630e2af0-b456-4b3a-b964-4d66ce5cc5df    1290139943
# 1  66f8163d-f081-4fbd-adb8-cfbbff9213f7    1141271215
# 2  e8c55557-81d4-4159-bd2b-c144e5fbabe3     694742752
#
#       order_timestamp_local     order_shift    last_status_date_local  \
# 0  2019-12-11T13:22:06.497Z   weekday lunch  2019-12-11T15:22:39.156Z
# 1  2019-11-06T17:57:17.967Z  weekday dinner  2019-11-06T18:18:48.680Z
# 2  2019-06-11T20:42:32.058Z  weekday dinner  2019-06-11T22:42:54.005Z
#
#    order_total  credit  paid_amount delivery_type  scheduled  ...  \
# 0        28.90    14.0         24.9      DELIVERY      False  ...
# 1        56.35     7.9         50.4      DELIVERY      False  ...
# 2        53.80     4.0         49.8      DELIVERY      False  ...
#
#   distance_merchant_customer promo_is_promotion normal_items_quantity  \
# 0                2722.603906                0.0                   2.0
# ...

# %% [markdown]
# # Criação da ABT

# %%
df_features_train = df_orders.query('order_timestamp_local >= "2019-06-01" & order_timestamp_local < "2019-07-01"')
df_features_train.head(3)
# Out:
#                                order_id  order_number  \
# 2  e8c55557-81d4-4159-bd2b-c144e5fbabe3     694742752
# 3  34a60e0d-0042-49af-9aa8-4dc526a998c2     679245732
# 5  0d8b3571-be59-48c0-bb92-b7f3ce2793a0     686714753
#
#       order_timestamp_local     order_shift    last_status_date_local  \
# 2  2019-06-11T20:42:32.058Z  weekday dinner  2019-06-11T22:42:54.005Z
# 3  2019-06-05T19:16:42.111Z  weekday dinner  2019-06-05T21:17:13.264Z
# 5  2019-06-08T14:44:02.062Z   weekend lunch  2019-06-08T15:25:13.583Z
#
#    order_total  credit  paid_amount delivery_type  scheduled  ...  \
# 2         53.8     4.0         49.8      DELIVERY      False  ...
# 3         58.9     4.0         54.9      DELIVERY      False  ...
# 5        131.9     4.0        127.9      DELIVERY      False  ...
#
#   distance_merchant_customer promo_is_promotion normal_items_quantity  \
# 2                1642.258522                0.0                   2.0
# ...

# %%
df_target_train = df_orders.query('order_timestamp_local >= "2019-07-01" & order_timestamp_local < "2019-08-01"').filter(['customer_id']).drop_duplicates()
df_target_train.head(3)
# Out:
#                                           customer_id
# 8   90f2b3ba9e0f08ee3183d6d918fb53e6534dbb600ec455...
# 17  15d5dbfca76a09718f673a21fa83ca91ea29cd844303b8...
# 22  4311cabf116b98af5288a4e67b08d4cd3a7fa8bcc9b51c...

# %%
df_abt_train = (
    df_features_train
    .groupby('customer_id')
    .agg(receita_1m = ('paid_amount', 'sum'),
         qtd_pedidos_1m = ('order_id', 'nunique'),
         data_ultima_venda = ('order_timestamp_local', 'max')
    )
    .reset_index()
)
df_abt_train.head()
# Out:
#                                          customer_id  receita_1m  \
# 0  0001a8e61d8b08ad436e8e6f4adeb399b88df962c72d9d...       102.0
# 1  0001a9f97d01d2696cf70c7657ee2d039388d691720ff9...        52.0
# 2  0004720dc16aed1f98fd79f59736170e0d686199cd9ae5...        59.3
# 3  0006a32816a3af172048de7db87c97c4c8c7ad7e6385fa...        95.2
# 4  00081913eb21cd12aecc831bda704f8c6482723b55e664...        27.0
#
#    qtd_pedidos_1m         data_ultima_venda
# 0               2  2019-06-15T21:57:51.803Z
# 1               1  2019-06-11T12:10:33.822Z
# 2               1  2019-06-01T12:45:14.808Z
# 3               2  2019-06-29T02:56:33.535Z
# 4               1  2019-06-17T19:41:34.313Z

# %%
df_abt_train = (
    df_abt_train
    .assign(data_ultima_venda = lambda df: pd.to_datetime(df['data_ultima_venda'], utc=True))
    .assign(data_ref = lambda df: pd.to_datetime('2019-07-01', utc=True))
    .assign(recencia = lambda df: (df['data_ref'] - df['data_ultima_venda']).dt.days)
    .filter(['data_ref', 'customer_id', 'receita_1m', 'qtd_pedidos_1m', 'recencia'])

)
df_abt_train.head()
# Out:
#                    data_ref  \
# 0 2019-07-01 00:00:00+00:00
# 1 2019-07-01 00:00:00+00:00
# 2 2019-07-01 00:00:00+00:00
# 3 2019-07-01 00:00:00+00:00
# 4 2019-07-01 00:00:00+00:00
#
#                                          customer_id  receita_1m  \
# 0  0001a8e61d8b08ad436e8e6f4adeb399b88df962c72d9d...       102.0
# 1  0001a9f97d01d2696cf70c7657ee2d039388d691720ff9...        52.0
# 2  0004720dc16aed1f98fd79f59736170e0d686199cd9ae5...        59.3
# 3  0006a32816a3af172048de7db87c97c4c8c7ad7e6385fa...        95.2
# 4  00081913eb21cd12aecc831bda704f8c6482723b55e664...        27.0
#
#    qtd_pedidos_1m  recencia
# 0               2        15
# 1               1        19
# 2               1        29
# 3               2         1
# 4               1        13

# %%
df_abt_train = df_abt_train.merge(df_target_train, how='left', on='customer_id', indicator=True)
df_abt_train.head()
# Out:
#                    data_ref  \
# 0 2019-07-01 00:00:00+00:00
# 1 2019-07-01 00:00:00+00:00
# 2 2019-07-01 00:00:00+00:00
# 3 2019-07-01 00:00:00+00:00
# 4 2019-07-01 00:00:00+00:00
#
#                                          customer_id  receita_1m  \
# 0  0001a8e61d8b08ad436e8e6f4adeb399b88df962c72d9d...       102.0
# 1  0001a9f97d01d2696cf70c7657ee2d039388d691720ff9...        52.0
# 2  0004720dc16aed1f98fd79f59736170e0d686199cd9ae5...        59.3
# 3  0006a32816a3af172048de7db87c97c4c8c7ad7e6385fa...        95.2
# 4  00081913eb21cd12aecc831bda704f8c6482723b55e664...        27.0
#
#    qtd_pedidos_1m  recencia     _merge
# 0               2        15  left_only
# 1               1        19  left_only
# 2               1        29  left_only
# 3               2         1  left_only
# 4               1        13  left_only

# %%
df_abt_train = df_abt_train.assign(churn_next_month = lambda df: np.where(df['_merge'] == "left_only", 1, 0)).drop('_merge', axis=1)

# %%
df_features_oot = df_orders.query('order_timestamp_local >= "2019-07-01" & order_timestamp_local < "2019-08-01"')
df_target_oot   = df_orders.query('order_timestamp_local >= "2019-08-01" & order_timestamp_local < "2019-09-01"').filter(['customer_id']).drop_duplicates()

df_abt_oot = (
    df_features_oot
    .groupby('customer_id')
    .agg(receita_1m      = ('paid_amount', 'sum'),
         qtd_pedidos_1m  = ('order_id', 'nunique'),
         data_ult_vnd = ('order_timestamp_local', 'max'))
    .reset_index()
    .assign(data_ref = pd.to_datetime('2019-08-01').date())
    .assign(data_ult_vnd = lambda df: pd.to_datetime(df['data_ult_vnd'], utc=True))
    .assign(data_ref = lambda df: pd.to_datetime('2019-08-01', utc=True))
    .assign(recencia = lambda df: (df['data_ref'] - df['data_ult_vnd']).dt.days)
    .merge(df_target_oot, how='left', on='customer_id', indicator=True)
    .assign(churn_next_month = lambda df: np.where(df['_merge'] == "left_only", 1, 0))
    .filter(['data_ref', 'customer_id', 'receita_1m', 'qtd_pedidos_1m', 'recencia', 'churn_next_month'])
)

# %%
#Por um detalhe no index para a automl eu irei criar um marcador no treino e oot
df_abt_train["tipo"]="train"
df_abt_oot["tipo"]="oot"

# %%
df_abt_train.head()
# Out:
#                    data_ref  \
# 0 2019-07-01 00:00:00+00:00
# 1 2019-07-01 00:00:00+00:00
# 2 2019-07-01 00:00:00+00:00
# 3 2019-07-01 00:00:00+00:00
# 4 2019-07-01 00:00:00+00:00
#
#                                          customer_id  receita_1m  \
# 0  0001a8e61d8b08ad436e8e6f4adeb399b88df962c72d9d...       102.0
# 1  0001a9f97d01d2696cf70c7657ee2d039388d691720ff9...        52.0
# 2  0004720dc16aed1f98fd79f59736170e0d686199cd9ae5...        59.3
# 3  0006a32816a3af172048de7db87c97c4c8c7ad7e6385fa...        95.2
# 4  00081913eb21cd12aecc831bda704f8c6482723b55e664...        27.0
#
#    qtd_pedidos_1m  recencia  churn_next_month   tipo
# 0               2        15                 1  train
# 1               1        19                 1  train
# 2               1        29                 1  train
# 3               2         1                 1  train
# 4               1        13                 1  train

# %%
df_abt_oot.head()
# Out:
#                    data_ref  \
# 0 2019-08-01 00:00:00+00:00
# 1 2019-08-01 00:00:00+00:00
# 2 2019-08-01 00:00:00+00:00
# 3 2019-08-01 00:00:00+00:00
# 4 2019-08-01 00:00:00+00:00
#
#                                          customer_id  receita_1m  \
# 0  000a1fac4f7a67cc3f2e7667167597cb2c9a1b9edafe18...       85.89
# 1  0014b7013c66a05d0b5ce0687d614ac220d3ae1af398d2...      211.96
# 2  00150a9d8edc32b5ac2c1a8089e5615dbd297cea2c6cba...      164.60
# 3  00197c67cab97917c3e147877fc36ae9e9208f4bd578ca...      196.20
# 4  001b8d424e1aa9b762831ccce74a6b4c648a83f2d8a239...      238.68
#
#    qtd_pedidos_1m  recencia  churn_next_month tipo
# 0               3        11                 0  oot
# 1               5        11                 0  oot
# 2               2        14                 0  oot
# 3               5         2                 0  oot
# 4               8         0                 0  oot

# %%
#juntar tudo em um dataset para ter o index
df_abt = pd.concat([df_abt_train, df_abt_oot]).reset_index().drop(columns="index")

# %%
df_abt.shape
# Out:
# (48520, 7)

# %%
df_abt.head()
# Out:
#                    data_ref  \
# 0 2019-07-01 00:00:00+00:00
# 1 2019-07-01 00:00:00+00:00
# 2 2019-07-01 00:00:00+00:00
# 3 2019-07-01 00:00:00+00:00
# 4 2019-07-01 00:00:00+00:00
#
#                                          customer_id  receita_1m  \
# 0  0001a8e61d8b08ad436e8e6f4adeb399b88df962c72d9d...       102.0
# 1  0001a9f97d01d2696cf70c7657ee2d039388d691720ff9...        52.0
# 2  0004720dc16aed1f98fd79f59736170e0d686199cd9ae5...        59.3
# 3  0006a32816a3af172048de7db87c97c4c8c7ad7e6385fa...        95.2
# 4  00081913eb21cd12aecc831bda704f8c6482723b55e664...        27.0
#
#    qtd_pedidos_1m  recencia  churn_next_month   tipo
# 0               2        15                 1  train
# 1               1        19                 1  train
# 2               1        29                 1  train
# 3               2         1                 1  train
# 4               1        13                 1  train

# %% [markdown]
# # Identificando as variáveis de modelagem

# %%
# pega a base de treinamento
df_train = df_abt.query('tipo == "train"')

# pega a base de avaliação (out of time)
df_oot   = df_abt.query('tipo == "oot"')

# %%
# Utilize as seguintes variáveis:
target = 'churn_next_month'

key_vars = ['data_ref', 'customer_id',"tipo"]
num_vars = ['receita_1m', 'qtd_pedidos_1m', 'recencia']
cat_vars = [] # não temos variáveis categóricas
features = num_vars + cat_vars

# %%
df_train.head()
# Out:
#                    data_ref  \
# 0 2019-07-01 00:00:00+00:00
# 1 2019-07-01 00:00:00+00:00
# 2 2019-07-01 00:00:00+00:00
# 3 2019-07-01 00:00:00+00:00
# 4 2019-07-01 00:00:00+00:00
#
#                                          customer_id  receita_1m  \
# 0  0001a8e61d8b08ad436e8e6f4adeb399b88df962c72d9d...       102.0
# 1  0001a9f97d01d2696cf70c7657ee2d039388d691720ff9...        52.0
# 2  0004720dc16aed1f98fd79f59736170e0d686199cd9ae5...        59.3
# 3  0006a32816a3af172048de7db87c97c4c8c7ad7e6385fa...        95.2
# 4  00081913eb21cd12aecc831bda704f8c6482723b55e664...        27.0
#
#    qtd_pedidos_1m  recencia  churn_next_month   tipo
# 0               2        15                 1  train
# 1               1        19                 1  train
# 2               1        29                 1  train
# 3               2         1                 1  train
# 4               1        13                 1  train

# %%
df_oot.head()
# Out:
#                        data_ref  \
# 30079 2019-08-01 00:00:00+00:00
# 30080 2019-08-01 00:00:00+00:00
# 30081 2019-08-01 00:00:00+00:00
# 30082 2019-08-01 00:00:00+00:00
# 30083 2019-08-01 00:00:00+00:00
#
#                                              customer_id  receita_1m  \
# 30079  000a1fac4f7a67cc3f2e7667167597cb2c9a1b9edafe18...       85.89
# 30080  0014b7013c66a05d0b5ce0687d614ac220d3ae1af398d2...      211.96
# 30081  00150a9d8edc32b5ac2c1a8089e5615dbd297cea2c6cba...      164.60
# 30082  00197c67cab97917c3e147877fc36ae9e9208f4bd578ca...      196.20
# 30083  001b8d424e1aa9b762831ccce74a6b4c648a83f2d8a239...      238.68
#
#        qtd_pedidos_1m  recencia  churn_next_month tipo
# 30079               3        11                 0  oot
# 30080               5        11                 0  oot
# 30081               2        14                 0  oot
# 30082               5         2                 0  oot
# 30083               8         0                 0  oot

# %% [markdown]
# # Usando o PyCaret na base do iFood
#
# Realize os seguintes passos utilizando o PyCaret:
#
# - Faça o setup
# - Treine vários modelos, utilize 5 folds e ordene pela `auc`
# - Salve o resultado com o resultado de treinamento de todos os modelos na variável `compare_models_results`
# - Crie o modelo que teve o melhor desempenho para o problema em questão. Lembre-se de avaliar o problema de negócio e não só a metrica de desempenho (`auc`)
# - Faça as devidas otimizações de hiperparâmetros. Utilize os seguintes parâmetros (`n_iter=30`, `optimize=AUC`, `fold=5`)
# - Faça os seguintes plots:
#     - Curva ROC
#     - Feature Importance
#     - Matriz de confusão
#     - Shap Values
#     - Ganhos comulativos
# - Faça uma análise de negócio
# - Finalize o modelo e salve na pasta: `/content/drive/MyDrive/modelos/`

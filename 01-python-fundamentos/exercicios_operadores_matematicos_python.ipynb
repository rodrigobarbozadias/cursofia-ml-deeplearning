# %% [markdown]
# # Exercícios Práticos de Python - Operadores Matemáticos

# %% [markdown]
# ## Instruções:
# 1. Tente resolver os exercícios utilizando operadores matemáticos em Python.
# 2. Verifique suas respostas rodando cada célula após completar o código.
# 3. Sinta-se à vontade para explorar e modificar os exemplos.

# %% [markdown]
# ### Exercício 1: Soma e Subtração

# %% [markdown]
# Escreva um código que some dois números e subtraia um terceiro número.

# %%
# Definindo três números


# Calcule a soma de a e b, e subtraia c


# Exiba o resultado
print("Resultado:", resultado)

# %% [markdown]
# ### Exercício 2: Multiplicação e Divisão

# %% [markdown]
# Escreva um código que multiplique dois números e divida por um terceiro número.

# %%
# Definindo três números


# Calcule a multiplicação de x e y, e divida por z


# Exiba o resultado
print("Resultado:", resultado)

# %% [markdown]
# ### Exercício 3: Módulo e Exponenciação

# %% [markdown]
# Escreva um código que calcule o resto da divisão (módulo) entre dois números,
# e depois calcule a exponenciação de um número ao quadrado.

# %%
# Definindo dois números


# Calcule o módulo de num1 por num2


# Calcule a exponenciação de num2 ao quadrado


# Exiba os resultados
print("Módulo:", modulo)
print("Exponenciação:", expo)

# %% [markdown]
# ### Exercício 4: Operadores Combinados

# %% [markdown]
# Escreva um código que utilize diferentes operadores matemáticos para calcular uma expressão.

# %%
# Definindo quatro números


# Calcule a expressão: (p + q) * r - s


# Exiba o resultado
print("Resultado da expressão:", resultado)

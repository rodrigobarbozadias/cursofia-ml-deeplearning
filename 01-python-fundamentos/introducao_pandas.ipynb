# %% [markdown]
# # DataFrame
#
# Antes de carregar os dados disponibilizados pela empresa Fast Delivery vamos testar alguns comandos e criar e manipular DataFrames desde o inicio.

# %%
import pandas as pd

# %% [markdown]
# Para criar um DataFrame vazio, podemos utilizar o comando abaixo.

# %%
df = pd.DataFrame() #vc vai passar um objeto que irá virar um dataframe
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# O DataFrame é mutável ou seja, podemos adicionar e remover colunas e linhas.
#
# Por exemplo para adicionar uma nova coluna com três linhas, precisamos criar o nome da coluna e adicionar os elementos utilizando uma estruturada de dados como uma lista.

# %%
df['nome'] =  ['Catarina', 'Pedro', 'Maria'] #isso é uma lista
df
# Out:
#        nome
# 0  Catarina
# 1     Pedro
# 2     Maria

# %% [markdown]
# Também podemos criar um DataFrame passando os dados por parâmetro.

# %%
dados = {
    'nome': ['Catarina', 'Pedro', 'Maria'], #isso é um dicionario
    'idade': [25, 35, 45],
    'altura': [1.75, 1.85, 1.82]
}

df = pd.DataFrame(dados)
df
# Out:
#        nome  idade  altura
# 0  Catarina     25    1.75
# 1     Pedro     35    1.85
# 2     Maria     45    1.82

# %% [markdown]
# Nesse caso, a chaves do dicionário serão as colunas e as linhas são os elementos que estão dentro da lista.
#
# Cada posição das listas, refere-se a linha no DataFrame.
#
# ## Operações do DataFrame
#
# ### Seleção
#
# Uma coluna específica pode ser obtida como uma Series.

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Note que o retorno é um Series que é uma estrutura de dados, onde os valores são nomeados.
#
# Caso a seleção seja realizada em mais de uma coluna, o retorno será um DataFrame.

# %%
df[['nome', 'altura']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-7e40f777a2c3> in <cell line: 1>()
# ----> 1 df[['nome', 'altura']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6247         if nmissing:
#    6248             if nmissing == len(indexer):
# -> 6249                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250
#    6251             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['nome', 'altura'], dtype='object')] are in the [columns]"

# %% [markdown]
# Para selecionar linhas, podemos utilizar os índices. Olhando no DataFrame, podemos ver os índices de 0 até 2, esse é o índice **EXPLICITO**, que pode ser sequencial ou podemos setar manualmente. O mesmo vale para colunas.
#
# Nesse caso, utilizamos o comando `.loc` para selecionar linha e coluna.

# %% [markdown]
# Vamos definir o indice das linhas para serem os nomes.

# %%
df.set_index('nome')
# Out:
#           idade  altura
# nome
# Catarina     25    1.75
# Pedro        35    1.85
# Maria        45    1.82

# %% [markdown]
# Note que esse comando retornou um valor, ou seja, ele não alterou o DataFrame original, para isso precisamos adicionar o parâmetro `inplace=True`.

# %%
df.set_index('nome', inplace=True)

# %%
df
# Out:
#           idade  altura
# nome
# Catarina     25    1.75
# Pedro        35    1.85
# Maria        45    1.82

# %% [markdown]
# Note que o indice agora virou o nome e podemos utilizar o `.loc` para selecionar elementos.

# %%
# Seleciona a linha Catarina e coluna idade, retorna o valor
df.loc['Catarina', 'idade']
# Out:
# 25

# %%
# Seleciona linha Catarina e as colunas alutra e idade, retorna uma Serie
df.loc['Catarina', ['idade', 'altura']]
# Out:
# idade     25.00
# altura     1.75
# Name: Catarina, dtype: float64

# %%
# Seleciona as linhas Catarina e Maria e todas as colunas, retorna um DataFrame
df.loc[['Catarina', 'Maria']]
# Out:
#           idade  altura
# nome
# Catarina     25    1.75
# Maria        45    1.82

# %%
# Seleciona as linhas Catarina e Maria e as colunas altura e idade, retorna um DataFrame
df.loc[['Catarina', 'Maria'], ['idade', 'altura']]
# Out:
#           idade  altura
# nome
# Catarina     25    1.75
# Maria        45    1.82

# %% [markdown]
# Podemos utilizar o `.iloc` para selecionar os elementos utilizando o índice **IMPLICITO**.

# %%
# Seleciona a linha 0 e coluna 0, retorna o valor
df.iloc[0, 0]
# Out:
# 25

# %%
# Seleciona linha 0 e as colunas 0 e 1, retorna uma Serie
df.iloc[0, [0, 1]]
# Out:
# idade     25.00
# altura     1.75
# Name: Catarina, dtype: float64

# %%
# Seleciona as linhas 0 e 1 e todas as colunas, retorna um DataFrame
df.iloc[[0, 1]]
# Out:
#           idade  altura
# nome
# Catarina     25    1.75
# Pedro        35    1.85

# %%
# Seleciona as linhas 0 e 2 e as colunas 1 e 0, retorna um DataFrame
df.iloc[[0, 2], [1, 0]]
# Out:
#           altura  idade
# nome
# Catarina    1.75     25
# Maria       1.82     45

# %% [markdown]
# ### Atribuição
#
# Uma coluna pode ser adicionada via atribuição

# %%
df['peso'] = 100
df
# Out:
#           idade  altura  peso
# nome
# Catarina     25    1.75   100
# Pedro        35    1.85   100
# Maria        45    1.82   100

# %% [markdown]
# Note que todas as linhas tiveram o mesmo valor.
#
# Importante: Para adicionar valores diferentes, é necessário passar uma lista com a quantidade total de linhas, caso contrário um erro será gerado.

# %%
df['peso'] = [70, 85]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-ef7173459bb7> in <cell line: 1>()
# ----> 1 df['peso'] = [70, 85]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3978         else:
#    3979             # set column
# -> 3980             self._set_item(key, value)
#    3981
#    3982     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4172         ensure homogeneity.
#    4173         """
# -> 4174         value = self._sanitize_column(value)
#    4175
#    4176         if (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4913
#    4914         if is_list_like(value):
# -> 4915             com.require_length_match(value, self.index)
#    4916         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4917
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     569     """
#     570     if len(data) != len(index):
# --> 571         raise ValueError(
#     572             "Length of values "
#     573             f"({len(data)}) "
#
# ValueError: Length of values (2) does not match length of index (3)

# %%
df['peso'] = [70, 85, 78]
df
# Out:
#           idade  altura  peso
# nome
# Catarina     25    1.75    70
# Pedro        35    1.85    85
# Maria        45    1.82    78

# %% [markdown]
# Também podemos alterar um valor específico, utilizado o `.loc` ou `.iloc`.

# %%
df.loc['Catarina', 'idade'] = 30 # Alterando a idade da Catarina para 30

# %%
df
# Out:
#           idade  altura  peso
# nome
# Catarina     30    1.75    70
# Pedro        35    1.85    85
# Maria        45    1.82    78

# %%
df.iloc[1, 1] = 1.90 # Alterando a altura do Pedro para 1.90
df
# Out:
#           idade  altura  peso
# nome
# Catarina     30    1.75    70
# Pedro        35    1.90    85
# Maria        45    1.82    78

# %% [markdown]
# ### Remoção
#
# Uma coluna pode ser deletada utilizando o nome (rótudo) e a função ```del``` conforme visto em dicionários.

# %%
del df['peso'] # Altera o objeto em memória

# %%
df
# Out:
#           idade  altura
# nome
# Catarina     30    1.75
# Pedro        35    1.90
# Maria        45    1.82

# %% [markdown]
# É possível utilizar o comando **```drop```**. Esse comando permite remover colunas ou linhas.
#
# **Para remover colunas**

# %%
df.drop(['idade', 'altura'], axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [Catarina, Pedro, Maria]

# %% [markdown]
# **Para remover linhas**

# %%
df.drop(['Pedro'], axis=0)
# Out:
#           idade  altura
# nome
# Catarina     30    1.75
# Maria        45    1.82

# %%
df.drop(['Catarina', 'Maria'], axis=0)
# Out:
#        idade  altura
# nome
# Pedro     35     1.9

# %% [markdown]
# É importante salientar que o método drop, por padrão, não remove no próprio DataFrame, ele devolve um novo objeto DataFrame que deve ser armazenado em uma nova variável.
#
# Para contornar esse problema, podemos utilizar o parâmetro ```inplace=True```.

# %%
df.drop(['Maria'], axis=0, inplace=True)

# %%
df
# Out:
#           idade  altura
# nome
# Catarina     30    1.75
# Pedro        35    1.90

# %% [markdown]
# ### Inserção
#
# Basicamente, um DataFrame pode ser tratado como se fosse um dicionário de Series. Colunas são inseridas no final. Para inserir uma coluna em um local específico podemos utilizar a função ```insert```.

# %%
df.insert(0, 'peso', [72, 78])
df
# Out:
#           peso  idade  altura
# nome
# Catarina    72     30    1.75
# Pedro       78     35    1.90

# %% [markdown]
# Para adicionar uma nova linha, podemos utilizar o comando `.loc`.

# %%
df.loc['Maria'] = [71, 25, 1.80]
df
# Out:
#           peso  idade  altura
# nome
# Catarina  72.0   30.0    1.75
# Pedro     78.0   35.0    1.90
# Maria     71.0   25.0    1.80

# %% [markdown]
# ### Operações matemáticas

# %%
df.dtypes
# Out:
# peso      float64
# idade     float64
# altura    float64
# dtype: object

# %%
df * 2
# Out:
#            peso  idade  altura
# nome
# Catarina  144.0   60.0     3.5
# Pedro     156.0   70.0     3.8
# Maria     142.0   50.0     3.6

# %%
df['peso'] * df['altura']
# Out:
# nome
# Catarina    126.0
# Pedro       148.2
# Maria       127.8
# dtype: float64

# %%
df['idade'] + 100
# Out:
# nome
# Catarina    130.0
# Pedro       135.0
# Maria       125.0
# Name: idade, dtype: float64

# %%
df.describe()
# Out:
#             peso  idade    altura
# count   3.000000    3.0  3.000000
# mean   73.666667   30.0  1.816667
# std     3.785939    5.0  0.076376
# min    71.000000   25.0  1.750000
# 25%    71.500000   27.5  1.775000
# 50%    72.000000   30.0  1.800000
# 75%    75.000000   32.5  1.850000
# max    78.000000   35.0  1.900000

# %% [markdown]
# ## Principais funcionalidades

# %% [markdown]
# ### Load dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-13-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
df = pd.read_csv('/content/drive/MyDrive/datasets/delivery_pedidos.csv')
df.head()
# Out:
#                               id_pedido  numero_pedido  \
# 0  630e2af0-b456-4b3a-b964-4d66ce5cc5df     1290139943
# 1  66f8163d-f081-4fbd-adb8-cfbbff9213f7     1141271215
# 2  e8c55557-81d4-4159-bd2b-c144e5fbabe3      694742752
# 3  34a60e0d-0042-49af-9aa8-4dc526a998c2      679245732
# 4  998f6d97-f884-40ba-a7a3-e9691930a642     1052187003
#
#      timestamp_local_pedido  total_pedido  credito  total_pago tipo_entrega  \
# 0  2022-12-11T13:22:06.497Z         28.90     14.0        24.9     DELIVERY
# 1  2022-11-06T17:57:17.967Z         56.35      7.9        50.4     DELIVERY
# 2  2022-06-11T20:42:32.058Z         53.80      4.0        49.8     DELIVERY
# 3  2022-06-05T19:16:42.111Z         58.90      4.0        54.9     DELIVERY
# 4  2022-10-15T21:01:23.973Z         54.80     14.0        50.8     DELIVERY
#
#           versao_do_app tipo_dispositivo plataforma_dispositivo  \
# 0                9.29.1           MOBILE                ANDROID
# 1          webapp_6.2.0             SITE                DESKTOP
# 2       iOS_iFood_9.2.1           MOBILE                    IOS
# 3       iOS_iFood_9.2.1           MOBILE                    IOS
# 4  Android_iFood_9.22.1           MOBILE                ANDROID
#
#   metodo_pagamento cidade_restaurante     bairro_restaurante  \
# 0        CC_ONLINE              NATAL            PONTA NEGRA
# 1        CC_ONLINE           LONDRINA  Gleba Fazenda Palhano
# 2        CC_ONLINE          SAO PAULO         Parque Bristol
# 3        CC_ONLINE           LONDRINA                 Centro
# 4        CC_ONLINE          SAO PAULO     Jardim Santo Elias
#
#   tipo_prato_restaurante  qtde_itens_normais  qtde_itens_promocionais  \
# 0      Comida Brasileira                 2.0                      0.0
# 1                Lanches                 0.0                      1.0
# 2      Comida Brasileira                 2.0                      0.0
# 3                Lanches                 1.0                      0.0
# 4        Comida Japonesa                 0.0                      2.0
#
#                                           id_cliente
# 0  48b6d81407646ca61163f064a426ce38ac08bed2ce84f0...
# 1  b3f74186880f5f9a79e0865ad8beab47e22b785b8b3bc0...
# 2  c4f8999d4cb83cac8134b2051ffc611d5d660c049c3744...
# 3  ac89a3eb35853705a09d54f1e5988ad876628b986045cd...
# 4  fdef6bf0530b1f6507f175167aa442ade79b6e6fa085c9...

# %%
df.dtypes
# Out:
# id_pedido                   object
# numero_pedido                int64
# timestamp_local_pedido      object
# total_pedido               float64
# credito                    float64
# total_pago                 float64
# tipo_entrega                object
# versao_do_app               object
# tipo_dispositivo            object
# plataforma_dispositivo      object
# metodo_pagamento            object
# cidade_restaurante          object
# bairro_restaurante          object
# tipo_prato_restaurante      object
# qtde_itens_normais         float64
# qtde_itens_promocionais    float64
# id_cliente                  object
# dtype: object

# %%
df.shape
# Out:
# (492138, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 492138 entries, 0 to 492137
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id_pedido                492138 non-null  object
#  1   numero_pedido            492138 non-null  int64
#  2   timestamp_local_pedido   492138 non-null  object
#  3   total_pedido             492138 non-null  float64
#  4   credito                  492138 non-null  float64
#  5   total_pago               492138 non-null  float64
#  6   tipo_entrega             492138 non-null  object
#  7   versao_do_app            489585 non-null  object
#  8   tipo_dispositivo         492137 non-null  object
#  9   plataforma_dispositivo   492138 non-null  object
#  10  metodo_pagamento         492138 non-null  object
#  11  cidade_restaurante       492138 non-null  object
#  12  bairro_restaurante       492138 non-null  object
#  13  tipo_prato_restaurante   492138 non-null  object
#  14  qtde_itens_normais       492137 non-null  float64
#  15  qtde_itens_promocionais  492137 non-null  float64
#  16  id_cliente               492138 non-null  object
# dtypes: float64(5), int64(1), object(11)
# memory usage: 63.8+ MB

# %%
df.columns
# Out:
# Index(['id_pedido', 'numero_pedido', 'timestamp_local_pedido', 'total_pedido',
#        'credito', 'total_pago', 'tipo_entrega', 'versao_do_app',
#        'tipo_dispositivo', 'plataforma_dispositivo', 'metodo_pagamento',
#        'cidade_restaurante', 'bairro_restaurante', 'tipo_prato_restaurante',
#        'qtde_itens_normais', 'qtde_itens_promocionais', 'id_cliente'],
#       dtype='object')

# %%
df.describe()
# Out:
#        numero_pedido   total_pedido        credito     total_pago  \
# count   4.921380e+05  492138.000000  492138.000000  492138.000000
# mean    9.643116e+08      55.816997       6.258059      50.326789
# std     2.064172e+08      31.489082       4.443247      32.239552
# min     6.677426e+08      13.000000       4.000000       9.000000
# 25%     7.778584e+08      35.900000       4.000000      30.000000
# 50%     9.286896e+08      47.700000       4.000000      42.500000
# 75%     1.138138e+09      66.000000       4.000000      61.500000
# max     1.373961e+09    1641.000000      84.000000    1637.000000
#
#        qtde_itens_normais  qtde_itens_promocionais
# count       492137.000000            492137.000000
# mean             1.583831                 0.471227
# std              2.155416                 1.356803
# min              0.000000                 0.000000
# 25%              1.000000                 0.000000
# 50%              1.000000                 0.000000
# 75%              2.000000                 1.000000
# max            233.000000               105.000000

# %%
df.isnull().sum()
# Out:
# id_pedido                     0
# numero_pedido                 0
# timestamp_local_pedido        0
# total_pedido                  0
# credito                       0
# total_pago                    0
# tipo_entrega                  0
# versao_do_app              2553
# tipo_dispositivo              1
# plataforma_dispositivo        0
# metodo_pagamento              0
# cidade_restaurante            0
# bairro_restaurante            0
# tipo_prato_restaurante        0
# qtde_itens_normais            1
# qtde_itens_promocionais       1
# id_cliente                    0
# dtype: int64

# %%
100 * (df.isnull().sum() / len(df))
# Out:
# id_pedido                  0.000000
# numero_pedido              0.000000
# timestamp_local_pedido     0.000000
# total_pedido               0.000000
# credito                    0.000000
# total_pago                 0.000000
# tipo_entrega               0.000000
# versao_do_app              0.518757
# tipo_dispositivo           0.000203
# plataforma_dispositivo     0.000000
# metodo_pagamento           0.000000
# cidade_restaurante         0.000000
# bairro_restaurante         0.000000
# tipo_prato_restaurante     0.000000
# qtde_itens_normais         0.000203
# qtde_itens_promocionais    0.000203
# id_cliente                 0.000000
# dtype: float64

# %%
df[['id_pedido', 'credito', 'total_pago']].head()
# Out:
#                               id_pedido  credito  total_pago
# 0  630e2af0-b456-4b3a-b964-4d66ce5cc5df     14.0        24.9
# 1  66f8163d-f081-4fbd-adb8-cfbbff9213f7      7.9        50.4
# 2  e8c55557-81d4-4159-bd2b-c144e5fbabe3      4.0        49.8
# 3  34a60e0d-0042-49af-9aa8-4dc526a998c2      4.0        54.9
# 4  998f6d97-f884-40ba-a7a3-e9691930a642     14.0        50.8

# %%
df.sort_values('total_pago').head(3)
# Out:
#                                    id_pedido  numero_pedido  \
# 15528   fe47b7a7-8a29-41c7-b8bb-ece801dbd153     1059553879
# 210657  0e3f705d-242a-465a-8ccd-d72770fc6e73     1141568590
# 172240  9aa718cb-0faa-4e6d-ae90-73bb82daba3d      859559299
#
#           timestamp_local_pedido  total_pedido  credito  total_pago  \
# 15528   2022-10-18T11:50:00.000Z         27.99    18.99         9.0
# 210657  2022-11-07T11:00:00.000Z         21.99    12.99         9.0
# 172240  2022-08-15T20:58:58.245Z         37.00    28.00         9.0
#
#        tipo_entrega         versao_do_app tipo_dispositivo  \
# 15528      DELIVERY  Android_iFood_9.22.1           MOBILE
# 210657     DELIVERY  Android_iFood_9.24.2           MOBILE
# 172240      TAKEOUT  Android_iFood_9.12.0           MOBILE
#
#        plataforma_dispositivo     metodo_pagamento cidade_restaurante  \
# 15528                 ANDROID  MEAL_VOUCHER_ONLINE             OSASCO
# 210657                ANDROID  MEAL_VOUCHER_ONLINE           BRASILIA
# 172240                ANDROID            CC_ONLINE             SUMARE
#
#        bairro_restaurante tipo_prato_restaurante  qtde_itens_normais  \
# 15528               Km 18      Comida Brasileira                 0.0
# 210657       Aguas Claras      Comida Brasileira                 0.0
# 172240  Jardim Paulistano                  Pizza                 3.0
#
#         qtde_itens_promocionais  \
# 15528                       1.0
# 210657                      1.0
# 172240                      0.0
#
#                                                id_cliente
# 15528   260c07ea8d9a3e12c9b1eeeaf31a2323329b5be950c88f...
# 210657  92b2aeace7d890197b8af41c32b2bcb137ff70c439a5d6...
# 172240  70dc2ba1f6bbf68dbc868d030c98dbc76968613d211c30...

# %%
df.sort_values('total_pago', ascending=False).head(3)
# Out:
#                                    id_pedido  numero_pedido  \
# 397661  ca830d92-51b0-4864-b63e-9e76252e6d12     1280972296
# 478640  ff8e5592-c33d-490a-b4fc-48edfad240dd     1281072397
# 26399   a26ad980-ef89-429f-869d-fd2b9c425265     1280966645
#
#           timestamp_local_pedido  total_pedido  credito  total_pago  \
# 397661  2022-12-08T21:58:30.856Z        1641.0      4.0      1637.0
# 478640  2022-12-08T22:34:55.203Z        1509.0      4.0      1505.0
# 26399   2022-12-08T21:56:46.841Z        1461.0      4.0      1457.0
#
#        tipo_entrega versao_do_app tipo_dispositivo plataforma_dispositivo  \
# 397661     DELIVERY        9.29.1           MOBILE                ANDROID
# 478640     DELIVERY        9.29.1           MOBILE                ANDROID
# 26399      DELIVERY        9.29.1           MOBILE                ANDROID
#
#        metodo_pagamento cidade_restaurante bairro_restaurante  \
# 397661       CC_OFFLINE         IMPERATRIZ       Cinco Irmãos
# 478640       CC_OFFLINE         IMPERATRIZ       Cinco Irmãos
# 26399        CC_OFFLINE         IMPERATRIZ       Cinco Irmãos
#
#        tipo_prato_restaurante  qtde_itens_normais  qtde_itens_promocionais  \
# 397661                Bebidas                 9.0                      0.0
# 478640                Bebidas                31.0                      0.0
# 26399                 Bebidas                 8.0                      0.0
#
#                                                id_cliente
# 397661  84da9b360bf44ed10b3bdcb21fb77a9dd1e675c878cf1a...
# 478640  84da9b360bf44ed10b3bdcb21fb77a9dd1e675c878cf1a...
# 26399   84da9b360bf44ed10b3bdcb21fb77a9dd1e675c878cf1a...

# %%
df.sort_values(['credito', 'total_pago'], ascending=False).head(4)
# Out:
#                                    id_pedido  numero_pedido  \
# 48265   f12dc6dd-cc38-43d1-b58b-7f7ec93df506      865182626
# 131780  d07202c5-5cf5-49a5-9f75-c3849ccdde33      852797437
# 428761  4026d4a6-24e6-4598-ae7e-98fd13a3c5d4      977859174
# 381708  681a74f3-fdcb-411d-9392-cbcd585142f8     1185819331
#
#           timestamp_local_pedido  total_pedido  credito  total_pago  \
# 48265   2022-08-17T21:48:25.602Z        124.40    84.00       40.40
# 131780  2022-08-12T19:03:17.079Z        107.70    84.00       23.70
# 428761  2022-09-25T22:02:48.258Z         77.87    66.93       36.97
# 381708  2022-11-16T20:01:07.493Z        186.70    64.00      122.70
#
#        tipo_entrega         versao_do_app tipo_dispositivo  \
# 48265      DELIVERY  Android_iFood_9.14.1           MOBILE
# 131780     DELIVERY  Android_iFood_9.12.0           MOBILE
# 428761     DELIVERY  Android_iFood_9.20.0           MOBILE
# 381708     DELIVERY      iOS_iFood_9.25.0           MOBILE
#
#        plataforma_dispositivo metodo_pagamento cidade_restaurante  \
# 48265                 ANDROID        CC_ONLINE          SAO PAULO
# 131780                ANDROID        CC_ONLINE           CAMPINAS
# 428761                ANDROID        CC_ONLINE          SAO PAULO
# 381708                    IOS        CC_ONLINE          SAO PAULO
#
#                bairro_restaurante tipo_prato_restaurante  qtde_itens_normais  \
# 48265                     Santana         Comida Chinesa                 1.0
# 131780  Conj. Hab. Padre Anchieta        Comida Japonesa                 2.0
# 428761            Cerqueira Cesar        Comida Mexicana                 0.0
# 381708                 Casa Verde          Frutos do Mar                 0.0
#
#         qtde_itens_promocionais  \
# 48265                       0.0
# 131780                      1.0
# 428761                      3.0
# 381708                      1.0
#
#                                                id_cliente
# 48265   0e1a609fcc0358101345e365db4acd7e720480f8ba52be...
# 131780  70dc2ba1f6bbf68dbc868d030c98dbc76968613d211c30...
# 428761  f5ddcc2007f7965392d626e5197ad51251e96379e18ace...
# 381708  0e6531a24f42a5172be06875bd3e44ebd006506f9f37fc...

# %%
# Usando o parametro how='any', se ALGUM dos valores são missing, remova a linha ou coluna.
df_aux = df.dropna() # Nesse caso, how='any' é o valor padrão do parâmetro.

# %%
df_aux.isnull().sum()
# Out:
# id_pedido                  0
# numero_pedido              0
# timestamp_local_pedido     0
# total_pedido               0
# credito                    0
# total_pago                 0
# tipo_entrega               0
# versao_do_app              0
# tipo_dispositivo           0
# plataforma_dispositivo     0
# metodo_pagamento           0
# cidade_restaurante         0
# bairro_restaurante         0
# tipo_prato_restaurante     0
# qtde_itens_normais         0
# qtde_itens_promocionais    0
# id_cliente                 0
# dtype: int64

# %%
# Usando o parametro how='all', se TODOS os valores são missing, remova a linha ou coluna.
df_aux = df.dropna(how='all')

# %%
df_aux.isnull().sum()
# Out:
# id_pedido                     0
# numero_pedido                 0
# timestamp_local_pedido        0
# total_pedido                  0
# credito                       0
# total_pago                    0
# tipo_entrega                  0
# versao_do_app              2553
# tipo_dispositivo              1
# plataforma_dispositivo        0
# metodo_pagamento              0
# cidade_restaurante            0
# bairro_restaurante            0
# tipo_prato_restaurante        0
# qtde_itens_normais            1
# qtde_itens_promocionais       1
# id_cliente                    0
# dtype: int64

# %%
df_aux['qtde_itens_normais'] = df_aux['qtde_itens_normais'].fillna(df['qtde_itens_normais'].median())

# %%
df_aux.isnull().sum()
# Out:
# id_pedido                     0
# numero_pedido                 0
# timestamp_local_pedido        0
# total_pedido                  0
# credito                       0
# total_pago                    0
# tipo_entrega                  0
# versao_do_app              2553
# tipo_dispositivo              1
# plataforma_dispositivo        0
# metodo_pagamento              0
# cidade_restaurante            0
# bairro_restaurante            0
# tipo_prato_restaurante        0
# qtde_itens_normais            0
# qtde_itens_promocionais       1
# id_cliente                    0
# dtype: int64

# %% [markdown]
# Podemos criar uma coluna baseado em uma condição. Por exemplo, criar uma Flag informando que o preço total do pedido é alto ou baixo.
#
# Se for maior que R$ 80 é alto, caso contrário é baixo.

# %% [markdown]
# Para isso podemos utilizar a biblioteca chamada [NumPY](https://numpy.org/) que tem uma funcionalidade chamada [np.where](https://numpy.org/doc/stable/reference/generated/numpy.where.html).
#
#
# `np.where(condition, True, False)`

# %%
import numpy as np

# %%
df['total_pedido'] > 80 # Essa é a condição e retorna False ou True.
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 492133     True
# 492134    False
# 492135    False
# 492136     True
# 492137    False
# Name: total_pedido, Length: 492138, dtype: bool

# %% [markdown]
# Utilizando o np.where para criar a flag.

# %%
np.where(df['total_pedido'] > 80, 'alto', 'baixo')
# Out:
# array(['baixo', 'baixo', 'baixo', ..., 'baixo', 'alto', 'baixo'],
#       dtype='<U5')

# %% [markdown]
# O retorno será um array que contém os resultados, basta salvar em uma nova coluna.

# %%
df['flag'] = np.where(df['total_pedido'] > 80, 'alto', 'baixo')

# %%
df.head(3)
# Out:
#                               id_pedido  numero_pedido  \
# 0  630e2af0-b456-4b3a-b964-4d66ce5cc5df     1290139943
# 1  66f8163d-f081-4fbd-adb8-cfbbff9213f7     1141271215
# 2  e8c55557-81d4-4159-bd2b-c144e5fbabe3      694742752
#
#      timestamp_local_pedido  total_pedido  credito  total_pago tipo_entrega  \
# 0  2022-12-11T13:22:06.497Z         28.90     14.0        24.9     DELIVERY
# 1  2022-11-06T17:57:17.967Z         56.35      7.9        50.4     DELIVERY
# 2  2022-06-11T20:42:32.058Z         53.80      4.0        49.8     DELIVERY
#
#      versao_do_app tipo_dispositivo plataforma_dispositivo metodo_pagamento  \
# 0           9.29.1           MOBILE                ANDROID        CC_ONLINE
# 1     webapp_6.2.0             SITE                DESKTOP        CC_ONLINE
# 2  iOS_iFood_9.2.1           MOBILE                    IOS        CC_ONLINE
#
#   cidade_restaurante     bairro_restaurante tipo_prato_restaurante  \
# 0              NATAL            PONTA NEGRA      Comida Brasileira
# 1           LONDRINA  Gleba Fazenda Palhano                Lanches
# 2          SAO PAULO         Parque Bristol      Comida Brasileira
#
#    qtde_itens_normais  qtde_itens_promocionais  \
# 0                 2.0                      0.0
# 1                 0.0                      1.0
# 2                 2.0                      0.0
#
#                                           id_cliente   flag
# 0  48b6d81407646ca61163f064a426ce38ac08bed2ce84f0...  baixo
# 1  b3f74186880f5f9a79e0865ad8beab47e22b785b8b3bc0...  baixo
# 2  c4f8999d4cb83cac8134b2051ffc611d5d660c049c3744...  baixo

# %%
df['flag'].value_counts().to_frame()
# Out:
#          flag
# baixo  420602
# alto    71536

# %% [markdown]
# ### Filtragem

# %%
df.shape
# Out:
# (492138, 18)

# %%
df['flag'] == 'alto'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 492133     True
# 492134    False
# 492135    False
# 492136     True
# 492137    False
# Name: flag, Length: 492138, dtype: bool

# %%
df[df['flag'] == 'alto'].shape
# Out:
# (71536, 18)

# %%
df[df['flag'] == 'baixo'].shape
# Out:
# (420602, 18)

# %% [markdown]
# Tambem podemos combinar diferentes condições de filtragem.

# %%
df['flag'] == 'baixo'
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 492133    False
# 492134     True
# 492135     True
# 492136    False
# 492137     True
# Name: flag, Length: 492138, dtype: bool

# %%
df['total_pedido'] > 200
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 492133    False
# 492134    False
# 492135    False
# 492136    False
# 492137    False
# Name: total_pedido, Length: 492138, dtype: bool

# %%
df[(df['flag'] == 'alto') & (df['total_pedido'] > 300)].shape
# Out:
# (438, 18)

# %%
df.query('flag == "alto"').shape
# Out:
# (71536, 18)

# %%
df.query('flag == "alto" and total_pedido > 300').shape
# Out:
# (438, 18)

# %% [markdown]
# ### Agrupamentos

# %%
df['timestamp_local_pedido'].min()
# Out:
# '2022-06-01T00:00:15.369Z'

# %%
df['timestamp_local_pedido'].max()
# Out:
# '2022-12-31T23:31:59.972Z'

# %%
df['timestamp_local_pedido'].agg(('min', 'max')).to_frame()
# Out:
#        timestamp_local_pedido
# min  2022-06-01T00:00:15.369Z
# max  2022-12-31T23:31:59.972Z

# %%
df.groupby('flag').mean()
# Out:
# <ipython-input-75-13aa964ecdde>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('flag').mean()
#        numero_pedido  total_pedido   credito  total_pago  qtde_itens_normais  \
# flag
# alto    9.731892e+08    113.011607  4.966800  108.376658            2.760107
# baixo   9.628017e+08     46.089336  6.477677   40.453666            1.383770
#
#        qtde_itens_promocionais
# flag
# alto                  0.493374
# baixo                 0.467460

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
df.groupby('flag').mean()
# Out:
# <ipython-input-77-13aa964ecdde>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('flag').mean()
#        numero_pedido  total_pedido  credito  total_pago  qtde_itens_normais  \
# flag
# alto    973189194.44        113.01     4.97      108.38                2.76
# baixo   962801693.27         46.09     6.48       40.45                1.38
#
#        qtde_itens_promocionais
# flag
# alto                      0.49
# baixo                     0.47

# %%
df.groupby(['flag']).agg(
    min_total=('total_pedido', 'min'),
    max_total=('total_pedido', 'max')
)
# Out:
#        min_total  max_total
# flag
# alto       80.01    1641.00
# baixo      13.00      80.00

# %%
(
    df
    .groupby(['flag'])
    .agg(
        min_total_pedido=('total_pedido', 'min'),
        max_total_pedido=('total_pedido', 'max'),
        min_total_pago=('total_pago', 'min'),
        max_total_pago=('total_pago', 'max')
    )
    .reset_index()
)
# Out:
#     flag  min_total_pedido  max_total_pedido  min_total_pago  max_total_pago
# 0   alto             80.01           1641.00           23.70         1637.00
# 1  baixo             13.00             80.00            9.00           76.00

# %% [markdown]
# ### Operações entre Tabelas

# %%
import pandas as pd

# %%
df_pedidos = pd.read_csv('/content/drive/MyDrive/datasets/delivery_pedidos.csv')
df_pedidos.head(3)
# Out:
#                               id_pedido  numero_pedido  \
# 0  630e2af0-b456-4b3a-b964-4d66ce5cc5df     1290139943
# 1  66f8163d-f081-4fbd-adb8-cfbbff9213f7     1141271215
# 2  e8c55557-81d4-4159-bd2b-c144e5fbabe3      694742752
#
#      timestamp_local_pedido  total_pedido  credito  total_pago tipo_entrega  \
# 0  2022-12-11T13:22:06.497Z         28.90    14.00       24.90     DELIVERY
# 1  2022-11-06T17:57:17.967Z         56.35     7.90       50.40     DELIVERY
# 2  2022-06-11T20:42:32.058Z         53.80     4.00       49.80     DELIVERY
#
#      versao_do_app tipo_dispositivo plataforma_dispositivo metodo_pagamento  \
# 0           9.29.1           MOBILE                ANDROID        CC_ONLINE
# 1     webapp_6.2.0             SITE                DESKTOP        CC_ONLINE
# 2  iOS_iFood_9.2.1           MOBILE                    IOS        CC_ONLINE
#
#   cidade_restaurante     bairro_restaurante tipo_prato_restaurante  \
# 0              NATAL            PONTA NEGRA      Comida Brasileira
# 1           LONDRINA  Gleba Fazenda Palhano                Lanches
# 2          SAO PAULO         Parque Bristol      Comida Brasileira
#
#    qtde_itens_normais  qtde_itens_promocionais  \
# 0                2.00                     0.00
# 1                0.00                     1.00
# 2                2.00                     0.00
#
#                                           id_cliente
# 0  48b6d81407646ca61163f064a426ce38ac08bed2ce84f0...
# 1  b3f74186880f5f9a79e0865ad8beab47e22b785b8b3bc0...
# 2  c4f8999d4cb83cac8134b2051ffc611d5d660c049c3744...

# %%
df_clientes = pd.read_csv('/content/drive/MyDrive/datasets/delivery_clientes.csv')
df_clientes.head(3)
# Out:
#                                          customer_id estado          cidade  \
# 0  ebeb208d1be66bb9a0a5037671b9e6f16d9ec8380b7152...     RJ  RIO DE JANEIRO
# 1  542b6d66775ba20aaa8d56afa5cfa064e4696ace462c1c...     SP       SAO PAULO
# 2  9f0dccf2a0b2f2e854fd8120bb4d2e3e739fc74afeb5f4...     GO         GOIANIA
#
#          bairro
# 0      Botafogo
# 1  Vila Zulmira
# 2     St. Perim

# %%
df_clientes.shape
# Out:
# (30079, 4)

# %% [markdown]
# ##### Left Join
# <img src="http://www.dinomagri.com/imgs/joins/left.png" alt="LEFT JOIN" width="250"/>

# %%
esq = {1, 2, 3, 4, 10}
dir = {3, 4, 5}

dir.difference(esq) # a chave 5 não existe na esquerda, logo não será filtrada.
# Out:
# {5}

# %%
df_pedidos.shape, df_clientes.shape
# Out:
# ((492138, 17), (30079, 4))

# %%
df_pedidos.merge(df_clientes, how='left', left_on='id_cliente', right_on='customer_id')
# Out:
#                                    id_pedido  numero_pedido  \
# 0       630e2af0-b456-4b3a-b964-4d66ce5cc5df     1290139943
# 1       66f8163d-f081-4fbd-adb8-cfbbff9213f7     1141271215
# 2       e8c55557-81d4-4159-bd2b-c144e5fbabe3      694742752
# 3       34a60e0d-0042-49af-9aa8-4dc526a998c2      679245732
# 4       998f6d97-f884-40ba-a7a3-e9691930a642     1052187003
# ...                                      ...            ...
# 492133  40ef2f26-41e4-4dd1-97f4-8d06da9ce344      783879321
# 492134  43c3f696-c21c-4866-97e2-a1edd9703248      796075379
# 492135  be646cfe-5717-4810-a872-8c29617ca34a      960478804
# 492136  949a643f-0767-4570-8503-4fa3927f7411      902054854
# 492137  6e459e9e-6f73-4215-bb0f-44cbea4f5d55     1127554197
#
#           timestamp_local_pedido  total_pedido  credito  total_pago  \
# 0       2022-12-11T13:22:06.497Z         28.90    14.00       24.90
# 1       2022-11-06T17:57:17.967Z         56.35     7.90       50.40
# 2       2022-06-11T20:42:32.058Z         53.80     4.00       49.80
# 3       2022-06-05T19:16:42.111Z         58.90     4.00       54.90
# 4       2022-10-15T21:01:23.973Z         54.80    14.00       50.80
# ...                          ...           ...      ...         ...
# 492133  2022-07-17T19:56:53.967Z         86.80     4.00       82.80
# 492134  2022-07-24T11:16:54.546Z         25.90     4.00       21.90
# 492135  2022-09-20T12:51:49.390Z         35.00     4.00       31.00
# 492136  2022-08-31T19:39:06.589Z         88.60     4.00       84.60
# 492137  2022-11-02T20:17:53.880Z         42.80    14.00       38.80
#
#        tipo_entrega         versao_do_app tipo_dispositivo  \
# 0          DELIVERY                9.29.1           MOBILE
# 1          DELIVERY          webapp_6.2.0             SITE
# 2          DELIVERY       iOS_iFood_9.2.1           MOBILE
# 3          DELIVERY       iOS_iFood_9.2.1           MOBILE
# 4          DELIVERY  Android_iFood_9.22.1           MOBILE
# ...             ...                   ...              ...
# 492133     DELIVERY       iOS_iFood_9.9.0           MOBILE
# 492134     DELIVERY      iOS_iFood_8.51.0           MOBILE
# 492135     DELIVERY  Android_iFood_9.18.2           MOBILE
# 492136     DELIVERY  Android_iFood_9.16.0           MOBILE
# 492137     DELIVERY  Android_iFood_9.24.2           MOBILE
#
#        plataforma_dispositivo  ...     cidade_restaurante  \
# 0                     ANDROID  ...                  NATAL
# 1                     DESKTOP  ...               LONDRINA
# 2                         IOS  ...              SAO PAULO
# 3                         IOS  ...               LONDRINA
# 4                     ANDROID  ...              SAO PAULO
# ...                       ...  ...                    ...
# 492133                    IOS  ...             SAO CARLOS
# 492134                    IOS  ...               CURITIBA
# 492135                ANDROID  ...         RIO DE JANEIRO
# 492136                ANDROID  ...             ARARAQUARA
# 492137                ANDROID  ...  SAO JOSE DO RIO PRETO
#
#            bairro_restaurante tipo_prato_restaurante qtde_itens_normais  \
# 0                 PONTA NEGRA      Comida Brasileira               2.00
# 1       Gleba Fazenda Palhano                Lanches               0.00
# 2              Parque Bristol      Comida Brasileira               2.00
# 3                      Centro                Lanches               1.00
# 4          Jardim Santo Elias        Comida Japonesa               0.00
# ...                       ...                    ...                ...
# 492133      Jardim Botafogo 1                Lanches               2.00
# 492134                 Centro      Comida Brasileira               0.00
# 492135               Cordovil                Marmita               1.00
# 492136                 Centro        Comida Japonesa               0.00
# 492137         Jardim Yolanda                Lanches               2.00
#
#         qtde_itens_promocionais  \
# 0                          0.00
# 1                          1.00
# 2                          0.00
# 3                          0.00
# 4                          2.00
# ...                         ...
# 492133                     0.00
# 492134                     1.00
# 492135                     0.00
# 492136                     1.00
# 492137                     0.00
#
#                                                id_cliente  \
# 0       48b6d81407646ca61163f064a426ce38ac08bed2ce84f0...
# 1       b3f74186880f5f9a79e0865ad8beab47e22b785b8b3bc0...
# 2       c4f8999d4cb83cac8134b2051ffc611d5d660c049c3744...
# 3       ac89a3eb35853705a09d54f1e5988ad876628b986045cd...
# 4       fdef6bf0530b1f6507f175167aa442ade79b6e6fa085c9...
# ...                                                   ...
# 492133  c9155b72411d95712a46efb2aaa99bcca59fe1d3388c89...
# 492134  e0c9002cf5cb0cb7d82bf3aa45693dec3a0af15f79be4e...
# 492135  6f3bcdd94a18419074813dd691aaeeff9458451e469fac...
# 492136  e3108a6e4e8e73e6856e32f45ed462720514a87378305b...
# 492137  5ad8475a3bd9091a740e14eac7695276b8e86cbb1c20d7...
#
#                                               customer_id estado  \
# 0       48b6d81407646ca61163f064a426ce38ac08bed2ce84f0...     RN
# 1       b3f74186880f5f9a79e0865ad8beab47e22b785b8b3bc0...     PR
# 2       c4f8999d4cb83cac8134b2051ffc611d5d660c049c3744...     SP
# 3       ac89a3eb35853705a09d54f1e5988ad876628b986045cd...     PR
# 4       fdef6bf0530b1f6507f175167aa442ade79b6e6fa085c9...     SP
# ...                                                   ...    ...
# 492133  c9155b72411d95712a46efb2aaa99bcca59fe1d3388c89...     SP
# 492134  e0c9002cf5cb0cb7d82bf3aa45693dec3a0af15f79be4e...     PR
# 492135  6f3bcdd94a18419074813dd691aaeeff9458451e469fac...     RJ
# 492136  e3108a6e4e8e73e6856e32f45ed462720514a87378305b...     SP
# 492137  5ad8475a3bd9091a740e14eac7695276b8e86cbb1c20d7...     SP
#
#                        cidade                                  bairro
# 0                  PARNAMIRIM                         Nova Parnamirim
# 1                    LONDRINA                   GLEBA FAZENDA PALHANO
# 2                   SAO PAULO                          Americanopolis
# 3                    LONDRINA                                  Centro
# 4                   SAO PAULO              Vila Siqueira (zona Norte)
# ...                       ...                                     ...
# 492133             SAO CARLOS                     Parque Santa Monica
# 492134               CURITIBA                                  Centro
# 492135         RIO DE JANEIRO                         Parada De Lucas
# 492136             ARARAQUARA                       Jardim California
# 492137  SAO JOSE DO RIO PRETO  Residencial Village Damha Rio Preto Ii
#
# [492138 rows x 21 columns]

# %% [markdown]
# ##### Inner Join
#
# <img src="http://www.dinomagri.com/imgs/joins/inner.png" alt="LEFT JOIN" width="250"/>

# %%
esq = {1, 2, 3, 4, 10}
dir = {3, 4, 5}

esq.intersection(dir)
# Out:
# {3, 4}

# %%
df = df_pedidos.merge(df_clientes, how='inner', left_on='id_cliente', right_on='customer_id')

# %%
df.head(3)
# Out:
#                               id_pedido  numero_pedido  \
# 0  630e2af0-b456-4b3a-b964-4d66ce5cc5df     1290139943
# 1  bc9d6acf-a929-4220-8d36-e699eae40e54      909199593
# 2  30a8995d-82f3-49a2-b8e9-196b13b061e2     1099584517
#
#      timestamp_local_pedido  total_pedido  credito  total_pago tipo_entrega  \
# 0  2022-12-11T13:22:06.497Z         28.90    14.00       24.90     DELIVERY
# 1  2022-09-03T13:24:47.337Z         25.00     4.00       21.00     DELIVERY
# 2  2022-10-27T13:25:14.417Z         30.00     9.00       21.00     DELIVERY
#
#           versao_do_app tipo_dispositivo plataforma_dispositivo  ...  \
# 0                9.29.1           MOBILE                ANDROID  ...
# 1  Android_iFood_9.16.1           MOBILE                ANDROID  ...
# 2  Android_iFood_9.24.0           MOBILE                ANDROID  ...
#
#   cidade_restaurante bairro_restaurante tipo_prato_restaurante  \
# 0              NATAL        PONTA NEGRA      Comida Brasileira
# 1              NATAL           Neopolis                  Pizza
# 2              NATAL           Planalto                Marmita
#
#   qtde_itens_normais  qtde_itens_promocionais  \
# 0               2.00                     0.00
# 1               1.00                     0.00
# 2               1.00                     0.00
#
#                                           id_cliente  \
# 0  48b6d81407646ca61163f064a426ce38ac08bed2ce84f0...
# 1  48b6d81407646ca61163f064a426ce38ac08bed2ce84f0...
# 2  48b6d81407646ca61163f064a426ce38ac08bed2ce84f0...
#
#                                          customer_id estado      cidade  \
# 0  48b6d81407646ca61163f064a426ce38ac08bed2ce84f0...     RN  PARNAMIRIM
# 1  48b6d81407646ca61163f064a426ce38ac08bed2ce84f0...     RN  PARNAMIRIM
# 2  48b6d81407646ca61163f064a426ce38ac08bed2ce84f0...     RN  PARNAMIRIM
#
#             bairro
# 0  Nova Parnamirim
# 1  Nova Parnamirim
# 2  Nova Parnamirim
#
# [3 rows x 21 columns]

# %%
df_pedidos.shape
# Out:
# (492138, 17)

# %%
df.shape
# Out:
# (492138, 21)

# %% [markdown]
# ### Operaçao com datas

# %%
df.dtypes
# Out:
# id_pedido                   object
# numero_pedido                int64
# timestamp_local_pedido      object
# total_pedido               float64
# credito                    float64
# total_pago                 float64
# tipo_entrega                object
# versao_do_app               object
# tipo_dispositivo            object
# plataforma_dispositivo      object
# metodo_pagamento            object
# cidade_restaurante          object
# bairro_restaurante          object
# tipo_prato_restaurante      object
# qtde_itens_normais         float64
# qtde_itens_promocionais    float64
# id_cliente                  object
# customer_id                 object
# estado                      object
# cidade                      object
# bairro                      object
# dtype: object

# %%
df['data_pedido'] = pd.to_datetime(df['timestamp_local_pedido'])

# %%
df['data_pedido'].dt.year[:5]
# Out:
# 0    2022
# 1    2022
# 2    2022
# 3    2022
# 4    2022
# Name: data_pedido, dtype: int64

# %%
df['data_pedido'].dt.month[:5]
# Out:
# 0    12
# 1     9
# 2    10
# 3     6
# 4     8
# Name: data_pedido, dtype: int64

# %%
df['data_pedido'].dt.weekday[:5]
# Out:
# 0    6
# 1    5
# 2    3
# 3    2
# 4    1
# Name: data_pedido, dtype: int64

# %%
df['data_pedido'].dt.month_name()[:5]
# Out:
# 0     December
# 1    September
# 2      October
# 3         June
# 4       August
# Name: data_pedido, dtype: object

# %% [markdown]
# ---
# **Autor**: Prof. Dino Magri
#
# **Contato**: `professor.dinomagri@gmail.com`
#
# **Licença deste notebook**:
# <br>
# <img align="left" width="80" src="https://licensebuttons.net/l/by/3.0/88x31.png" />
#
# <br>
# <br>
#
# [Clique aqui para saber mais sobre a licença CC BY v4.0](https://creativecommons.org/licenses/by/4.0/legalcode.pt)
#
#
# ---

# %% [markdown]
# # Exercícios Regressão - Gabarito
#
# Utilize a base de dados de preço de carros (`car_price_train.csv`).
#
# O objetivo é criar um modelo que seja capaz de sugerir o preço de venda de carros usados na concessionária Supimpa.
#
# A base contém informações sobre as caracteristicas do carro:
#
# - `carID` - variável que identifica o carro
# - `brand` - marca do carro
# - `model` - modelo do carro
# - `year` - ano
# - `transmission` - tipo da transmissão
# - `mileage` - quilometragem
# - `fuelType` - tipo de combustível
# - `tax` - imposto
# - `mpg` - miles por gallon - milhas por galão
# - `engineSize` - tamanho do motor
# - `target` - preço de venda do carro em dólares

# %% [markdown]
# ## Carregando os dados

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/datasets/car_price_train.csv')
df.head(3)
# Out:
#    carID     brand                   model  year transmission  mileage  \
# 0  14266  vauxhall                     GTC  2018       Manual     4646
# 1  15238      ford   Grand Tourneo Connect  2015       Manual    94362
# 2  13982        vw         Tiguan Allspace  2019    Automatic     6580
#
#   fuelType    tax   mpg  engineSize  target
# 0   Petrol  145.0  36.2         2.0   19998
# 1   Diesel  125.0  58.9         1.6    9490
# 2   Diesel  145.0  39.2         2.0   31990

# %%
df.shape
# Out:
# (3968, 11)

# %%
df.describe()
# Out:
#               carID         year        mileage          tax          mpg  \
# count   3968.000000  3968.000000    3968.000000  3968.000000  3968.000000
# mean   15830.915827  2016.691784   25347.024446   152.483619    50.334955
# std     2200.751077     2.908401   24620.999153    83.738882    35.373234
# min    12002.000000  1997.000000       1.000000     0.000000     2.800000
# 25%    13953.500000  2016.000000    5930.000000   145.000000    38.700000
# 50%    15807.500000  2017.000000   19550.000000   145.000000    47.100000
# 75%    17750.750000  2019.000000   37317.750000   150.000000    54.300000
# max    19629.000000  2020.000000  259000.000000   580.000000   470.800000
#
#         engineSize         target
# count  3968.000000    3968.000000
# mean      2.125126   23309.007812
# std       0.788259   16288.551889
# min       0.000000     450.000000
# 25%       1.600000   11994.000000
# 50%       2.000000   18995.000000
# 75%       2.500000   29998.000000
# max       6.600000  145000.000000

# %% [markdown]
# ## Definindo as variáveis

# %%
df.columns
# Out:
# Index(['carID', 'brand', 'model', 'year', 'transmission', 'mileage',
#        'fuelType', 'tax', 'mpg', 'engineSize', 'target'],
#       dtype='object')

# %%
key_vars = ['carID']
num_vars = ['mileage', 'tax', 'mpg', 'engineSize']
cat_vars = ['brand', 'model', 'transmission', 'fuelType']

features = cat_vars + num_vars
target = 'target'

X = df[features]
y = df[target]

# %% [markdown]
# ## Criando a base de treino e teste

# %% [markdown]
# Crie a base de treino e teste utilizando o método `train_test_split` com os seguintes parâmetros.
#
# `test_size=0.2`
# `random_state=42`

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape
# Out:
# (2777, 8)

# %%
X_test.shape
# Out:
# (1191, 8)

# %% [markdown]
# ## Pipeline de dados

# %% [markdown]
# Crie os pipelines de transformações de dados para modelos lineares e não lineares.
#
# Selecione as técnicas de feature engineering que julgar que sejam as mais adequadas para as variáveis da conjunto de dados.
#
# Para facilitar, crie listas de tuplas que definem os steps para modelos lineares e não lineares.

# %%
# !pip install feature-engine
# Out:
# Collecting feature-engine
#   Downloading feature_engine-1.6.2-py2.py3-none-any.whl (328 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.9/328.9 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.10/dist-packages (from feature-engine) (1.23.5)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from feature-engine) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from feature-engine) (1.2.2)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from feature-engine) (1.11.4)
# Requirement already satisfied: statsmodels>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from feature-engine) (0.14.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.3->feature-engine) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.3->feature-engine) (2023.3.post1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->feature-engine) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->feature-engine) (3.2.0)
# Requirement already satisfied: patsy>=0.5.4 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.11.1->feature-engine) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.11.1->feature-engine) (23.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.4->statsmodels>=0.11.1->feature-engine) (1.16.0)
# Installing collected packages: feature-engine
# Successfully installed feature-engine-1.6.2

# %%
from sklearn.pipeline import Pipeline
from feature_engine.imputation import MeanMedianImputer, CategoricalImputer
from sklearn.preprocessing import StandardScaler
from feature_engine.wrappers import SklearnTransformerWrapper
from feature_engine.encoding import OneHotEncoder

# %%
steps_modelos_lineares = [
    ('numeric_imputer', MeanMedianImputer(variables=num_vars, imputation_method='median')),
    ('numeric_scaler', SklearnTransformerWrapper(variables=num_vars, transformer=StandardScaler())),
    ('categoric_imputer', CategoricalImputer(variables=cat_vars, fill_value='NotAv')),
    ('one_hot_encoder', OneHotEncoder(variables=cat_vars)),
]

steps_modelos_nao_lineares = [
    ('numeric_imputer', MeanMedianImputer(variables=num_vars, imputation_method='median')),
    ('categoric_imputer', CategoricalImputer(variables=cat_vars, fill_value='NotAv')),
    ('one_hot_encoder', OneHotEncoder(variables=cat_vars)),

]

# %% [markdown]
# ## Treinando diversos modelos

# %% [markdown]
# Crie um DataFrame comparativo com os seguintes algoritmos:
#
# - LinearRegression
# - SGDRegressor
# - DecisionTreeRegressor
# - RandomForestRegressor
# - XGBRegressor
# - LGBMRegressor
# - XGBRegressor
# - CatBoostRegressor
#
# Compute as seguintes métricas tanto para treino, quanto para teste:
# - RMSE
# - MAE
# - MAPE
#
# O DataFrame abaixo é um exemplo do que é esperado.
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>algoritmo</th>
#       <th>base</th>
#       <th>rmse</th>
#       <th>mae</th>
#       <th>mape</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>16</th>
#       <td>catboost</td>
#       <td>treino</td>
#       <td>2423.2371</td>
#       <td>1742.7349</td>
#       <td>0.1021</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>catboost</td>
#       <td>teste</td>
#       <td>4007.3208</td>
#       <td>2385.0553</td>
#       <td>0.1318</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>decision_tree</td>
#       <td>treino</td>
#       <td>249.1378</td>
#       <td>24.5117</td>
#       <td>0.0009</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>decision_tree</td>
#       <td>teste</td>
#       <td>6608.6693</td>
#       <td>3460.4962</td>
#       <td>0.1770</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>gb</td>
#       <td>treino</td>
#       <td>4260.8895</td>
#       <td>3067.5421</td>
#       <td>0.1932</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>gb</td>
#       <td>teste</td>
#       <td>4899.7093</td>
#       <td>3312.6936</td>
#       <td>0.1914</td>
#     </tr>
#   </tbody>
# </table>

# %%
# !pip install lightgbm xgboost catboost
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.1.0)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Collecting catboost
#   Downloading catboost-1.2.2-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.11.4)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.2

# %%
random_state = 42

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor

modelos_lineares = [
    ('linear_regression', LinearRegression()),
    ('sgdr', SGDRegressor(random_state=random_state)),
]

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor

modelos_nao_lineares = [
    ('decision_tree', DecisionTreeRegressor(random_state=random_state)),
    ('random_forest', RandomForestRegressor(random_state=random_state)),
    ('xgb', XGBRegressor(random_state=random_state)),
    ('lgbm', LGBMRegressor(random_state=random_state)),
    ('catboost', CatBoostRegressor(random_state=random_state, verbose=0))
]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

df_resultados = pd.DataFrame(columns=['algoritmo', 'base', 'rmse', 'mae', 'mape'])
df_resultados
# Out:
# Empty DataFrame
# Columns: [algoritmo, base, rmse, mae, mape]
# Index: []

# %%
def treinar_modelo(model_name, model, steps, X_train, y_train, X_test, y_test, random_state):
    pipeline = Pipeline(steps=steps + [(model_name, model)])
    pipeline.fit(X_train, y_train)

    res_treino = [
        mean_squared_error(y_train, pipeline.predict(X_train), squared=False),
        mean_absolute_error(y_train, pipeline.predict(X_train)),
        mean_absolute_percentage_error(y_train, pipeline.predict(X_train)),
    ]
    res_teste = [
        mean_squared_error(y_test, pipeline.predict(X_test), squared=False),
        mean_absolute_error(y_test, pipeline.predict(X_test)),
        mean_absolute_percentage_error(y_test, pipeline.predict(X_test)),
    ]

    return res_treino, res_teste

# %%
pd.options.display.float_format = '{:.4f}'.format
import warnings
warnings.filterwarnings('ignore')

# %%
for model_name, model in modelos_lineares:
    print(f'Treinando {model_name} ...', end=' ')
    res_treino, res_teste = treinar_modelo(model_name, model, steps_modelos_lineares, X_train, y_train, X_test, y_test, random_state)
    df_resultados.loc[len(df_resultados)] = [model_name, 'treino'] + res_treino
    df_resultados.loc[len(df_resultados)] = [model_name, 'teste'] + res_teste
    print('OK')

for model_name, model in modelos_nao_lineares:
    print(f'Treinando {model_name} ...', end=' ')
    res_treino, res_teste = treinar_modelo(model_name, model, steps_modelos_nao_lineares, X_train, y_train, X_test, y_test, random_state)
    df_resultados.loc[len(df_resultados)] = [model_name, 'treino'] + res_treino
    df_resultados.loc[len(df_resultados)] = [model_name, 'teste'] + res_teste
    print('OK')
# Out:
# Treinando linear_regression ... OK
# Treinando sgdr ... OK
# Treinando decision_tree ... OK
# Treinando random_forest ... OK
# Treinando xgb ... OK
# Treinando lgbm ... [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000618 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 537
# [LightGBM] [Info] Number of data points in the train set: 2777, number of used features: 69
# [LightGBM] [Info] Start training from score 23035.427080
# OK
# Treinando catboost ... OK

# %%
df_resultados[df_resultados.base == 'treino'].sort_values(['mae'])
# Out:
#             algoritmo    base      rmse       mae   mape
# 4       decision_tree  treino  249.1378   24.5117 0.0009
# 6       random_forest  treino 1725.1742  942.6826 0.0521
# 8                 xgb  treino 1779.8733 1237.4746 0.0695
# 12           catboost  treino 2423.2371 1742.7349 0.1021
# 10               lgbm  treino 3398.2517 2075.9294 0.1216
# 0   linear_regression  treino 5896.4355 3829.3563 0.2425
# 2                sgdr  treino 6130.7345 3979.4935 0.2574

# %%
df_resultados[df_resultados.base == 'teste'].sort_values(['mae'])
# Out:
#             algoritmo   base                rmse                mae  \
# 13           catboost  teste           4007.3208          2385.0553
# 9                 xgb  teste           4551.2900          2470.0958
# 7       random_forest  teste           5104.3762          2584.0442
# 11               lgbm  teste           5130.5404          2878.3697
# 5       decision_tree  teste           6608.6693          3460.4962
# 3                sgdr  teste           6796.3102          4371.9905
# 1   linear_regression  teste 47101003811686.7266 1364816560251.9619
#
#             mape
# 13        0.1318
# 9         0.1323
# 7         0.1371
# 11        0.1554
# 5         0.1770
# 3         0.2795
# 1  78437733.3733

# %% [markdown]
# ## Validação Cruzada
#
# Selecione os dois principais algoritmos que tiveram o melhor valor para MAE e aplique  a validação cruzada Kfold.
#
# Utilize a funcionalidade `cross_val_score` com os seguintes parâmetros:
#
# - `scoring='neg_mean_absolute_error'`
# - `X=X_train`
# - `y=y_train`
# - `n_jobs=-1`
#
# Utilize a funcionalidade `KFold` com os seguintes parâmetros:
#
# - `n_splits=5`
# - `shuffle=True`
# - `random_state=4`
#
# Lembre-se de calcular a média e desvio padrão para cada validação cruzada.

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score


kf = KFold(n_splits=5, shuffle=True, random_state=42)

rf_pipeline = Pipeline(steps=steps_modelos_nao_lineares + [('rf', RandomForestRegressor(random_state=42))])
cv_results_rf = cross_val_score(estimator=rf_pipeline, scoring='neg_mean_absolute_error', X=X_train, y=y_train, cv=kf, n_jobs=-1)
print('Mean CV RF', cv_results_rf.mean())
print('Std CV RF', cv_results_rf.std())

print()

catboost_pipeline = Pipeline(steps=steps_modelos_nao_lineares + [('catboost', CatBoostRegressor(random_state=42))])
cv_results_catboost = cross_val_score(estimator=catboost_pipeline, scoring='neg_mean_absolute_error', X=X_train, y=y_train, cv=kf, n_jobs=-1)
print('Mean CV Catboost', cv_results_catboost.mean())
print('Std CV Catboost', cv_results_catboost.std())
# Out:
# Mean CV RF -2679.6206701902693
# Std CV RF 162.3727624533136
#
# Mean CV Catboost -2500.9422279431105
# Std CV Catboost 114.2279106986258

# %% [markdown]
# ## Otimização de Hiperparâmetros
#
# Para o melhor modelo encontrado na Validação Cruzada, aplique uma grid de hiperparâmetros e diversos valores.
#
# Essa grid deve ter ao menos 3 hiperparâmetros e 3 diferentes valores para cada hiperparâmetro.
#
# Utilize o método `GridSearchCV` com os seguintes parâmetros:
# - `scoring='neg_mean_absolute_error'`
# - `cv=3`
# - `n_jobs=-1`

# %%
# Essa célula demora 12 minutos
from sklearn.model_selection import GridSearchCV

catboost_pipeline = Pipeline(steps=steps_modelos_nao_lineares + [('catboost', CatBoostRegressor(random_state=42, verbose=0))])

parametros = {
    'catboost__learning_rate': [0.01, 0.05, 0.1],
    'catboost__iterations': [100, 1000, 5000],
    'catboost__max_depth': [3, 7, 10],
}

grid_search = GridSearchCV(catboost_pipeline, parametros, scoring='neg_mean_absolute_error', cv=3, n_jobs=-1)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('numeric_imputer',
#                                         MeanMedianImputer(variables=['mileage',
#                                                                      'tax',
#                                                                      'mpg',
#                                                                      'engineSize'])),
#                                        ('categoric_imputer',
#                                         CategoricalImputer(fill_value='NotAv',
#                                                            variables=['brand',
#                                                                       'model',
#                                                                       'transmission',
#                                                                       'fuelType'])),
#                                        ('one_hot_encoder',
#                                         OneHotEncoder(variables=['brand',
#                                                                  'model',
#                                                                  'transmission',
#                                                                  'fuelType'])),
#                                        ('catboost',
#                                         <catboost.core.CatBoostRegressor object at 0x789d1f796500>)]),
#              n_jobs=-1,
#              param_grid={'catboost__iterations': [100, 1000, 5000],
#                          'catboost__learning_rate': [0.01, 0.05, 0.1],
#                          'catboost__max_depth': [3, 7, 10]},
#              scoring='neg_mean_absolute_error')

# %%
grid_search.best_params_
# Out:
# {'catboost__iterations': 5000,
#  'catboost__learning_rate': 0.05,
#  'catboost__max_depth': 7}

# %%
best_model = grid_search.best_estimator_

# %%
y_train_pred = best_model.predict(X_train)
y_test_pred = best_model.predict(X_test)

mae_train = mean_absolute_error(y_train, y_train_pred)
mae_test = mean_absolute_error(y_test, y_test_pred)

print('Best model train:', mae_train)
print('Best model test:', mae_test)
# Out:
# Best model train: 638.072562702918
# Best model test: 2189.7185208744127

# %% [markdown]
# ## Feature Selection
#
# Aplique uma técnica de seleção automática de atributos.
#
# Lembre-se de converter os dados de treino e teste utilizando o pipeline do melhor modelo.
#
# Após a seleção automatica de atributos, será necessário treinar um novo modelo somente com esses atributos, além disso aplique os valores para os hiperparâmetros que foram encontrados durante o GridSearchCV para o algoritmo que produziu o melhor modelo.

# %%
len(best_model[-1].feature_importances_)
# Out:
# 110

# %%
from sklearn.feature_selection import SelectFromModel

sfm = SelectFromModel(best_model[-1], threshold=0.1)
sfm.fit(best_model[:-1].transform(X_train), y_train)


variaveis_selecionadas = list(best_model[:-1].transform(X_train).columns[sfm.get_support()])
variaveis_selecionadas
# Out:
# ['mileage',
#  'tax',
#  'mpg',
#  'engineSize',
#  'brand_skoda',
#  'brand_hyundi',
#  'brand_vw',
#  'brand_ford',
#  'brand_audi',
#  'brand_merc',
#  'brand_bmw',
#  'model_ Santa Fe',
#  'model_ I800',
#  'model_ CLS Class',
#  'model_ Caddy Maxi Life',
#  'model_ V Class',
#  'model_ Q8',
#  'model_ KA',
#  'model_ R8',
#  'model_ 6 Series',
#  'model_ S Class',
#  'model_ X6',
#  'model_ 7 Series',
#  'model_ GLS Class',
#  'model_ X4',
#  'model_ Galaxy',
#  'model_ M4',
#  'model_ RS6',
#  'model_ SLK',
#  'model_ 8 Series',
#  'model_ Caravelle',
#  'model_ i8',
#  'model_ X7',
#  'model_ G Class',
#  'model_ Mustang',
#  'model_ California',
#  'transmission_Manual',
#  'transmission_Semi-Auto',
#  'transmission_Automatic',
#  'fuelType_Diesel',
#  'fuelType_Petrol',
#  'fuelType_Hybrid']

# %%
X_train_fs = best_model[:-1].transform(X_train)[variaveis_selecionadas]
X_test_fs = best_model[:-1].transform(X_test)[variaveis_selecionadas]

# %%
best_model[:-1].transform(X_train).shape
# Out:
# (2777, 110)

# %%
X_train_fs.shape
# Out:
# (2777, 42)

# %%
best_params = grid_search.best_params_
best_params
# Out:
# {'catboost__iterations': 5000,
#  'catboost__learning_rate': 0.05,
#  'catboost__max_depth': 7}

# %%
best_model_with_fs = CatBoostRegressor(
    random_state=42,
    learning_rate=best_params['catboost__learning_rate'],
    iterations=best_params['catboost__iterations'],
    max_depth=best_params['catboost__max_depth']
)
best_model_with_fs.fit(X_train_fs, y_train)
# Out:
# 0:	learn: 15548.8153809	total: 2.05ms	remaining: 10.3s
# 1:	learn: 15026.3829126	total: 4.13ms	remaining: 10.3s
# 2:	learn: 14526.7517292	total: 6.27ms	remaining: 10.4s
# 3:	learn: 14078.3647595	total: 8.32ms	remaining: 10.4s
# 4:	learn: 13660.1188698	total: 10.2ms	remaining: 10.2s
# 5:	learn: 13232.0562416	total: 12.2ms	remaining: 10.1s
# 6:	learn: 12863.1049218	total: 14.1ms	remaining: 10.1s
# 7:	learn: 12489.3648507	total: 16.1ms	remaining: 10.1s
# 8:	learn: 12135.4367413	total: 18.1ms	remaining: 10s
# 9:	learn: 11792.1060235	total: 20.1ms	remaining: 10s
# 10:	learn: 11473.8822787	total: 22.1ms	remaining: 10s
# 11:	learn: 11176.1741769	total: 24.1ms	remaining: 10s
# 12:	learn: 10878.9691710	total: 26.1ms	remaining: 10s
# 13:	learn: 10609.7294177	total: 28ms	remaining: 9.96s
# 14:	learn: 10359.5125218	total: 30.3ms	remaining: 10.1s
# 15:	learn: 10124.9910203	total: 32.2ms	remaining: 10s
# 16:	learn: 9898.8662744	total: 34.3ms	remaining: 10s
# 17:	learn: 9693.3229144	total: 36.2ms	remaining: 10s
# 18:	learn: 9465.2616413	total: 38.2ms	remaining: 10s
# 19:	learn: 9280.7524214	total: 40.3ms	remaining: 10s
# 20:	learn: 9102.8439409	total: 42.3ms	remaining: 10s
# 21:	learn: 8915.9069747	total: 44.1ms	remaining: 9.99s
# 22:	learn: 8741.1003480	total: 46.1ms	remaining: 9.97s
# 23:	learn: 8581.6038039	total: 48ms	remaining: 9.96s
# 24:	learn: 8411.3803655	total: 50.2ms	remaining: 9.98s
# 25:	learn: 8276.3793485	total: 52.3ms	remaining: 10s
# 26:	learn: 8140.6306592	total: 54.3ms	remaining: 10s
# 27:	learn: 8010.9749075	total: 56.6ms	remaining: 10s
# 28:	learn: 7908.3664752	total: 58.6ms	remaining: 10s
# 29:	learn: 7788.4654444	total: 60.6ms	remaining: 10s
# 30:	learn: 7665.2627148	total: 62.6ms	remaining: 10s
# 31:	learn: 7560.2446228	total: 64.9ms	remaining: 10.1s
# 32:	learn: 7451.9286659	total: 67ms	remaining: 10.1s
# 33:	learn: 7357.2315461	total: 69ms	remaining: 10.1s
# 34:	learn: 7266.7135472	total: 71ms	remaining: 10.1s
# 35:	learn: 7180.0772273	total: 72.9ms	remaining: 10.1s
# 36:	learn: 7104.1918484	total: 75ms	remaining: 10.1s
# 37:	learn: 7011.1086248	total: 76.8ms	remaining: 10s
# 38:	learn: 6919.7192857	total: 78.8ms	remaining: 10s
# 39:	learn: 6836.7583939	total: 80.8ms	remaining: 10s
# 40:	learn: 6756.1996959	total: 82.9ms	remaining: 10s
# 41:	learn: 6680.3636967	total: 84.7ms	remaining: 9.99s
# 42:	learn: 6616.7188436	total: 86.7ms	remaining: 10s
# 43:	learn: 6545.7199239	total: 88.7ms	remaining: 9.99s
# 44:	learn: 6480.2277107	total: 90.8ms	remaining: 10s
# 45:	learn: 6416.8258932	total: 93ms	remaining: 10s
# 46:	learn: 6362.1979166	total: 94.7ms	remaining: 9.98s
# 47:	learn: 6316.8260996	total: 99.6ms	remaining: 10.3s
# 48:	learn: 6265.5270032	total: 103ms	remaining: 10.4s
# 49:	learn: 6207.4414214	total: 105ms	remaining: 10.4s
# 50:	learn: 6169.1575601	total: 107ms	remaining: 10.4s
# 51:	learn: 6119.5009410	total: 109ms	remaining: 10.4s
# 52:	learn: 6077.1975350	total: 118ms	remaining: 11s
# 53:	learn: 6032.4678592	total: 120ms	remaining: 11s
# 54:	learn: 6000.6425003	total: 122ms	remaining: 11s
# 55:	learn: 5967.3739945	total: 124ms	remaining: 10.9s
# 56:	learn: 5931.7611358	total: 126ms	remaining: 10.9s
# 57:	learn: 5883.0120266	total: 127ms	remaining: 10.9s
# 58:	learn: 5848.1507319	total: 129ms	remaining: 10.8s
# 59:	learn: 5822.8511334	total: 131ms	remaining: 10.8s
# 60:	learn: 5791.6566155	total: 133ms	remaining: 10.8s
# 61:	learn: 5758.1666022	total: 135ms	remaining: 10.8s
# 62:	learn: 5726.7349418	total: 138ms	remaining: 10.8s
# 63:	learn: 5704.9188273	total: 140ms	remaining: 10.8s
# 64:	learn: 5672.3122940	total: 141ms	remaining: 10.7s
# 65:	learn: 5638.2935659	total: 143ms	remaining: 10.7s
# 66:	learn: 5612.7512624	total: 145ms	remaining: 10.7s
# 67:	learn: 5583.7915689	total: 147ms	remaining: 10.7s
# 68:	learn: 5553.3834512	total: 151ms	remaining: 10.8s
# 69:	learn: 5527.5705755	total: 153ms	remaining: 10.8s
# 70:	learn: 5502.8084723	total: 155ms	remaining: 10.8s
# 71:	learn: 5472.6170281	total: 157ms	remaining: 10.8s
# 72:	learn: 5444.0495212	total: 159ms	remaining: 10.8s
# 73:	learn: 5424.3658210	total: 161ms	remaining: 10.7s
# 74:	learn: 5393.4918010	total: 163ms	remaining: 10.7s
# 75:	learn: 5362.6696406	total: 165ms	remaining: 10.7s
# 76:	learn: 5336.4191357	total: 167ms	remaining: 10.7s
# 77:	learn: 5312.1309492	total: 169ms	remaining: 10.7s
# 78:	learn: 5293.8436499	total: 171ms	remaining: 10.7s
# 79:	learn: 5268.4117265	total: 173ms	remaining: 10.6s
# 80:	learn: 5251.9355536	total: 175ms	remaining: 10.6s
# 81:	learn: 5234.2957296	total: 177ms	remaining: 10.6s
# 82:	learn: 5210.6458250	total: 179ms	remaining: 10.6s
# 83:	learn: 5194.6426216	total: 181ms	remaining: 10.6s
# 84:	learn: 5173.5378732	total: 182ms	remaining: 10.5s
# 85:	learn: 5152.2138856	total: 185ms	remaining: 10.6s
# 86:	learn: 5130.2999431	total: 192ms	remaining: 10.8s
# 87:	learn: 5111.8653625	total: 194ms	remaining: 10.8s
# 88:	learn: 5091.4603578	total: 196ms	remaining: 10.8s
# 89:	learn: 5080.7424052	total: 198ms	remaining: 10.8s
# 90:	learn: 5064.4654223	total: 200ms	remaining: 10.8s
# 91:	learn: 5050.6884664	total: 201ms	remaining: 10.7s
# 92:	learn: 5032.8446086	total: 203ms	remaining: 10.7s
# 93:	learn: 5020.8082189	total: 206ms	remaining: 10.7s
# 94:	learn: 5007.3668707	total: 208ms	remaining: 10.7s
# 95:	learn: 4990.0184894	total: 210ms	remaining: 10.7s
# 96:	learn: 4963.2124945	total: 212ms	remaining: 10.7s
# 97:	learn: 4950.3540949	total: 214ms	remaining: 10.7s
# 98:	learn: 4934.6205831	total: 216ms	remaining: 10.7s
# 99:	learn: 4915.3895484	total: 218ms	remaining: 10.7s
# 100:	learn: 4900.6213532	total: 220ms	remaining: 10.7s
# 101:	learn: 4885.9916626	total: 222ms	remaining: 10.7s
# 102:	learn: 4873.1834241	total: 224ms	remaining: 10.7s
# 103:	learn: 4856.8287469	total: 227ms	remaining: 10.7s
# 104:	learn: 4843.6979290	total: 229ms	remaining: 10.7s
# 105:	learn: 4825.2545971	total: 231ms	remaining: 10.6s
# 106:	learn: 4822.4406864	total: 232ms	remaining: 10.6s
# 107:	learn: 4809.3053260	total: 234ms	remaining: 10.6s
# 108:	learn: 4793.5006153	total: 236ms	remaining: 10.6s
# 109:	learn: 4777.7959618	total: 237ms	remaining: 10.6s
# 110:	learn: 4766.3063182	total: 239ms	remaining: 10.5s
# 111:	learn: 4754.7212678	total: 241ms	remaining: 10.5s
# 112:	learn: 4745.0508068	total: 243ms	remaining: 10.5s
# 113:	learn: 4730.6623810	total: 245ms	remaining: 10.5s
# 114:	learn: 4719.9966868	total: 247ms	remaining: 10.5s
# 115:	learn: 4706.5456026	total: 249ms	remaining: 10.5s
# 116:	learn: 4698.5323817	total: 251ms	remaining: 10.5s
# 117:	learn: 4689.2890568	total: 253ms	remaining: 10.5s
# 118:	learn: 4676.4502000	total: 255ms	remaining: 10.4s
# 119:	learn: 4664.8566672	total: 257ms	remaining: 10.4s
# 120:	learn: 4654.2765296	total: 259ms	remaining: 10.4s
# 121:	learn: 4640.1767959	total: 261ms	remaining: 10.4s
# 122:	learn: 4634.4266508	total: 263ms	remaining: 10.4s
# 123:	learn: 4625.8110001	total: 266ms	remaining: 10.5s
# 124:	learn: 4614.3422127	total: 268ms	remaining: 10.4s
# 125:	learn: 4603.3353484	total: 270ms	remaining: 10.4s
# 126:	learn: 4588.6920116	total: 272ms	remaining: 10.4s
# 127:	learn: 4581.6910541	total: 274ms	remaining: 10.4s
# 128:	learn: 4566.6498812	total: 276ms	remaining: 10.4s
# 129:	learn: 4559.9554459	total: 278ms	remaining: 10.4s
# 130:	learn: 4551.9541920	total: 280ms	remaining: 10.4s
# 131:	learn: 4540.6472137	total: 282ms	remaining: 10.4s
# 132:	learn: 4528.0886668	total: 284ms	remaining: 10.4s
# 133:	learn: 4520.0132821	total: 286ms	remaining: 10.4s
# 134:	learn: 4510.5608820	total: 288ms	remaining: 10.4s
# 135:	learn: 4500.0281209	total: 289ms	remaining: 10.4s
# 136:	learn: 4492.0890268	total: 291ms	remaining: 10.3s
# 137:	learn: 4484.5597209	total: 293ms	remaining: 10.3s
# 138:	learn: 4471.3949234	total: 295ms	remaining: 10.3s
# 139:	learn: 4464.3488522	total: 297ms	remaining: 10.3s
# 140:	learn: 4453.7650079	total: 300ms	remaining: 10.3s
# 141:	learn: 4442.0806542	total: 302ms	remaining: 10.3s
# 142:	learn: 4434.2103371	total: 304ms	remaining: 10.3s
# 143:	learn: 4426.0467685	total: 306ms	remaining: 10.3s
# 144:	learn: 4414.5995388	total: 308ms	remaining: 10.3s
# 145:	learn: 4402.8924862	total: 310ms	remaining: 10.3s
# 146:	learn: 4389.8424087	total: 312ms	remaining: 10.3s
# 147:	learn: 4378.1435598	total: 315ms	remaining: 10.3s
# 148:	learn: 4362.1555732	total: 317ms	remaining: 10.3s
# 149:	learn: 4352.5986607	total: 319ms	remaining: 10.3s
# 150:	learn: 4337.0399387	total: 320ms	remaining: 10.3s
# 151:	learn: 4324.2787435	total: 322ms	remaining: 10.3s
# 152:	learn: 4314.9100225	total: 325ms	remaining: 10.3s
# 153:	learn: 4305.7757401	total: 328ms	remaining: 10.3s
# 154:	learn: 4295.4733372	total: 330ms	remaining: 10.3s
# 155:	learn: 4285.4389719	total: 333ms	remaining: 10.3s
# 156:	learn: 4271.4587226	total: 338ms	remaining: 10.4s
# 157:	learn: 4254.1059124	total: 340ms	remaining: 10.4s
# 158:	learn: 4247.4733998	total: 341ms	remaining: 10.4s
# 159:	learn: 4238.8946784	total: 343ms	remaining: 10.4s
# 160:	learn: 4226.2615721	total: 345ms	remaining: 10.4s
# 161:	learn: 4219.3577912	total: 347ms	remaining: 10.4s
# 162:	learn: 4208.4177222	total: 349ms	remaining: 10.4s
# 163:	learn: 4200.6830741	total: 351ms	remaining: 10.3s
# 164:	learn: 4190.3201213	total: 353ms	remaining: 10.3s
# 165:	learn: 4184.4121807	total: 355ms	remaining: 10.3s
# 166:	learn: 4171.7265944	total: 357ms	remaining: 10.3s
# 167:	learn: 4161.6500834	total: 359ms	remaining: 10.3s
# 168:	learn: 4151.9767099	total: 361ms	remaining: 10.3s
# 169:	learn: 4146.2202486	total: 363ms	remaining: 10.3s
# 170:	learn: 4139.1714765	total: 365ms	remaining: 10.3s
# 171:	learn: 4133.5800495	total: 367ms	remaining: 10.3s
# 172:	learn: 4123.8980159	total: 369ms	remaining: 10.3s
# 173:	learn: 4115.8009691	total: 372ms	remaining: 10.3s
# 174:	learn: 4102.1903374	total: 375ms	remaining: 10.3s
# 175:	learn: 4092.7900970	total: 379ms	remaining: 10.4s
# 176:	learn: 4080.4282501	total: 381ms	remaining: 10.4s
# 177:	learn: 4074.6072677	total: 383ms	remaining: 10.4s
# 178:	learn: 4069.6184424	total: 385ms	remaining: 10.4s
# 179:	learn: 4061.6517748	total: 387ms	remaining: 10.4s
# 180:	learn: 4055.9413265	total: 389ms	remaining: 10.4s
# 181:	learn: 4047.3974413	total: 391ms	remaining: 10.4s
# 182:	learn: 4042.7231677	total: 393ms	remaining: 10.4s
# 183:	learn: 4035.1622005	total: 395ms	remaining: 10.3s
# 184:	learn: 4025.6460505	total: 397ms	remaining: 10.3s
# 185:	learn: 4020.4573180	total: 399ms	remaining: 10.3s
# 186:	learn: 4015.3014951	total: 401ms	remaining: 10.3s
# 187:	learn: 4006.3151433	total: 403ms	remaining: 10.3s
# 188:	learn: 4000.5885306	total: 405ms	remaining: 10.3s
# 189:	learn: 3995.5870790	total: 406ms	remaining: 10.3s
# 190:	learn: 3990.0305159	total: 408ms	remaining: 10.3s
# 191:	learn: 3981.7216588	total: 410ms	remaining: 10.3s
# 192:	learn: 3974.2840170	total: 412ms	remaining: 10.3s
# 193:	learn: 3967.3985451	total: 417ms	remaining: 10.3s
# 194:	learn: 3962.7849607	total: 421ms	remaining: 10.4s
# 195:	learn: 3955.5802756	total: 423ms	remaining: 10.4s
# 196:	learn: 3948.8155842	total: 425ms	remaining: 10.4s
# 197:	learn: 3942.7792398	total: 427ms	remaining: 10.4s
# 198:	learn: 3937.8465750	total: 429ms	remaining: 10.4s
# 199:	learn: 3934.0260648	total: 431ms	remaining: 10.3s
# 200:	learn: 3928.9121117	total: 434ms	remaining: 10.3s
# 201:	learn: 3921.5387346	total: 437ms	remaining: 10.4s
# 202:	learn: 3915.9615102	total: 439ms	remaining: 10.4s
# 203:	learn: 3909.9265563	total: 441ms	remaining: 10.4s
# 204:	learn: 3903.6013009	total: 443ms	remaining: 10.4s
# 205:	learn: 3896.2560161	total: 445ms	remaining: 10.3s
# 206:	learn: 3891.4005179	total: 447ms	remaining: 10.3s
# 207:	learn: 3885.2673678	total: 449ms	remaining: 10.3s
# 208:	learn: 3878.1259140	total: 451ms	remaining: 10.3s
# 209:	learn: 3870.9374246	total: 453ms	remaining: 10.3s
# 210:	learn: 3866.0841569	total: 455ms	remaining: 10.3s
# 211:	learn: 3861.1831250	total: 458ms	remaining: 10.4s
# 212:	learn: 3853.9172135	total: 461ms	remaining: 10.3s
# 213:	learn: 3849.9145651	total: 463ms	remaining: 10.3s
# 214:	learn: 3838.1665405	total: 465ms	remaining: 10.3s
# 215:	learn: 3831.4311209	total: 467ms	remaining: 10.3s
# 216:	learn: 3821.6243426	total: 469ms	remaining: 10.3s
# 217:	learn: 3813.4121157	total: 471ms	remaining: 10.3s
# 218:	learn: 3808.2904697	total: 472ms	remaining: 10.3s
# 219:	learn: 3799.5202926	total: 474ms	remaining: 10.3s
# 220:	learn: 3795.1213472	total: 476ms	remaining: 10.3s
# 221:	learn: 3788.9224125	total: 478ms	remaining: 10.3s
# 222:	learn: 3786.5858069	total: 480ms	remaining: 10.3s
# 223:	learn: 3781.8155930	total: 482ms	remaining: 10.3s
# 224:	learn: 3778.2531275	total: 484ms	remaining: 10.3s
# 225:	learn: 3775.0376954	total: 489ms	remaining: 10.3s
# 226:	learn: 3771.6359035	total: 494ms	remaining: 10.4s
# 227:	learn: 3769.3641141	total: 496ms	remaining: 10.4s
# 228:	learn: 3762.5547687	total: 498ms	remaining: 10.4s
# 229:	learn: 3756.9546399	total: 500ms	remaining: 10.4s
# 230:	learn: 3751.1500551	total: 502ms	remaining: 10.4s
# 231:	learn: 3744.4593100	total: 504ms	remaining: 10.4s
# 232:	learn: 3741.2863033	total: 506ms	remaining: 10.4s
# 233:	learn: 3736.9225244	total: 508ms	remaining: 10.3s
# 234:	learn: 3733.5668281	total: 510ms	remaining: 10.3s
# 235:	learn: 3725.6397041	total: 512ms	remaining: 10.3s
# 236:	learn: 3721.4037897	total: 514ms	remaining: 10.3s
# 237:	learn: 3714.4558162	total: 516ms	remaining: 10.3s
# 238:	learn: 3711.1356979	total: 518ms	remaining: 10.3s
# 239:	learn: 3707.5255846	total: 519ms	remaining: 10.3s
# 240:	learn: 3705.5501874	total: 522ms	remaining: 10.3s
# 241:	learn: 3701.5505630	total: 523ms	remaining: 10.3s
# 242:	learn: 3698.2734107	total: 525ms	remaining: 10.3s
# 243:	learn: 3691.1132281	total: 527ms	remaining: 10.3s
# 244:	learn: 3689.0880147	total: 529ms	remaining: 10.3s
# 245:	learn: 3685.0785686	total: 531ms	remaining: 10.3s
# 246:	learn: 3680.0269497	total: 533ms	remaining: 10.3s
# 247:	learn: 3673.5213127	total: 535ms	remaining: 10.2s
# 248:	learn: 3667.6951885	total: 537ms	remaining: 10.2s
# 249:	learn: 3664.3418554	total: 538ms	remaining: 10.2s
# 250:	learn: 3656.5978537	total: 540ms	remaining: 10.2s
# 251:	learn: 3654.5659224	total: 542ms	remaining: 10.2s
# 252:	learn: 3652.1002480	total: 544ms	remaining: 10.2s
# 253:	learn: 3643.9418642	total: 546ms	remaining: 10.2s
# 254:	learn: 3637.9617326	total: 548ms	remaining: 10.2s
# 255:	learn: 3636.4748762	total: 550ms	remaining: 10.2s
# 256:	learn: 3630.9286199	total: 552ms	remaining: 10.2s
# 257:	learn: 3623.6545312	total: 554ms	remaining: 10.2s
# 258:	learn: 3618.2838636	total: 556ms	remaining: 10.2s
# 259:	learn: 3614.3265960	total: 558ms	remaining: 10.2s
# 260:	learn: 3612.9111071	total: 559ms	remaining: 10.2s
# 261:	learn: 3607.1070666	total: 562ms	remaining: 10.2s
# 262:	learn: 3597.9755260	total: 565ms	remaining: 10.2s
# 263:	learn: 3590.6971663	total: 575ms	remaining: 10.3s
# 264:	learn: 3586.0947424	total: 577ms	remaining: 10.3s
# 265:	learn: 3581.1282676	total: 579ms	remaining: 10.3s
# 266:	learn: 3576.0940409	total: 581ms	remaining: 10.3s
# 267:	learn: 3569.7537812	total: 583ms	remaining: 10.3s
# 268:	learn: 3564.4388037	total: 585ms	remaining: 10.3s
# 269:	learn: 3561.4475312	total: 587ms	remaining: 10.3s
# 270:	learn: 3554.7633639	total: 589ms	remaining: 10.3s
# 271:	learn: 3552.9292178	total: 591ms	remaining: 10.3s
# 272:	learn: 3544.5896525	total: 592ms	remaining: 10.3s
# 273:	learn: 3538.3429672	total: 594ms	remaining: 10.3s
# 274:	learn: 3532.3222724	total: 596ms	remaining: 10.2s
# 275:	learn: 3526.5046786	total: 598ms	remaining: 10.2s
# 276:	learn: 3522.2348088	total: 600ms	remaining: 10.2s
# 277:	learn: 3517.9652646	total: 602ms	remaining: 10.2s
# 278:	learn: 3514.6102858	total: 604ms	remaining: 10.2s
# 279:	learn: 3508.9274289	total: 606ms	remaining: 10.2s
# 280:	learn: 3506.1676701	total: 608ms	remaining: 10.2s
# 281:	learn: 3501.3518601	total: 610ms	remaining: 10.2s
# 282:	learn: 3496.0238728	total: 612ms	remaining: 10.2s
# 283:	learn: 3492.3795201	total: 614ms	remaining: 10.2s
# 284:	learn: 3486.7773515	total: 616ms	remaining: 10.2s
# 285:	learn: 3479.1594184	total: 618ms	remaining: 10.2s
# 286:	learn: 3474.5431488	total: 620ms	remaining: 10.2s
# 287:	learn: 3470.3762224	total: 622ms	remaining: 10.2s
# 288:	learn: 3466.1689681	total: 624ms	remaining: 10.2s
# 289:	learn: 3460.1699061	total: 626ms	remaining: 10.2s
# 290:	learn: 3455.7595916	total: 628ms	remaining: 10.2s
# 291:	learn: 3451.7690869	total: 629ms	remaining: 10.1s
# 292:	learn: 3447.2794219	total: 631ms	remaining: 10.1s
# 293:	learn: 3444.1334158	total: 633ms	remaining: 10.1s
# 294:	learn: 3441.7256040	total: 635ms	remaining: 10.1s
# 295:	learn: 3438.8953921	total: 637ms	remaining: 10.1s
# 296:	learn: 3435.2004690	total: 639ms	remaining: 10.1s
# 297:	learn: 3431.5003804	total: 641ms	remaining: 10.1s
# 298:	learn: 3428.2977270	total: 642ms	remaining: 10.1s
# 299:	learn: 3425.6351832	total: 646ms	remaining: 10.1s
# 300:	learn: 3419.8848707	total: 648ms	remaining: 10.1s
# 301:	learn: 3415.5858181	total: 650ms	remaining: 10.1s
# 302:	learn: 3410.5124477	total: 652ms	remaining: 10.1s
# 303:	learn: 3409.1021563	total: 654ms	remaining: 10.1s
# 304:	learn: 3402.1555776	total: 655ms	remaining: 10.1s
# 305:	learn: 3399.0520485	total: 657ms	remaining: 10.1s
# 306:	learn: 3396.2869491	total: 659ms	remaining: 10.1s
# 307:	learn: 3391.1120465	total: 661ms	remaining: 10.1s
# 308:	learn: 3386.2094037	total: 663ms	remaining: 10.1s
# 309:	learn: 3383.1238893	total: 665ms	remaining: 10.1s
# 310:	learn: 3381.0033374	total: 667ms	remaining: 10.1s
# 311:	learn: 3377.7783857	total: 669ms	remaining: 10.1s
# 312:	learn: 3373.1298448	total: 671ms	remaining: 10s
# 313:	learn: 3367.3536802	total: 673ms	remaining: 10s
# 314:	learn: 3362.4519413	total: 675ms	remaining: 10s
# 315:	learn: 3358.7376359	total: 677ms	remaining: 10s
# 316:	learn: 3355.0117917	total: 679ms	remaining: 10s
# 317:	learn: 3348.8746647	total: 681ms	remaining: 10s
# 318:	learn: 3345.8654151	total: 683ms	remaining: 10s
# 319:	learn: 3339.3169109	total: 685ms	remaining: 10s
# 320:	learn: 3335.6890047	total: 687ms	remaining: 10s
# 321:	learn: 3331.3930695	total: 689ms	remaining: 10s
# 322:	learn: 3326.2497860	total: 691ms	remaining: 10s
# 323:	learn: 3324.0595905	total: 692ms	remaining: 9.99s
# 324:	learn: 3317.0312862	total: 694ms	remaining: 9.99s
# 325:	learn: 3314.8049499	total: 696ms	remaining: 9.98s
# 326:	learn: 3312.1825325	total: 702ms	remaining: 10s
# 327:	learn: 3307.4841347	total: 705ms	remaining: 10s
# 328:	learn: 3303.7549211	total: 711ms	remaining: 10.1s
# 329:	learn: 3300.9805490	total: 716ms	remaining: 10.1s
# 330:	learn: 3296.6220682	total: 718ms	remaining: 10.1s
# 331:	learn: 3294.2073445	total: 720ms	remaining: 10.1s
# 332:	learn: 3289.9783984	total: 722ms	remaining: 10.1s
# 333:	learn: 3285.6669238	total: 724ms	remaining: 10.1s
# 334:	learn: 3281.7567601	total: 726ms	remaining: 10.1s
# 335:	learn: 3277.7125053	total: 728ms	remaining: 10.1s
# 336:	learn: 3274.6732151	total: 729ms	remaining: 10.1s
# 337:	learn: 3271.8245758	total: 731ms	remaining: 10.1s
# 338:	learn: 3266.8443956	total: 733ms	remaining: 10.1s
# 339:	learn: 3263.1957043	total: 735ms	remaining: 10.1s
# 340:	learn: 3260.5690956	total: 737ms	remaining: 10.1s
# 341:	learn: 3257.2574743	total: 739ms	remaining: 10.1s
# 342:	learn: 3252.6613244	total: 741ms	remaining: 10.1s
# 343:	learn: 3247.7011672	total: 743ms	remaining: 10.1s
# 344:	learn: 3243.9450911	total: 746ms	remaining: 10.1s
# 345:	learn: 3240.0275242	total: 748ms	remaining: 10.1s
# 346:	learn: 3236.2570597	total: 753ms	remaining: 10.1s
# 347:	learn: 3232.3664264	total: 757ms	remaining: 10.1s
# 348:	learn: 3228.0039518	total: 759ms	remaining: 10.1s
# 349:	learn: 3222.3393595	total: 761ms	remaining: 10.1s
# 350:	learn: 3218.7205654	total: 766ms	remaining: 10.2s
# 351:	learn: 3215.3525555	total: 769ms	remaining: 10.2s
# 352:	learn: 3210.7712792	total: 775ms	remaining: 10.2s
# 353:	learn: 3206.8879115	total: 778ms	remaining: 10.2s
# 354:	learn: 3203.2362515	total: 784ms	remaining: 10.3s
# 355:	learn: 3200.0704246	total: 786ms	remaining: 10.3s
# 356:	learn: 3197.5503066	total: 789ms	remaining: 10.3s
# 357:	learn: 3193.6476792	total: 792ms	remaining: 10.3s
# 358:	learn: 3191.6700876	total: 794ms	remaining: 10.3s
# 359:	learn: 3188.2670161	total: 797ms	remaining: 10.3s
# 360:	learn: 3184.9832115	total: 799ms	remaining: 10.3s
# 361:	learn: 3182.0201121	total: 800ms	remaining: 10.3s
# 362:	learn: 3179.4598930	total: 802ms	remaining: 10.2s
# 363:	learn: 3175.8333666	total: 804ms	remaining: 10.2s
# 364:	learn: 3171.2937307	total: 806ms	remaining: 10.2s
# 365:	learn: 3167.7022693	total: 808ms	remaining: 10.2s
# 366:	learn: 3165.1634636	total: 810ms	remaining: 10.2s
# 367:	learn: 3160.9930791	total: 812ms	remaining: 10.2s
# 368:	learn: 3157.9644712	total: 814ms	remaining: 10.2s
# 369:	learn: 3156.1285535	total: 816ms	remaining: 10.2s
# 370:	learn: 3153.1601723	total: 818ms	remaining: 10.2s
# 371:	learn: 3149.6841072	total: 820ms	remaining: 10.2s
# 372:	learn: 3146.8661014	total: 822ms	remaining: 10.2s
# 373:	learn: 3142.5716635	total: 824ms	remaining: 10.2s
# 374:	learn: 3140.3030499	total: 825ms	remaining: 10.2s
# 375:	learn: 3135.4332003	total: 827ms	remaining: 10.2s
# 376:	learn: 3131.8168829	total: 829ms	remaining: 10.2s
# 377:	learn: 3129.6547380	total: 831ms	remaining: 10.2s
# 378:	learn: 3126.7850979	total: 833ms	remaining: 10.2s
# 379:	learn: 3123.3795040	total: 835ms	remaining: 10.2s
# 380:	learn: 3119.5774390	total: 837ms	remaining: 10.1s
# 381:	learn: 3117.4214342	total: 839ms	remaining: 10.1s
# 382:	learn: 3114.9203418	total: 841ms	remaining: 10.1s
# 383:	learn: 3112.0204184	total: 843ms	remaining: 10.1s
# 384:	learn: 3109.9740027	total: 845ms	remaining: 10.1s
# 385:	learn: 3106.6686003	total: 847ms	remaining: 10.1s
# 386:	learn: 3105.3590057	total: 849ms	remaining: 10.1s
# 387:	learn: 3101.6570299	total: 851ms	remaining: 10.1s
# 388:	learn: 3097.6476467	total: 853ms	remaining: 10.1s
# 389:	learn: 3093.8794412	total: 855ms	remaining: 10.1s
# 390:	learn: 3091.7504913	total: 857ms	remaining: 10.1s
# 391:	learn: 3089.3816729	total: 859ms	remaining: 10.1s
# 392:	learn: 3085.9878157	total: 861ms	remaining: 10.1s
# 393:	learn: 3082.7806090	total: 863ms	remaining: 10.1s
# 394:	learn: 3078.0089630	total: 865ms	remaining: 10.1s
# 395:	learn: 3073.6536920	total: 867ms	remaining: 10.1s
# 396:	learn: 3069.9098182	total: 869ms	remaining: 10.1s
# 397:	learn: 3067.2896088	total: 870ms	remaining: 10.1s
# 398:	learn: 3062.2002642	total: 872ms	remaining: 10.1s
# 399:	learn: 3058.6031438	total: 874ms	remaining: 10.1s
# 400:	learn: 3056.6546263	total: 876ms	remaining: 10s
# 401:	learn: 3054.9552497	total: 878ms	remaining: 10s
# 402:	learn: 3052.0290006	total: 880ms	remaining: 10s
# 403:	learn: 3048.2526961	total: 882ms	remaining: 10s
# 404:	learn: 3046.7902892	total: 884ms	remaining: 10s
# 405:	learn: 3043.4054673	total: 886ms	remaining: 10s
# 406:	learn: 3041.5162145	total: 888ms	remaining: 10s
# 407:	learn: 3039.7857544	total: 890ms	remaining: 10s
# 408:	learn: 3037.1553978	total: 892ms	remaining: 10s
# 409:	learn: 3034.9071377	total: 894ms	remaining: 10s
# 410:	learn: 3029.3057032	total: 896ms	remaining: 10s
# 411:	learn: 3027.2857552	total: 898ms	remaining: 10s
# 412:	learn: 3024.6011043	total: 900ms	remaining: 9.99s
# 413:	learn: 3021.3461951	total: 902ms	remaining: 9.99s
# 414:	learn: 3018.4855144	total: 904ms	remaining: 9.98s
# 415:	learn: 3015.0381219	total: 906ms	remaining: 9.98s
# 416:	learn: 3012.0989192	total: 908ms	remaining: 9.98s
# 417:	learn: 3010.2673399	total: 910ms	remaining: 9.97s
# 418:	learn: 3007.2675979	total: 912ms	remaining: 9.97s
# 419:	learn: 3005.0333173	total: 914ms	remaining: 9.96s
# 420:	learn: 3002.9481453	total: 916ms	remaining: 9.96s
# 421:	learn: 3000.3271786	total: 918ms	remaining: 9.95s
# 422:	learn: 2998.0978444	total: 920ms	remaining: 9.95s
# 423:	learn: 2997.5792777	total: 921ms	remaining: 9.94s
# 424:	learn: 2994.3496064	total: 923ms	remaining: 9.93s
# 425:	learn: 2990.3406374	total: 925ms	remaining: 9.93s
# 426:	learn: 2988.9381337	total: 927ms	remaining: 9.92s
# 427:	learn: 2985.5926429	total: 929ms	remaining: 9.92s
# 428:	learn: 2983.0462624	total: 930ms	remaining: 9.91s
# 429:	learn: 2981.1373919	total: 932ms	remaining: 9.91s
# 430:	learn: 2980.2532624	total: 934ms	remaining: 9.9s
# 431:	learn: 2976.0133759	total: 941ms	remaining: 9.95s
# 432:	learn: 2974.6684189	total: 944ms	remaining: 9.95s
# 433:	learn: 2971.3448253	total: 946ms	remaining: 9.95s
# 434:	learn: 2968.0518823	total: 948ms	remaining: 9.95s
# 435:	learn: 2964.6685837	total: 950ms	remaining: 9.94s
# 436:	learn: 2960.8437158	total: 952ms	remaining: 9.94s
# 437:	learn: 2956.7366047	total: 954ms	remaining: 9.94s
# 438:	learn: 2954.6005032	total: 956ms	remaining: 9.93s
# 439:	learn: 2953.4809267	total: 958ms	remaining: 9.93s
# 440:	learn: 2950.2824408	total: 960ms	remaining: 9.92s
# 441:	learn: 2947.6929680	total: 962ms	remaining: 9.92s
# 442:	learn: 2944.6981584	total: 964ms	remaining: 9.91s
# 443:	learn: 2942.2223677	total: 966ms	remaining: 9.91s
# 444:	learn: 2939.3968067	total: 968ms	remaining: 9.91s
# 445:	learn: 2938.0129535	total: 970ms	remaining: 9.9s
# 446:	learn: 2935.7215056	total: 972ms	remaining: 9.9s
# 447:	learn: 2933.5085771	total: 974ms	remaining: 9.89s
# 448:	learn: 2931.2441742	total: 978ms	remaining: 9.91s
# 449:	learn: 2928.3822471	total: 980ms	remaining: 9.91s
# 450:	learn: 2925.2389759	total: 982ms	remaining: 9.9s
# 451:	learn: 2923.3808906	total: 984ms	remaining: 9.9s
# 452:	learn: 2921.6715636	total: 986ms	remaining: 9.89s
# 453:	learn: 2918.4516190	total: 988ms	remaining: 9.89s
# 454:	learn: 2915.4673094	total: 990ms	remaining: 9.89s
# 455:	learn: 2913.1600439	total: 992ms	remaining: 9.88s
# 456:	learn: 2909.9809411	total: 994ms	remaining: 9.88s
# 457:	learn: 2906.1256114	total: 996ms	remaining: 9.88s
# 458:	learn: 2903.5400774	total: 998ms	remaining: 9.87s
# 459:	learn: 2901.1555202	total: 1s	remaining: 9.87s
# 460:	learn: 2898.2858594	total: 1s	remaining: 9.87s
# 461:	learn: 2896.7115276	total: 1s	remaining: 9.86s
# 462:	learn: 2892.5155562	total: 1.01s	remaining: 9.86s
# 463:	learn: 2890.9323639	total: 1.01s	remaining: 9.85s
# 464:	learn: 2888.6346260	total: 1.01s	remaining: 9.86s
# 465:	learn: 2886.6944110	total: 1.01s	remaining: 9.86s
# 466:	learn: 2886.1732398	total: 1.01s	remaining: 9.85s
# 467:	learn: 2883.8746524	total: 1.02s	remaining: 9.86s
# 468:	learn: 2883.1606492	total: 1.02s	remaining: 9.88s
# 469:	learn: 2880.2725332	total: 1.02s	remaining: 9.87s
# 470:	learn: 2878.0103376	total: 1.02s	remaining: 9.87s
# 471:	learn: 2875.7970753	total: 1.03s	remaining: 9.86s
# 472:	learn: 2873.4090107	total: 1.03s	remaining: 9.87s
# 473:	learn: 2870.3685249	total: 1.03s	remaining: 9.86s
# 474:	learn: 2867.5458614	total: 1.03s	remaining: 9.86s
# 475:	learn: 2865.6480576	total: 1.04s	remaining: 9.86s
# 476:	learn: 2863.5054284	total: 1.04s	remaining: 9.85s
# 477:	learn: 2861.1099216	total: 1.04s	remaining: 9.85s
# 478:	learn: 2859.4475542	total: 1.04s	remaining: 9.85s
# 479:	learn: 2856.5088337	total: 1.04s	remaining: 9.84s
# 480:	learn: 2854.5807955	total: 1.05s	remaining: 9.84s
# 481:	learn: 2853.3842366	total: 1.05s	remaining: 9.83s
# 482:	learn: 2849.9346050	total: 1.05s	remaining: 9.83s
# 483:	learn: 2848.8488799	total: 1.05s	remaining: 9.82s
# 484:	learn: 2846.2356343	total: 1.05s	remaining: 9.82s
# 485:	learn: 2843.9777739	total: 1.06s	remaining: 9.83s
# 486:	learn: 2840.9500418	total: 1.06s	remaining: 9.83s
# 487:	learn: 2839.9432763	total: 1.06s	remaining: 9.82s
# 488:	learn: 2838.0816337	total: 1.06s	remaining: 9.82s
# 489:	learn: 2835.2909167	total: 1.07s	remaining: 9.81s
# 490:	learn: 2834.6408717	total: 1.07s	remaining: 9.81s
# 491:	learn: 2832.5413114	total: 1.07s	remaining: 9.8s
# 492:	learn: 2830.7095132	total: 1.07s	remaining: 9.8s
# 493:	learn: 2828.9887825	total: 1.07s	remaining: 9.8s
# 494:	learn: 2827.9319627	total: 1.08s	remaining: 9.79s
# 495:	learn: 2825.9356564	total: 1.08s	remaining: 9.79s
# 496:	learn: 2823.4133454	total: 1.08s	remaining: 9.79s
# 497:	learn: 2821.2976063	total: 1.08s	remaining: 9.78s
# 498:	learn: 2818.0928405	total: 1.08s	remaining: 9.78s
# 499:	learn: 2815.9817228	total: 1.09s	remaining: 9.77s
# 500:	learn: 2813.8665141	total: 1.09s	remaining: 9.77s
# 501:	learn: 2811.4459708	total: 1.09s	remaining: 9.77s
# 502:	learn: 2809.0765284	total: 1.09s	remaining: 9.76s
# 503:	learn: 2807.5631152	total: 1.09s	remaining: 9.76s
# 504:	learn: 2805.0928855	total: 1.1s	remaining: 9.77s
# 505:	learn: 2803.1125035	total: 1.1s	remaining: 9.76s
# 506:	learn: 2801.1938144	total: 1.1s	remaining: 9.76s
# 507:	learn: 2798.7127617	total: 1.1s	remaining: 9.76s
# 508:	learn: 2796.2916800	total: 1.1s	remaining: 9.75s
# 509:	learn: 2794.0496092	total: 1.11s	remaining: 9.75s
# 510:	learn: 2790.6174709	total: 1.11s	remaining: 9.74s
# 511:	learn: 2789.1504626	total: 1.11s	remaining: 9.74s
# 512:	learn: 2787.4381034	total: 1.11s	remaining: 9.74s
# 513:	learn: 2785.6759431	total: 1.11s	remaining: 9.73s
# 514:	learn: 2783.2004392	total: 1.12s	remaining: 9.73s
# 515:	learn: 2780.9854546	total: 1.12s	remaining: 9.72s
# 516:	learn: 2780.1388809	total: 1.12s	remaining: 9.72s
# 517:	learn: 2778.3723037	total: 1.12s	remaining: 9.72s
# 518:	learn: 2775.6095306	total: 1.13s	remaining: 9.71s
# 519:	learn: 2773.3146387	total: 1.13s	remaining: 9.71s
# 520:	learn: 2771.8363602	total: 1.13s	remaining: 9.73s
# 521:	learn: 2769.2663125	total: 1.14s	remaining: 9.75s
# 522:	learn: 2768.4482803	total: 1.14s	remaining: 9.75s
# 523:	learn: 2765.6386178	total: 1.14s	remaining: 9.75s
# 524:	learn: 2764.8709808	total: 1.14s	remaining: 9.74s
# 525:	learn: 2762.8900153	total: 1.14s	remaining: 9.74s
# 526:	learn: 2761.0651465	total: 1.15s	remaining: 9.73s
# 527:	learn: 2758.3630641	total: 1.15s	remaining: 9.73s
# 528:	learn: 2756.7626068	total: 1.15s	remaining: 9.73s
# 529:	learn: 2754.3788583	total: 1.15s	remaining: 9.72s
# 530:	learn: 2752.7271418	total: 1.15s	remaining: 9.72s
# 531:	learn: 2750.3798447	total: 1.16s	remaining: 9.72s
# 532:	learn: 2747.9963360	total: 1.16s	remaining: 9.71s
# 533:	learn: 2745.6429543	total: 1.16s	remaining: 9.71s
# 534:	learn: 2744.9526788	total: 1.16s	remaining: 9.7s
# 535:	learn: 2743.0884493	total: 1.16s	remaining: 9.7s
# 536:	learn: 2741.9317465	total: 1.17s	remaining: 9.7s
# 537:	learn: 2740.7523396	total: 1.17s	remaining: 9.69s
# 538:	learn: 2739.0000209	total: 1.17s	remaining: 9.69s
# 539:	learn: 2735.9292885	total: 1.17s	remaining: 9.68s
# 540:	learn: 2733.9519456	total: 1.18s	remaining: 9.69s
# 541:	learn: 2731.0928073	total: 1.18s	remaining: 9.69s
# 542:	learn: 2730.5498434	total: 1.18s	remaining: 9.68s
# 543:	learn: 2728.4972192	total: 1.18s	remaining: 9.68s
# 544:	learn: 2726.3737155	total: 1.18s	remaining: 9.67s
# 545:	learn: 2724.8136970	total: 1.19s	remaining: 9.67s
# 546:	learn: 2723.2260480	total: 1.19s	remaining: 9.67s
# 547:	learn: 2721.7713783	total: 1.19s	remaining: 9.66s
# 548:	learn: 2719.3939589	total: 1.19s	remaining: 9.66s
# 549:	learn: 2717.4029707	total: 1.19s	remaining: 9.65s
# 550:	learn: 2716.7616387	total: 1.2s	remaining: 9.65s
# 551:	learn: 2715.7938984	total: 1.2s	remaining: 9.65s
# 552:	learn: 2714.8246863	total: 1.2s	remaining: 9.64s
# 553:	learn: 2711.8208565	total: 1.2s	remaining: 9.64s
# 554:	learn: 2709.3631121	total: 1.2s	remaining: 9.64s
# 555:	learn: 2706.4759017	total: 1.21s	remaining: 9.63s
# 556:	learn: 2704.5967603	total: 1.21s	remaining: 9.63s
# 557:	learn: 2702.3372083	total: 1.21s	remaining: 9.62s
# 558:	learn: 2700.5767201	total: 1.21s	remaining: 9.62s
# 559:	learn: 2699.4897138	total: 1.21s	remaining: 9.62s
# 560:	learn: 2697.1187884	total: 1.22s	remaining: 9.62s
# 561:	learn: 2696.1283907	total: 1.22s	remaining: 9.61s
# 562:	learn: 2695.1401637	total: 1.22s	remaining: 9.61s
# 563:	learn: 2694.1754821	total: 1.22s	remaining: 9.6s
# 564:	learn: 2692.9310458	total: 1.22s	remaining: 9.6s
# 565:	learn: 2691.3153772	total: 1.22s	remaining: 9.59s
# 566:	learn: 2690.0951430	total: 1.23s	remaining: 9.59s
# 567:	learn: 2687.6584875	total: 1.23s	remaining: 9.58s
# 568:	learn: 2686.3504671	total: 1.23s	remaining: 9.58s
# 569:	learn: 2685.4486474	total: 1.23s	remaining: 9.58s
# 570:	learn: 2683.5822916	total: 1.23s	remaining: 9.57s
# 571:	learn: 2680.5883952	total: 1.24s	remaining: 9.57s
# 572:	learn: 2678.6560686	total: 1.24s	remaining: 9.56s
# 573:	learn: 2678.0344138	total: 1.24s	remaining: 9.56s
# 574:	learn: 2676.8953234	total: 1.24s	remaining: 9.56s
# 575:	learn: 2675.2032818	total: 1.24s	remaining: 9.56s
# 576:	learn: 2674.4740741	total: 1.25s	remaining: 9.55s
# 577:	learn: 2672.3573246	total: 1.25s	remaining: 9.55s
# 578:	learn: 2670.0823616	total: 1.25s	remaining: 9.54s
# 579:	learn: 2668.9627114	total: 1.25s	remaining: 9.54s
# 580:	learn: 2666.6765777	total: 1.26s	remaining: 9.55s
# 581:	learn: 2664.3324660	total: 1.26s	remaining: 9.55s
# 582:	learn: 2662.4488132	total: 1.26s	remaining: 9.54s
# 583:	learn: 2661.8215331	total: 1.26s	remaining: 9.54s
# 584:	learn: 2660.2633837	total: 1.26s	remaining: 9.55s
# 585:	learn: 2657.6050560	total: 1.27s	remaining: 9.54s
# 586:	learn: 2655.3288457	total: 1.27s	remaining: 9.54s
# 587:	learn: 2653.1147402	total: 1.27s	remaining: 9.54s
# 588:	learn: 2652.1674367	total: 1.27s	remaining: 9.53s
# 589:	learn: 2649.8150099	total: 1.27s	remaining: 9.53s
# 590:	learn: 2647.8216099	total: 1.28s	remaining: 9.52s
# 591:	learn: 2645.6013337	total: 1.28s	remaining: 9.52s
# 592:	learn: 2644.7214207	total: 1.28s	remaining: 9.52s
# 593:	learn: 2642.2589979	total: 1.28s	remaining: 9.51s
# 594:	learn: 2639.6470268	total: 1.28s	remaining: 9.51s
# 595:	learn: 2639.0510850	total: 1.29s	remaining: 9.5s
# 596:	learn: 2638.1737652	total: 1.29s	remaining: 9.5s
# 597:	learn: 2636.0489872	total: 1.29s	remaining: 9.5s
# 598:	learn: 2635.5420474	total: 1.29s	remaining: 9.49s
# 599:	learn: 2633.7430877	total: 1.29s	remaining: 9.49s
# 600:	learn: 2632.3285343	total: 1.29s	remaining: 9.48s
# 601:	learn: 2630.6309842	total: 1.3s	remaining: 9.48s
# 602:	learn: 2628.9134000	total: 1.3s	remaining: 9.47s
# 603:	learn: 2628.3515971	total: 1.3s	remaining: 9.47s
# 604:	learn: 2626.2224523	total: 1.3s	remaining: 9.47s
# 605:	learn: 2625.8602114	total: 1.3s	remaining: 9.46s
# 606:	learn: 2623.6426453	total: 1.31s	remaining: 9.46s
# 607:	learn: 2620.8499971	total: 1.31s	remaining: 9.46s
# 608:	learn: 2619.3398478	total: 1.31s	remaining: 9.45s
# 609:	learn: 2617.5816498	total: 1.31s	remaining: 9.45s
# 610:	learn: 2616.3352508	total: 1.31s	remaining: 9.44s
# 611:	learn: 2614.4056915	total: 1.32s	remaining: 9.44s
# 612:	learn: 2612.5255471	total: 1.32s	remaining: 9.44s
# 613:	learn: 2611.2151899	total: 1.32s	remaining: 9.45s
# 614:	learn: 2610.3606169	total: 1.33s	remaining: 9.46s
# 615:	learn: 2608.9999115	total: 1.33s	remaining: 9.47s
# 616:	learn: 2607.7507505	total: 1.33s	remaining: 9.47s
# 617:	learn: 2606.0019016	total: 1.33s	remaining: 9.46s
# 618:	learn: 2603.5766782	total: 1.34s	remaining: 9.46s
# 619:	learn: 2601.2541317	total: 1.34s	remaining: 9.46s
# 620:	learn: 2599.6252103	total: 1.34s	remaining: 9.46s
# 621:	learn: 2598.6914093	total: 1.34s	remaining: 9.45s
# 622:	learn: 2596.7698054	total: 1.34s	remaining: 9.45s
# 623:	learn: 2594.7660858	total: 1.35s	remaining: 9.45s
# 624:	learn: 2593.1920814	total: 1.35s	remaining: 9.44s
# 625:	learn: 2591.6423359	total: 1.35s	remaining: 9.44s
# 626:	learn: 2590.0641717	total: 1.35s	remaining: 9.43s
# 627:	learn: 2587.5483294	total: 1.35s	remaining: 9.43s
# 628:	learn: 2585.6417477	total: 1.36s	remaining: 9.43s
# 629:	learn: 2584.3220949	total: 1.36s	remaining: 9.42s
# 630:	learn: 2583.4018433	total: 1.36s	remaining: 9.42s
# 631:	learn: 2582.1976690	total: 1.36s	remaining: 9.41s
# 632:	learn: 2580.6332689	total: 1.36s	remaining: 9.41s
# 633:	learn: 2579.6159686	total: 1.37s	remaining: 9.41s
# 634:	learn: 2577.0234028	total: 1.37s	remaining: 9.41s
# 635:	learn: 2575.4413297	total: 1.37s	remaining: 9.4s
# 636:	learn: 2573.7643067	total: 1.37s	remaining: 9.4s
# 637:	learn: 2572.8944686	total: 1.37s	remaining: 9.39s
# 638:	learn: 2571.0933854	total: 1.38s	remaining: 9.39s
# 639:	learn: 2570.0937066	total: 1.38s	remaining: 9.39s
# 640:	learn: 2569.5080143	total: 1.38s	remaining: 9.38s
# 641:	learn: 2568.6611852	total: 1.38s	remaining: 9.38s
# 642:	learn: 2566.1814057	total: 1.38s	remaining: 9.38s
# 643:	learn: 2564.9570185	total: 1.39s	remaining: 9.37s
# 644:	learn: 2563.8416687	total: 1.39s	remaining: 9.37s
# 645:	learn: 2562.7233797	total: 1.39s	remaining: 9.38s
# 646:	learn: 2560.8973899	total: 1.39s	remaining: 9.38s
# 647:	learn: 2559.8421331	total: 1.4s	remaining: 9.38s
# 648:	learn: 2558.7729405	total: 1.4s	remaining: 9.38s
# 649:	learn: 2557.7436087	total: 1.4s	remaining: 9.38s
# 650:	learn: 2555.7588491	total: 1.4s	remaining: 9.37s
# 651:	learn: 2553.8591885	total: 1.4s	remaining: 9.37s
# 652:	learn: 2553.2077894	total: 1.41s	remaining: 9.37s
# 653:	learn: 2551.2433269	total: 1.41s	remaining: 9.36s
# 654:	learn: 2549.5438011	total: 1.41s	remaining: 9.36s
# 655:	learn: 2548.6045913	total: 1.41s	remaining: 9.36s
# 656:	learn: 2546.6208906	total: 1.41s	remaining: 9.35s
# 657:	learn: 2544.6405123	total: 1.42s	remaining: 9.35s
# 658:	learn: 2543.1112053	total: 1.42s	remaining: 9.35s
# 659:	learn: 2541.7021724	total: 1.42s	remaining: 9.34s
# 660:	learn: 2540.1763604	total: 1.42s	remaining: 9.34s
# 661:	learn: 2539.2571944	total: 1.43s	remaining: 9.35s
# 662:	learn: 2537.4119333	total: 1.43s	remaining: 9.37s
# 663:	learn: 2536.8040826	total: 1.43s	remaining: 9.37s
# 664:	learn: 2535.1518416	total: 1.44s	remaining: 9.37s
# 665:	learn: 2533.8951856	total: 1.44s	remaining: 9.37s
# 666:	learn: 2531.9365662	total: 1.44s	remaining: 9.37s
# 667:	learn: 2530.1116383	total: 1.44s	remaining: 9.37s
# 668:	learn: 2527.9717467	total: 1.45s	remaining: 9.37s
# 669:	learn: 2526.1194670	total: 1.45s	remaining: 9.36s
# 670:	learn: 2523.6495602	total: 1.45s	remaining: 9.36s
# 671:	learn: 2522.6740076	total: 1.45s	remaining: 9.36s
# 672:	learn: 2520.8440916	total: 1.45s	remaining: 9.35s
# 673:	learn: 2519.9671519	total: 1.46s	remaining: 9.35s
# 674:	learn: 2518.5663517	total: 1.46s	remaining: 9.35s
# 675:	learn: 2517.5896088	total: 1.46s	remaining: 9.34s
# 676:	learn: 2515.9716428	total: 1.46s	remaining: 9.34s
# 677:	learn: 2515.1921505	total: 1.46s	remaining: 9.33s
# 678:	learn: 2514.0000077	total: 1.47s	remaining: 9.33s
# 679:	learn: 2511.8531879	total: 1.47s	remaining: 9.33s
# 680:	learn: 2510.6052626	total: 1.47s	remaining: 9.33s
# 681:	learn: 2510.0495469	total: 1.47s	remaining: 9.32s
# 682:	learn: 2508.6555748	total: 1.47s	remaining: 9.32s
# 683:	learn: 2506.9055710	total: 1.48s	remaining: 9.32s
# 684:	learn: 2505.3080348	total: 1.48s	remaining: 9.31s
# 685:	learn: 2503.9700273	total: 1.48s	remaining: 9.31s
# 686:	learn: 2503.0607167	total: 1.48s	remaining: 9.31s
# 687:	learn: 2501.8877825	total: 1.48s	remaining: 9.3s
# 688:	learn: 2500.7006672	total: 1.49s	remaining: 9.3s
# 689:	learn: 2498.9623704	total: 1.49s	remaining: 9.3s
# 690:	learn: 2497.9033045	total: 1.49s	remaining: 9.29s
# 691:	learn: 2496.1347780	total: 1.49s	remaining: 9.29s
# 692:	learn: 2495.2506355	total: 1.49s	remaining: 9.29s
# 693:	learn: 2494.0882601	total: 1.5s	remaining: 9.28s
# 694:	learn: 2492.9841598	total: 1.5s	remaining: 9.28s
# 695:	learn: 2491.8669465	total: 1.5s	remaining: 9.28s
# 696:	learn: 2491.1753216	total: 1.5s	remaining: 9.27s
# 697:	learn: 2489.0321811	total: 1.5s	remaining: 9.27s
# 698:	learn: 2486.8601493	total: 1.51s	remaining: 9.27s
# 699:	learn: 2485.3915875	total: 1.51s	remaining: 9.26s
# 700:	learn: 2483.9992759	total: 1.51s	remaining: 9.26s
# 701:	learn: 2482.5125331	total: 1.52s	remaining: 9.28s
# 702:	learn: 2481.1040573	total: 1.52s	remaining: 9.29s
# 703:	learn: 2479.8500926	total: 1.52s	remaining: 9.28s
# 704:	learn: 2477.8990061	total: 1.52s	remaining: 9.28s
# 705:	learn: 2477.1294352	total: 1.52s	remaining: 9.28s
# 706:	learn: 2476.1779311	total: 1.53s	remaining: 9.27s
# 707:	learn: 2475.4902599	total: 1.53s	remaining: 9.27s
# 708:	learn: 2474.3418498	total: 1.53s	remaining: 9.27s
# 709:	learn: 2473.6139669	total: 1.53s	remaining: 9.26s
# 710:	learn: 2472.0260960	total: 1.53s	remaining: 9.26s
# 711:	learn: 2470.1116086	total: 1.54s	remaining: 9.26s
# 712:	learn: 2469.2567773	total: 1.54s	remaining: 9.25s
# 713:	learn: 2468.2691482	total: 1.54s	remaining: 9.25s
# 714:	learn: 2467.0031043	total: 1.54s	remaining: 9.25s
# 715:	learn: 2465.9146420	total: 1.54s	remaining: 9.24s
# 716:	learn: 2464.6212370	total: 1.55s	remaining: 9.24s
# 717:	learn: 2463.3682330	total: 1.55s	remaining: 9.24s
# 718:	learn: 2462.1233243	total: 1.55s	remaining: 9.23s
# 719:	learn: 2460.5136821	total: 1.55s	remaining: 9.23s
# 720:	learn: 2459.4153435	total: 1.55s	remaining: 9.22s
# 721:	learn: 2458.2940991	total: 1.56s	remaining: 9.22s
# 722:	learn: 2456.8130020	total: 1.56s	remaining: 9.22s
# 723:	learn: 2455.0454323	total: 1.56s	remaining: 9.22s
# 724:	learn: 2453.7352379	total: 1.56s	remaining: 9.22s
# 725:	learn: 2451.5703095	total: 1.56s	remaining: 9.22s
# 726:	learn: 2449.6575108	total: 1.57s	remaining: 9.21s
# 727:	learn: 2448.6434167	total: 1.57s	remaining: 9.21s
# 728:	learn: 2447.7484054	total: 1.57s	remaining: 9.22s
# 729:	learn: 2446.4947248	total: 1.58s	remaining: 9.22s
# 730:	learn: 2444.3657789	total: 1.58s	remaining: 9.21s
# 731:	learn: 2442.9793301	total: 1.58s	remaining: 9.21s
# 732:	learn: 2440.6676050	total: 1.58s	remaining: 9.21s
# 733:	learn: 2440.0951142	total: 1.58s	remaining: 9.21s
# 734:	learn: 2438.4560719	total: 1.59s	remaining: 9.2s
# 735:	learn: 2436.5913162	total: 1.59s	remaining: 9.2s
# 736:	learn: 2435.7116500	total: 1.59s	remaining: 9.2s
# 737:	learn: 2434.0083373	total: 1.59s	remaining: 9.19s
# 738:	learn: 2432.7833504	total: 1.59s	remaining: 9.19s
# 739:	learn: 2431.6515145	total: 1.59s	remaining: 9.19s
# 740:	learn: 2430.2135326	total: 1.6s	remaining: 9.18s
# 741:	learn: 2429.6031233	total: 1.6s	remaining: 9.18s
# 742:	learn: 2428.5336761	total: 1.6s	remaining: 9.18s
# 743:	learn: 2426.6524214	total: 1.6s	remaining: 9.18s
# 744:	learn: 2425.7866794	total: 1.6s	remaining: 9.17s
# 745:	learn: 2425.1434340	total: 1.61s	remaining: 9.17s
# 746:	learn: 2424.2580820	total: 1.61s	remaining: 9.16s
# 747:	learn: 2423.0530377	total: 1.61s	remaining: 9.16s
# 748:	learn: 2421.1756511	total: 1.61s	remaining: 9.16s
# 749:	learn: 2420.2705757	total: 1.61s	remaining: 9.15s
# 750:	learn: 2419.4349615	total: 1.62s	remaining: 9.15s
# 751:	learn: 2418.0500169	total: 1.62s	remaining: 9.15s
# 752:	learn: 2416.7600647	total: 1.62s	remaining: 9.14s
# 753:	learn: 2414.5005258	total: 1.62s	remaining: 9.14s
# 754:	learn: 2413.8391982	total: 1.62s	remaining: 9.13s
# 755:	learn: 2413.4975858	total: 1.63s	remaining: 9.13s
# 756:	learn: 2412.6886330	total: 1.63s	remaining: 9.13s
# 757:	learn: 2411.3981788	total: 1.63s	remaining: 9.12s
# 758:	learn: 2410.6498531	total: 1.63s	remaining: 9.12s
# 759:	learn: 2409.3598304	total: 1.63s	remaining: 9.12s
# 760:	learn: 2407.9887938	total: 1.64s	remaining: 9.11s
# 761:	learn: 2405.9473906	total: 1.64s	remaining: 9.11s
# 762:	learn: 2404.7822502	total: 1.64s	remaining: 9.11s
# 763:	learn: 2403.5085407	total: 1.64s	remaining: 9.1s
# 764:	learn: 2402.8608764	total: 1.64s	remaining: 9.1s
# 765:	learn: 2401.7468744	total: 1.65s	remaining: 9.1s
# 766:	learn: 2399.8410014	total: 1.65s	remaining: 9.09s
# 767:	learn: 2398.2414759	total: 1.65s	remaining: 9.09s
# 768:	learn: 2397.3211104	total: 1.65s	remaining: 9.09s
# 769:	learn: 2395.6350702	total: 1.65s	remaining: 9.08s
# 770:	learn: 2394.4693840	total: 1.66s	remaining: 9.08s
# 771:	learn: 2393.2799841	total: 1.66s	remaining: 9.08s
# 772:	learn: 2391.3612789	total: 1.66s	remaining: 9.07s
# 773:	learn: 2389.1312408	total: 1.66s	remaining: 9.07s
# 774:	learn: 2388.1522595	total: 1.66s	remaining: 9.07s
# 775:	learn: 2386.4777521	total: 1.67s	remaining: 9.06s
# 776:	learn: 2384.9009681	total: 1.67s	remaining: 9.06s
# 777:	learn: 2383.8972087	total: 1.67s	remaining: 9.06s
# 778:	learn: 2382.7260772	total: 1.67s	remaining: 9.05s
# 779:	learn: 2381.9468257	total: 1.67s	remaining: 9.05s
# 780:	learn: 2381.2243711	total: 1.68s	remaining: 9.05s
# 781:	learn: 2380.1692497	total: 1.68s	remaining: 9.04s
# 782:	learn: 2379.3500407	total: 1.68s	remaining: 9.04s
# 783:	learn: 2378.3514921	total: 1.68s	remaining: 9.04s
# 784:	learn: 2376.5965340	total: 1.68s	remaining: 9.04s
# 785:	learn: 2375.0114795	total: 1.69s	remaining: 9.04s
# 786:	learn: 2373.9538476	total: 1.69s	remaining: 9.03s
# 787:	learn: 2372.3545764	total: 1.69s	remaining: 9.03s
# 788:	learn: 2370.9099160	total: 1.69s	remaining: 9.03s
# 789:	learn: 2370.2174777	total: 1.69s	remaining: 9.03s
# 790:	learn: 2369.0977386	total: 1.7s	remaining: 9.03s
# 791:	learn: 2368.4503490	total: 1.7s	remaining: 9.02s
# 792:	learn: 2367.7591998	total: 1.7s	remaining: 9.02s
# 793:	learn: 2367.0145235	total: 1.7s	remaining: 9.02s
# 794:	learn: 2366.2596525	total: 1.71s	remaining: 9.04s
# 795:	learn: 2365.4549445	total: 1.71s	remaining: 9.04s
# 796:	learn: 2364.1053590	total: 1.72s	remaining: 9.05s
# 797:	learn: 2362.9230180	total: 1.72s	remaining: 9.06s
# 798:	learn: 2361.8289861	total: 1.72s	remaining: 9.05s
# 799:	learn: 2360.1149883	total: 1.72s	remaining: 9.05s
# 800:	learn: 2359.1666316	total: 1.73s	remaining: 9.06s
# 801:	learn: 2358.5368782	total: 1.73s	remaining: 9.07s
# 802:	learn: 2357.0860409	total: 1.74s	remaining: 9.07s
# 803:	learn: 2355.7006859	total: 1.74s	remaining: 9.1s
# 804:	learn: 2354.9886064	total: 1.75s	remaining: 9.11s
# 805:	learn: 2353.2373220	total: 1.75s	remaining: 9.11s
# 806:	learn: 2351.8112346	total: 1.75s	remaining: 9.1s
# 807:	learn: 2350.4104405	total: 1.75s	remaining: 9.1s
# 808:	learn: 2348.8182668	total: 1.76s	remaining: 9.1s
# 809:	learn: 2348.2598101	total: 1.76s	remaining: 9.09s
# 810:	learn: 2347.6085453	total: 1.76s	remaining: 9.09s
# 811:	learn: 2346.9133870	total: 1.76s	remaining: 9.09s
# 812:	learn: 2345.4509806	total: 1.76s	remaining: 9.08s
# 813:	learn: 2344.7982623	total: 1.76s	remaining: 9.08s
# 814:	learn: 2343.8517439	total: 1.77s	remaining: 9.08s
# 815:	learn: 2343.2573112	total: 1.77s	remaining: 9.07s
# 816:	learn: 2341.5325733	total: 1.77s	remaining: 9.07s
# 817:	learn: 2340.4912129	total: 1.77s	remaining: 9.07s
# 818:	learn: 2339.1756006	total: 1.77s	remaining: 9.06s
# 819:	learn: 2338.5069586	total: 1.78s	remaining: 9.06s
# 820:	learn: 2337.2611240	total: 1.78s	remaining: 9.06s
# 821:	learn: 2336.3339952	total: 1.78s	remaining: 9.05s
# 822:	learn: 2335.6991539	total: 1.78s	remaining: 9.06s
# 823:	learn: 2335.0774135	total: 1.79s	remaining: 9.06s
# 824:	learn: 2334.2059575	total: 1.79s	remaining: 9.07s
# 825:	learn: 2333.1758794	total: 1.79s	remaining: 9.07s
# 826:	learn: 2332.2156525	total: 1.8s	remaining: 9.06s
# 827:	learn: 2329.9810025	total: 1.8s	remaining: 9.06s
# 828:	learn: 2328.4379236	total: 1.8s	remaining: 9.06s
# 829:	learn: 2328.1142462	total: 1.8s	remaining: 9.05s
# 830:	learn: 2326.7328770	total: 1.8s	remaining: 9.05s
# 831:	learn: 2325.8063126	total: 1.81s	remaining: 9.05s
# 832:	learn: 2325.2484837	total: 1.81s	remaining: 9.05s
# 833:	learn: 2324.2475391	total: 1.81s	remaining: 9.04s
# 834:	learn: 2322.3263426	total: 1.81s	remaining: 9.04s
# 835:	learn: 2321.4146815	total: 1.81s	remaining: 9.04s
# 836:	learn: 2320.5167855	total: 1.82s	remaining: 9.03s
# 837:	learn: 2320.1463609	total: 1.82s	remaining: 9.03s
# 838:	learn: 2318.6271149	total: 1.82s	remaining: 9.03s
# 839:	learn: 2317.7618208	total: 1.82s	remaining: 9.02s
# 840:	learn: 2315.6566186	total: 1.82s	remaining: 9.02s
# 841:	learn: 2315.3086495	total: 1.83s	remaining: 9.02s
# 842:	learn: 2314.5796123	total: 1.83s	remaining: 9.02s
# 843:	learn: 2312.5460278	total: 1.83s	remaining: 9.02s
# 844:	learn: 2311.5137487	total: 1.83s	remaining: 9.01s
# 845:	learn: 2309.8682519	total: 1.83s	remaining: 9.01s
# 846:	learn: 2308.3503766	total: 1.84s	remaining: 9.01s
# 847:	learn: 2307.1245583	total: 1.84s	remaining: 9s
# 848:	learn: 2306.6184180	total: 1.84s	remaining: 9s
# 849:	learn: 2305.4669933	total: 1.84s	remaining: 8.99s
# 850:	learn: 2303.7380352	total: 1.84s	remaining: 8.99s
# 851:	learn: 2303.5482977	total: 1.85s	remaining: 8.99s
# 852:	learn: 2303.2067388	total: 1.85s	remaining: 9s
# 853:	learn: 2301.6784476	total: 1.85s	remaining: 9s
# 854:	learn: 2300.5434198	total: 1.85s	remaining: 8.99s
# 855:	learn: 2298.8828146	total: 1.86s	remaining: 8.99s
# 856:	learn: 2298.1844937	total: 1.86s	remaining: 8.99s
# 857:	learn: 2297.6892124	total: 1.86s	remaining: 8.98s
# 858:	learn: 2297.0098281	total: 1.86s	remaining: 8.98s
# 859:	learn: 2294.5885283	total: 1.86s	remaining: 8.98s
# 860:	learn: 2293.0627955	total: 1.87s	remaining: 8.97s
# 861:	learn: 2292.1866844	total: 1.87s	remaining: 8.97s
# 862:	learn: 2291.4368072	total: 1.87s	remaining: 8.97s
# 863:	learn: 2290.7492502	total: 1.87s	remaining: 8.96s
# 864:	learn: 2289.9552669	total: 1.87s	remaining: 8.96s
# 865:	learn: 2288.8343490	total: 1.88s	remaining: 8.96s
# 866:	learn: 2287.6477162	total: 1.88s	remaining: 8.96s
# 867:	learn: 2286.6572072	total: 1.88s	remaining: 8.95s
# 868:	learn: 2285.6491088	total: 1.89s	remaining: 8.97s
# 869:	learn: 2284.8487471	total: 1.89s	remaining: 8.97s
# 870:	learn: 2284.0635723	total: 1.89s	remaining: 8.97s
# 871:	learn: 2282.8968399	total: 1.9s	remaining: 8.98s
# 872:	learn: 2280.6109020	total: 1.9s	remaining: 8.98s
# 873:	learn: 2279.7884335	total: 1.9s	remaining: 8.98s
# 874:	learn: 2278.0309056	total: 1.9s	remaining: 8.97s
# 875:	learn: 2277.0078131	total: 1.91s	remaining: 8.97s
# 876:	learn: 2276.4099146	total: 1.91s	remaining: 8.97s
# ...
# 4709:	learn: 899.1210706	total: 12.8s	remaining: 789ms
# 4710:	learn: 898.9686805	total: 12.8s	remaining: 787ms
# 4711:	learn: 898.8620578	total: 12.8s	remaining: 784ms
# 4712:	learn: 898.7922594	total: 12.8s	remaining: 781ms
# 4713:	learn: 898.6262772	total: 12.8s	remaining: 778ms
# 4714:	learn: 898.5134054	total: 12.8s	remaining: 776ms
# 4715:	learn: 898.3665928	total: 12.8s	remaining: 773ms
# 4716:	learn: 898.2681161	total: 12.8s	remaining: 770ms
# 4717:	learn: 898.1890368	total: 12.8s	remaining: 767ms
# 4718:	learn: 897.9767603	total: 12.8s	remaining: 764ms
# 4719:	learn: 897.9179005	total: 12.8s	remaining: 762ms
# 4720:	learn: 897.7574575	total: 12.8s	remaining: 759ms
# 4721:	learn: 897.6955286	total: 12.8s	remaining: 756ms
# 4722:	learn: 897.6201013	total: 12.8s	remaining: 753ms
# 4723:	learn: 897.5528222	total: 12.8s	remaining: 751ms
# 4724:	learn: 897.5114399	total: 12.8s	remaining: 748ms
# 4725:	learn: 897.2626781	total: 12.9s	remaining: 745ms
# 4726:	learn: 897.2289895	total: 12.9s	remaining: 742ms
# 4727:	learn: 897.1528583	total: 12.9s	remaining: 740ms
# 4728:	learn: 897.0721949	total: 12.9s	remaining: 737ms
# 4729:	learn: 896.9524917	total: 12.9s	remaining: 734ms
# 4730:	learn: 896.8126839	total: 12.9s	remaining: 731ms
# 4731:	learn: 896.6982088	total: 12.9s	remaining: 729ms
# 4732:	learn: 896.5992528	total: 12.9s	remaining: 726ms
# 4733:	learn: 896.4133224	total: 12.9s	remaining: 723ms
# 4734:	learn: 896.3483353	total: 12.9s	remaining: 720ms
# 4735:	learn: 896.1999620	total: 12.9s	remaining: 718ms
# 4736:	learn: 896.1459632	total: 12.9s	remaining: 715ms
# 4737:	learn: 896.0570098	total: 12.9s	remaining: 712ms
# 4738:	learn: 895.9584106	total: 12.9s	remaining: 709ms
# 4739:	learn: 895.8345558	total: 12.9s	remaining: 707ms
# 4740:	learn: 895.6821097	total: 12.9s	remaining: 704ms
# 4741:	learn: 895.4446100	total: 12.9s	remaining: 701ms
# 4742:	learn: 895.3089443	total: 12.9s	remaining: 698ms
# 4743:	learn: 895.1999516	total: 12.9s	remaining: 696ms
# 4744:	learn: 895.0735669	total: 12.9s	remaining: 693ms
# 4745:	learn: 895.0117243	total: 12.9s	remaining: 690ms
# 4746:	learn: 894.8830035	total: 12.9s	remaining: 687ms
# 4747:	learn: 894.7409756	total: 12.9s	remaining: 685ms
# 4748:	learn: 894.4879237	total: 12.9s	remaining: 682ms
# 4749:	learn: 894.4155948	total: 12.9s	remaining: 679ms
# 4750:	learn: 894.3154531	total: 12.9s	remaining: 676ms
# 4751:	learn: 894.1301506	total: 12.9s	remaining: 674ms
# 4752:	learn: 893.9801735	total: 12.9s	remaining: 671ms
# 4753:	learn: 893.8743239	total: 12.9s	remaining: 668ms
# 4754:	learn: 893.7783889	total: 12.9s	remaining: 665ms
# 4755:	learn: 893.7173636	total: 12.9s	remaining: 663ms
# 4756:	learn: 893.6275019	total: 12.9s	remaining: 660ms
# 4757:	learn: 893.5649730	total: 12.9s	remaining: 657ms
# 4758:	learn: 893.5324491	total: 12.9s	remaining: 654ms
# 4759:	learn: 893.3180033	total: 12.9s	remaining: 652ms
# 4760:	learn: 893.0842239	total: 12.9s	remaining: 649ms
# 4761:	learn: 893.0406508	total: 12.9s	remaining: 646ms
# 4762:	learn: 892.9399345	total: 12.9s	remaining: 643ms
# 4763:	learn: 892.8535164	total: 12.9s	remaining: 641ms
# 4764:	learn: 892.6739858	total: 12.9s	remaining: 638ms
# 4765:	learn: 892.4356494	total: 12.9s	remaining: 635ms
# 4766:	learn: 892.3918507	total: 12.9s	remaining: 632ms
# 4767:	learn: 892.2827281	total: 12.9s	remaining: 630ms
# 4768:	learn: 892.1664855	total: 12.9s	remaining: 627ms
# 4769:	learn: 891.9302076	total: 12.9s	remaining: 624ms
# 4770:	learn: 891.8506029	total: 13s	remaining: 622ms
# 4771:	learn: 891.7283471	total: 13s	remaining: 620ms
# 4772:	learn: 891.5861764	total: 13s	remaining: 617ms
# 4773:	learn: 891.3880472	total: 13s	remaining: 614ms
# 4774:	learn: 891.3013105	total: 13s	remaining: 612ms
# 4775:	learn: 891.0227659	total: 13s	remaining: 609ms
# 4776:	learn: 890.8463627	total: 13s	remaining: 606ms
# 4777:	learn: 890.7919723	total: 13s	remaining: 603ms
# 4778:	learn: 890.6339352	total: 13s	remaining: 601ms
# 4779:	learn: 890.5042741	total: 13s	remaining: 598ms
# 4780:	learn: 890.3835352	total: 13s	remaining: 595ms
# 4781:	learn: 890.2971267	total: 13s	remaining: 592ms
# 4782:	learn: 890.2419510	total: 13s	remaining: 590ms
# 4783:	learn: 890.1919147	total: 13s	remaining: 587ms
# 4784:	learn: 890.0771595	total: 13s	remaining: 584ms
# 4785:	learn: 889.8502891	total: 13s	remaining: 581ms
# 4786:	learn: 889.6538001	total: 13s	remaining: 579ms
# 4787:	learn: 889.5546203	total: 13s	remaining: 576ms
# 4788:	learn: 889.4324416	total: 13s	remaining: 573ms
# 4789:	learn: 889.1777851	total: 13s	remaining: 570ms
# 4790:	learn: 889.1260204	total: 13s	remaining: 568ms
# 4791:	learn: 889.0639886	total: 13s	remaining: 565ms
# 4792:	learn: 888.9746786	total: 13s	remaining: 562ms
# 4793:	learn: 888.8716632	total: 13s	remaining: 559ms
# 4794:	learn: 888.7784429	total: 13s	remaining: 557ms
# 4795:	learn: 888.6617645	total: 13s	remaining: 554ms
# 4796:	learn: 888.5817429	total: 13s	remaining: 551ms
# 4797:	learn: 888.5180425	total: 13s	remaining: 548ms
# 4798:	learn: 888.4085863	total: 13s	remaining: 546ms
# 4799:	learn: 888.2912769	total: 13s	remaining: 543ms
# 4800:	learn: 888.2225181	total: 13s	remaining: 540ms
# 4801:	learn: 888.1072467	total: 13s	remaining: 537ms
# 4802:	learn: 887.8737643	total: 13s	remaining: 535ms
# 4803:	learn: 887.7486631	total: 13s	remaining: 532ms
# 4804:	learn: 887.6268291	total: 13s	remaining: 529ms
# 4805:	learn: 887.3836850	total: 13s	remaining: 526ms
# 4806:	learn: 887.3089323	total: 13s	remaining: 524ms
# 4807:	learn: 887.1584765	total: 13s	remaining: 521ms
# 4808:	learn: 886.9308919	total: 13s	remaining: 518ms
# 4809:	learn: 886.8361797	total: 13s	remaining: 515ms
# 4810:	learn: 886.8100643	total: 13.1s	remaining: 513ms
# 4811:	learn: 886.7383276	total: 13.1s	remaining: 510ms
# 4812:	learn: 886.6543266	total: 13.1s	remaining: 507ms
# 4813:	learn: 886.3395967	total: 13.1s	remaining: 504ms
# 4814:	learn: 886.2727600	total: 13.1s	remaining: 502ms
# 4815:	learn: 886.1413463	total: 13.1s	remaining: 499ms
# 4816:	learn: 885.9861747	total: 13.1s	remaining: 496ms
# 4817:	learn: 885.8277490	total: 13.1s	remaining: 493ms
# 4818:	learn: 885.5182149	total: 13.1s	remaining: 491ms
# 4819:	learn: 885.3921105	total: 13.1s	remaining: 488ms
# 4820:	learn: 885.3044546	total: 13.1s	remaining: 485ms
# 4821:	learn: 885.2128296	total: 13.1s	remaining: 483ms
# 4822:	learn: 885.1666069	total: 13.1s	remaining: 480ms
# 4823:	learn: 885.0687830	total: 13.1s	remaining: 477ms
# 4824:	learn: 884.8633340	total: 13.1s	remaining: 475ms
# 4825:	learn: 884.6396924	total: 13.1s	remaining: 472ms
# 4826:	learn: 884.5463753	total: 13.1s	remaining: 469ms
# 4827:	learn: 884.4606469	total: 13.1s	remaining: 466ms
# 4828:	learn: 884.3276644	total: 13.1s	remaining: 464ms
# 4829:	learn: 884.2592084	total: 13.1s	remaining: 461ms
# 4830:	learn: 884.1201343	total: 13.1s	remaining: 458ms
# 4831:	learn: 883.9544190	total: 13.1s	remaining: 455ms
# 4832:	learn: 883.7301407	total: 13.1s	remaining: 453ms
# 4833:	learn: 883.6558425	total: 13.1s	remaining: 450ms
# 4834:	learn: 883.6054267	total: 13.1s	remaining: 447ms
# 4835:	learn: 883.4323400	total: 13.1s	remaining: 444ms
# 4836:	learn: 883.3054786	total: 13.1s	remaining: 442ms
# 4837:	learn: 883.1684527	total: 13.1s	remaining: 439ms
# 4838:	learn: 883.0813954	total: 13.1s	remaining: 436ms
# 4839:	learn: 882.9644656	total: 13.1s	remaining: 433ms
# 4840:	learn: 882.6624009	total: 13.1s	remaining: 431ms
# 4841:	learn: 882.5734623	total: 13.1s	remaining: 428ms
# 4842:	learn: 882.4691501	total: 13.1s	remaining: 425ms
# 4843:	learn: 882.3409493	total: 13.1s	remaining: 423ms
# 4844:	learn: 882.2845306	total: 13.1s	remaining: 420ms
# 4845:	learn: 882.1278627	total: 13.1s	remaining: 417ms
# 4846:	learn: 881.9346408	total: 13.1s	remaining: 414ms
# 4847:	learn: 881.8241784	total: 13.1s	remaining: 412ms
# 4848:	learn: 881.5642361	total: 13.1s	remaining: 409ms
# 4849:	learn: 881.4107967	total: 13.1s	remaining: 406ms
# 4850:	learn: 881.3045267	total: 13.1s	remaining: 404ms
# 4851:	learn: 881.1932500	total: 13.1s	remaining: 401ms
# 4852:	learn: 880.9847803	total: 13.1s	remaining: 398ms
# 4853:	learn: 880.9188636	total: 13.1s	remaining: 395ms
# 4854:	learn: 880.8008296	total: 13.1s	remaining: 393ms
# 4855:	learn: 880.6817046	total: 13.1s	remaining: 390ms
# 4856:	learn: 880.6463881	total: 13.2s	remaining: 387ms
# 4857:	learn: 880.4827687	total: 13.2s	remaining: 385ms
# 4858:	learn: 880.3369747	total: 13.2s	remaining: 382ms
# 4859:	learn: 880.2005689	total: 13.2s	remaining: 379ms
# 4860:	learn: 880.0247347	total: 13.2s	remaining: 376ms
# 4861:	learn: 879.9268340	total: 13.2s	remaining: 374ms
# 4862:	learn: 879.8013579	total: 13.2s	remaining: 371ms
# 4863:	learn: 879.6889969	total: 13.2s	remaining: 368ms
# 4864:	learn: 879.6157120	total: 13.2s	remaining: 366ms
# 4865:	learn: 879.5092817	total: 13.2s	remaining: 363ms
# 4866:	learn: 879.3625122	total: 13.2s	remaining: 360ms
# 4867:	learn: 879.2198258	total: 13.2s	remaining: 357ms
# 4868:	learn: 879.1773901	total: 13.2s	remaining: 355ms
# 4869:	learn: 878.9753079	total: 13.2s	remaining: 352ms
# 4870:	learn: 878.8485103	total: 13.2s	remaining: 349ms
# 4871:	learn: 878.7771525	total: 13.2s	remaining: 346ms
# 4872:	learn: 878.6482785	total: 13.2s	remaining: 344ms
# 4873:	learn: 878.6160089	total: 13.2s	remaining: 341ms
# 4874:	learn: 878.5472132	total: 13.2s	remaining: 338ms
# 4875:	learn: 878.5271215	total: 13.2s	remaining: 336ms
# 4876:	learn: 878.4677889	total: 13.2s	remaining: 333ms
# 4877:	learn: 878.3722945	total: 13.2s	remaining: 330ms
# 4878:	learn: 878.2995692	total: 13.2s	remaining: 327ms
# 4879:	learn: 878.2154797	total: 13.2s	remaining: 325ms
# 4880:	learn: 878.0925647	total: 13.2s	remaining: 322ms
# 4881:	learn: 877.9910949	total: 13.2s	remaining: 319ms
# 4882:	learn: 877.8823273	total: 13.2s	remaining: 317ms
# 4883:	learn: 877.6881170	total: 13.2s	remaining: 314ms
# 4884:	learn: 877.6014728	total: 13.2s	remaining: 311ms
# 4885:	learn: 877.3965058	total: 13.2s	remaining: 308ms
# 4886:	learn: 877.3083769	total: 13.2s	remaining: 306ms
# 4887:	learn: 877.2295070	total: 13.2s	remaining: 303ms
# 4888:	learn: 877.0977411	total: 13.2s	remaining: 300ms
# 4889:	learn: 877.0328436	total: 13.2s	remaining: 297ms
# 4890:	learn: 876.8900269	total: 13.2s	remaining: 295ms
# 4891:	learn: 876.8172199	total: 13.2s	remaining: 292ms
# 4892:	learn: 876.6020160	total: 13.2s	remaining: 289ms
# 4893:	learn: 876.5596316	total: 13.2s	remaining: 287ms
# 4894:	learn: 876.4466038	total: 13.2s	remaining: 284ms
# 4895:	learn: 876.3432984	total: 13.2s	remaining: 281ms
# 4896:	learn: 876.3165873	total: 13.2s	remaining: 278ms
# 4897:	learn: 876.1987272	total: 13.2s	remaining: 276ms
# 4898:	learn: 875.9634431	total: 13.2s	remaining: 273ms
# 4899:	learn: 875.9198034	total: 13.2s	remaining: 270ms
# 4900:	learn: 875.7928884	total: 13.2s	remaining: 268ms
# 4901:	learn: 875.6171496	total: 13.2s	remaining: 265ms
# 4902:	learn: 875.3517582	total: 13.3s	remaining: 262ms
# 4903:	learn: 875.2639625	total: 13.3s	remaining: 259ms
# 4904:	learn: 874.9844602	total: 13.3s	remaining: 257ms
# 4905:	learn: 874.9214858	total: 13.3s	remaining: 254ms
# 4906:	learn: 874.8477978	total: 13.3s	remaining: 251ms
# 4907:	learn: 874.7211167	total: 13.3s	remaining: 249ms
# 4908:	learn: 874.6600236	total: 13.3s	remaining: 246ms
# 4909:	learn: 874.4762244	total: 13.3s	remaining: 243ms
# 4910:	learn: 874.2710863	total: 13.3s	remaining: 240ms
# 4911:	learn: 874.1314103	total: 13.3s	remaining: 238ms
# 4912:	learn: 874.0439814	total: 13.3s	remaining: 235ms
# 4913:	learn: 873.9712077	total: 13.3s	remaining: 232ms
# 4914:	learn: 873.8781036	total: 13.3s	remaining: 230ms
# 4915:	learn: 873.7164813	total: 13.3s	remaining: 227ms
# 4916:	learn: 873.5694209	total: 13.3s	remaining: 224ms
# 4917:	learn: 873.4973367	total: 13.3s	remaining: 221ms
# 4918:	learn: 873.2926736	total: 13.3s	remaining: 219ms
# 4919:	learn: 873.2331394	total: 13.3s	remaining: 216ms
# 4920:	learn: 873.1246263	total: 13.3s	remaining: 213ms
# 4921:	learn: 873.0381840	total: 13.3s	remaining: 211ms
# 4922:	learn: 872.8758953	total: 13.3s	remaining: 208ms
# 4923:	learn: 872.8035055	total: 13.3s	remaining: 205ms
# 4924:	learn: 872.6440115	total: 13.3s	remaining: 202ms
# 4925:	learn: 872.5538008	total: 13.3s	remaining: 200ms
# 4926:	learn: 872.3678746	total: 13.3s	remaining: 197ms
# 4927:	learn: 872.2843720	total: 13.3s	remaining: 194ms
# 4928:	learn: 872.2582864	total: 13.3s	remaining: 192ms
# 4929:	learn: 872.1725301	total: 13.3s	remaining: 189ms
# 4930:	learn: 872.0867388	total: 13.3s	remaining: 186ms
# 4931:	learn: 871.9112117	total: 13.3s	remaining: 184ms
# 4932:	learn: 871.7907060	total: 13.3s	remaining: 181ms
# 4933:	learn: 871.6900618	total: 13.3s	remaining: 178ms
# 4934:	learn: 871.6161277	total: 13.3s	remaining: 175ms
# 4935:	learn: 871.4666759	total: 13.3s	remaining: 173ms
# 4936:	learn: 871.3435929	total: 13.3s	remaining: 170ms
# 4937:	learn: 871.2608464	total: 13.3s	remaining: 167ms
# 4938:	learn: 871.0537548	total: 13.3s	remaining: 165ms
# 4939:	learn: 870.8452350	total: 13.3s	remaining: 162ms
# 4940:	learn: 870.7611837	total: 13.3s	remaining: 159ms
# 4941:	learn: 870.6684952	total: 13.3s	remaining: 156ms
# 4942:	learn: 870.6139296	total: 13.3s	remaining: 154ms
# 4943:	learn: 870.4958758	total: 13.3s	remaining: 151ms
# 4944:	learn: 870.2318435	total: 13.3s	remaining: 148ms
# 4945:	learn: 870.1594710	total: 13.3s	remaining: 146ms
# 4946:	learn: 870.1248821	total: 13.3s	remaining: 143ms
# 4947:	learn: 870.0679780	total: 13.4s	remaining: 140ms
# 4948:	learn: 869.8891731	total: 13.4s	remaining: 138ms
# 4949:	learn: 869.8274107	total: 13.4s	remaining: 135ms
# 4950:	learn: 869.7124805	total: 13.4s	remaining: 132ms
# 4951:	learn: 869.5930808	total: 13.4s	remaining: 130ms
# 4952:	learn: 869.3301905	total: 13.4s	remaining: 127ms
# 4953:	learn: 869.0232774	total: 13.4s	remaining: 124ms
# 4954:	learn: 868.7845702	total: 13.4s	remaining: 121ms
# 4955:	learn: 868.5708138	total: 13.4s	remaining: 119ms
# 4956:	learn: 868.5491311	total: 13.4s	remaining: 116ms
# 4957:	learn: 868.2810790	total: 13.4s	remaining: 113ms
# 4958:	learn: 868.1480169	total: 13.4s	remaining: 111ms
# 4959:	learn: 867.9782560	total: 13.4s	remaining: 108ms
# 4960:	learn: 867.9135590	total: 13.4s	remaining: 105ms
# 4961:	learn: 867.7880911	total: 13.4s	remaining: 103ms
# 4962:	learn: 867.6500692	total: 13.4s	remaining: 99.8ms
# 4963:	learn: 867.5028899	total: 13.4s	remaining: 97.1ms
# 4964:	learn: 867.3769923	total: 13.4s	remaining: 94.4ms
# 4965:	learn: 867.2714042	total: 13.4s	remaining: 91.7ms
# 4966:	learn: 867.1032389	total: 13.4s	remaining: 89ms
# 4967:	learn: 866.9998333	total: 13.4s	remaining: 86.3ms
# 4968:	learn: 866.7872316	total: 13.4s	remaining: 83.6ms
# 4969:	learn: 866.6699042	total: 13.4s	remaining: 80.9ms
# 4970:	learn: 866.5660563	total: 13.4s	remaining: 78.2ms
# 4971:	learn: 866.5173089	total: 13.4s	remaining: 75.5ms
# 4972:	learn: 866.4523039	total: 13.4s	remaining: 72.8ms
# 4973:	learn: 866.2505813	total: 13.4s	remaining: 70.1ms
# 4974:	learn: 866.1500414	total: 13.4s	remaining: 67.4ms
# 4975:	learn: 866.0627192	total: 13.4s	remaining: 64.7ms
# 4976:	learn: 865.9812753	total: 13.4s	remaining: 62ms
# 4977:	learn: 865.8781897	total: 13.4s	remaining: 59.3ms
# 4978:	learn: 865.7543614	total: 13.4s	remaining: 56.6ms
# 4979:	learn: 865.6795408	total: 13.4s	remaining: 53.9ms
# 4980:	learn: 865.5731618	total: 13.4s	remaining: 51.2ms
# 4981:	learn: 865.4943489	total: 13.4s	remaining: 48.5ms
# 4982:	learn: 865.4506342	total: 13.4s	remaining: 45.8ms
# 4983:	learn: 865.1707716	total: 13.4s	remaining: 43.1ms
# 4984:	learn: 865.0583668	total: 13.4s	remaining: 40.4ms
# 4985:	learn: 864.9593977	total: 13.4s	remaining: 37.7ms
# 4986:	learn: 864.8705696	total: 13.4s	remaining: 35ms
# 4987:	learn: 864.7121928	total: 13.4s	remaining: 32.3ms
# 4988:	learn: 864.3716854	total: 13.4s	remaining: 29.6ms
# 4989:	learn: 864.2662667	total: 13.4s	remaining: 26.9ms
# 4990:	learn: 864.1179872	total: 13.4s	remaining: 24.3ms
# 4991:	learn: 864.0004243	total: 13.4s	remaining: 21.6ms
# 4992:	learn: 863.9459363	total: 13.5s	remaining: 18.9ms
# 4993:	learn: 863.8578660	total: 13.5s	remaining: 16.2ms
# 4994:	learn: 863.7737664	total: 13.5s	remaining: 13.5ms
# 4995:	learn: 863.5386312	total: 13.5s	remaining: 10.8ms
# 4996:	learn: 863.3675201	total: 13.5s	remaining: 8.08ms
# 4997:	learn: 863.2763527	total: 13.5s	remaining: 5.39ms
# 4998:	learn: 863.1701099	total: 13.5s	remaining: 2.69ms
# 4999:	learn: 863.0933146	total: 13.5s	remaining: 0us

# %%
y_train_pred = best_model_with_fs.predict(X_train_fs)
y_test_pred = best_model_with_fs.predict(X_test_fs)

mae_train = mean_absolute_error(y_train, y_train_pred)
mae_test = mean_absolute_error(y_test, y_test_pred)

print('Best model with FS train:', mae_train)
print('Best model with FS test:', mae_test)
# Out:
# Best model with FS train: 618.6473043346813
# Best model with FS test: 2348.531405889027

# %% [markdown]
# ## Avalie o melhor modelo na base de produção

# %% [markdown]
# Para o melhor modelo, avali-o na base de produção.
#
# Lembre-se de avaliar os pipelines criados anteriormente. Todas as variáveis existentes durante o processo de treinamento, devem ser criadas/utilizadas na predição do modelo.

# %%
df_prod = pd.read_csv('/content/drive/MyDrive/datasets/car_price_prod.csv')
df_prod.shape
# Out:
# (992, 11)

# %%
df_prod
# Out:
#      carID   brand       model  year transmission  mileage fuelType      tax  \
# 0    13209    ford        Edge  2017    Automatic    30255   Diesel 165.0000
# 1    15965     bmw          X4  2015    Automatic    95408   Diesel 145.0000
# 2    14659     bmw    6 Series  2016    Automatic    32449   Diesel 160.0000
# 3    12756    merc     S Class  2012    Automatic    72700   Diesel 235.0000
# 4    13289    merc     V Class  2018    Automatic    15232   Diesel 145.0000
# ..     ...     ...         ...   ...          ...      ...      ...      ...
# 987  17108    merc     X-CLASS  2018    Automatic     9500   Diesel 260.0000
# 988  14859    merc   CLS Class  2017    Semi-Auto    27354   Diesel 160.0000
# 989  12676     bmw          X6  2016    Semi-Auto    31585   Diesel 200.0000
# 990  16387  toyota       Verso  2017    Semi-Auto    16084   Petrol 160.0000
# 991  13362      vw    Scirocco  2017    Automatic    16614   Petrol 145.0000
#
#         mpg  engineSize  target
# 0   48.7000      2.0000   20500
# 1   54.3000      2.0000   15199
# 2   51.4000      3.0000   18450
# 3   41.5000      3.0000   12995
# 4   48.7000      2.1000   19750
# ..      ...         ...     ...
# 987 31.4000      3.0000   36790
# 988 49.6000      3.0000   23998
# 989 47.1000      3.0000   28950
# 990 43.5000      1.8000   15498
# 991 44.1000      2.0000   14999
#
# [992 rows x 11 columns]

# %%
X_prod = df_prod[features]
y_prod = df_prod[target]

# %%
y_prod_pred = best_model.predict(X_prod)
mae_prod = mean_absolute_error(y_prod, y_prod_pred)
mape_prod = mean_absolute_percentage_error(y_prod, y_prod_pred)

print('Best model MAE prod:', mae_train)
print('Best model MAPE prod:', mape_prod)
# Out:
# Best model MAE prod: 618.6473043346813
# Best model MAPE prod: 0.0708727288772974

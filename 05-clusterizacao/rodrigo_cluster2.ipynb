# %%
# !pip install ydata_profiling
# Out:
# Collecting ydata_profiling
#   Downloading ydata_profiling-4.16.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting scipy<1.16,>=1.4.1 (from ydata_profiling)
#   Downloading scipy-1.15.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 914.8 kB/s eta 0:00:00
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in /usr/local/lib/python3.11/dist-packages (from ydata_profiling) (2.2.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /usr/local/lib/python3.11/dist-packages (from ydata_profiling) (3.10.0)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.11/dist-packages (from ydata_profiling) (2.11.7)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from ydata_profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /usr/local/lib/python3.11/dist-packages (from ydata_profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from ydata_profiling) (2.0.2)
# Collecting htmlmin==0.1.12 (from ydata_profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting phik<0.13,>=0.11.1 (from ydata_profiling)
#   Downloading phik-0.12.5-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in /usr/local/lib/python3.11/dist-packages (from ydata_profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /usr/local/lib/python3.11/dist-packages (from ydata_profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from ydata_profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata_profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from ydata_profiling) (0.14.5)
# Requirement already satisfied: typeguard<5,>=3 in /usr/local/lib/python3.11/dist-packages (from ydata_profiling) (4.4.4)
# Collecting imagehash==4.3.1 (from ydata_profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: wordcloud>=1.9.3 in /usr/local/lib/python3.11/dist-packages (from ydata_profiling) (1.9.4)
# Collecting dacite>=1.8 (from ydata_profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in /usr/local/lib/python3.11/dist-packages (from ydata_profiling) (0.60.0)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.11/dist-packages (from imagehash==4.3.1->ydata_profiling) (1.8.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from imagehash==4.3.1->ydata_profiling) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<3.2,>=2.11.1->ydata_profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba<=0.61,>=0.56.0->ydata_profiling) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas!=1.4.0,<3.0,>1.1->ydata_profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas!=1.4.0,<3.0,>1.1->ydata_profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.11/dist-packages (from phik<0.13,>=0.11.1->ydata_profiling) (1.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata_profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata_profiling) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata_profiling) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata_profiling) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata_profiling) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata_profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata_profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata_profiling) (2025.7.14)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels<1,>=0.13.2->ydata_profiling) (1.0.1)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.11/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.11/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (3.5)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling)
#   Downloading puremagic-1.30-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata_profiling) (1.17.0)
# Downloading ydata_profiling-4.16.1-py2.py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 7.5 MB/s eta 0:00:00
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 7.0 MB/s eta 0:00:00
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.5-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (679 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.0/679.0 kB 20.1 MB/s eta 0:00:00
# Downloading scipy-1.15.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 22.6 MB/s eta 0:00:00
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 3.3 MB/s eta 0:00:00
# Downloading puremagic-1.30-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.7 MB/s eta 0:00:00
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=73dab09e217a55871346324b5658c1a4c46e0e95e4a687773ef3f0b98a80f5cb
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# Installing collected packages: puremagic, htmlmin, scipy, multimethod, dacite, imagehash, visions, phik, ydata_profiling
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.1
#     Uninstalling scipy-1.16.1:
#       Successfully uninstalled scipy-1.16.1
# Successfully installed dacite-1.9.2 htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.12 phik-0.12.5 puremagic-1.30 scipy-1.15.3 visions-0.8.1 ydata_profiling-4.16.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from scipy import stats
from yellowbrick.cluster import KElbowVisualizer
from ydata_profiling import ProfileReport
import math
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
# Conectar ao Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/FIA Analytics/Trabalho final/shopping_trends.csv")
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#   Payment Method  Shipping Type Discount Applied Promo Code Used  \
# 0    Credit Card        Express              Yes             Yes
# 1  Bank Transfer        Express              Yes             Yes
# 2           Cash  Free Shipping              Yes             Yes
# 3         PayPal   Next Day Air              Yes             Yes
# 4           Cash  Free Shipping              Yes             Yes
#
#    Previous Purchases Preferred Payment Method Frequency of Purchases
# 0                  14                    Venmo            Fortnightly
# 1                   2                     Cash            Fortnightly
# 2                  23              Credit Card                 Weekly
# 3                  49                   PayPal                 Weekly
# 4                  31                   PayPal               Annually

# %%
# Informações básicas sobre os tipos de dados
print(f"Dataset shape: {df.shape}")
print("\nTipos de dados:")
print(df.dtypes)
# Out:
# Dataset shape: (3900, 19)
#
# Tipos de dados:
# Customer ID                   int64
# Age                           int64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)         int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %%
df.describe().round(2)
# Out:
#        Customer ID      Age  Purchase Amount (USD)  Review Rating  \
# count      3900.00  3900.00                3900.00        3900.00
# mean       1950.50    44.07                  59.76           3.75
# std        1125.98    15.21                  23.69           0.72
# min           1.00    18.00                  20.00           2.50
# 25%         975.75    31.00                  39.00           3.10
# 50%        1950.50    44.00                  60.00           3.70
# 75%        2925.25    57.00                  81.00           4.40
# max        3900.00    70.00                 100.00           5.00
#
#        Previous Purchases
# count             3900.00
# mean                25.35
# std                 14.45
# min                  1.00
# 25%                 13.00
# 50%                 25.00
# 75%                 38.00
# max                 50.00

# %%
profile = ProfileReport(df, title="Consumer info")
profile
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Identificação das features categoricas
categorical_features = [
    'Gender',
    'Category',
    'Location',
    'Season',
    'Subscription Status',
    'Shipping Type',
    'Discount Applied',
    'Promo Code Used',
    'Payment Method',
    'Frequency of Purchases'
]

# %%
# Identificação das features numericas
numerical_features = [
    'Age',
    'Purchase Amount (USD)',
    'Review Rating',
    'Previous Purchases'
]

# %%
# Especificação da coluna Customer ID
customer_id_col = 'Customer ID'

# %%
# Verificação dos recursos numéricos/categóricos identificados realmente existem no DataFrame
actual_numerical_features_eda = [col for col in numerical_features if col in df.columns]
actual_categorical_features_eda = [col for col in categorical_features if col in df.columns]

# %%
#Resposta explicativa quantitativa vs. resposta qualitativa
# Crie uma função para boxplots
def boxplot_by_category(df, num_var, cat_var, figsize=(10, 6)):
    plt.figure(figsize=figsize)
    sns.boxplot(x=cat_var, y=num_var, data=df)
    plt.title(f'{num_var} by {cat_var}')
    plt.xticks(rotation=45)
    plt.tight_layout()

# estatísticas descritivas por grupo
    stats_by_group = df.groupby(cat_var)[num_var].agg(['mean', 'median', 'std', 'min', 'max'])
    print(f"Statistics of {num_var} by {cat_var}:")
    print(stats_by_group.round(2))

    return stats_by_group

# %%
# Histograms & boxplots
for col in ["Age", "Purchase Amount (USD)"]:
    plt.figure()
    plt.hist(df[col].dropna(), bins=30)
    plt.title(f"Histogram of {col}")
    plt.xlabel(col); plt.ylabel("Frequency"); plt.show()

    sns.boxplot(x=df[col])
    plt.title(f'Boxplot de {col}')
    plt.tight_layout()
    plt.show()

# %%
# valor de compra por categoria
purchase_by_category = boxplot_by_category(df, 'Purchase Amount (USD)', 'Category')
# Out:
# Statistics of Purchase Amount (USD) by Category:
#               mean  median    std  min  max
# Category
# Accessories  59.84    60.0  23.30   20  100
# Clothing     60.03    60.0  23.79   20  100
# Footwear     60.26    60.0  23.64   20  100
# Outerwear    57.17    54.5  24.59   20  100

# %%
# Count Plots (Bar Charts) for Categorical Features
if actual_categorical_features_eda:
    num_plots = len(actual_categorical_features_eda)
    if num_plots > 0:
        # Determine layout dynamically - aim for max 3 columns
        num_cols = min(3, num_plots)
        num_rows = math.ceil(num_plots / num_cols)
        plt.figure(figsize=(6 * num_cols, 4 * num_rows)) # ajuste o tamanho com base na grade
        for i, col in enumerate(actual_categorical_features_eda):
            plt.subplot(num_rows, num_cols, i + 1)
            # Use seaborn's countplot
            order = df[col].value_counts().index[:15] # Limite às 15 principais categorias para facilitar a leitura
            sns.countplot(data=df, y=col, order=order, palette='viridis') # Use y=col para barras horizontais se houver muitas categorias
            plt.title(f'Distribution of {col}')
            plt.xlabel('Count')
            plt.ylabel(col) # Rótulo correto para o eixo y
            if len(order) < df[col].nunique():
                 plt.title(f'Distribution of {col} (Top 15)') # Atualizar

        plt.tight_layout()
        plt.suptitle('Count Plots of Categorical Features', y=1.02, size=16)
        plt.show()
        print("Displayed count plots for categorical features.")
    else:
        print("No categorical features to plot count plots for.")
# Out:
# /tmp/ipython-input-1466726164.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y=col, order=order, palette='viridis') # Use y=col para barras horizontais se houver muitas categorias
# /tmp/ipython-input-1466726164.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y=col, order=order, palette='viridis') # Use y=col para barras horizontais se houver muitas categorias
# /tmp/ipython-input-1466726164.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y=col, order=order, palette='viridis') # Use y=col para barras horizontais se houver muitas categorias
# /tmp/ipython-input-1466726164.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y=col, order=order, palette='viridis') # Use y=col para barras horizontais se houver muitas categorias
# /tmp/ipython-input-1466726164.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y=col, order=order, palette='viridis') # Use y=col para barras horizontais se houver muitas categorias
# /tmp/ipython-input-1466726164.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y=col, order=order, palette='viridis') # Use y=col para barras horizontais se houver muitas categorias
# /tmp/ipython-input-1466726164.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y=col, order=order, palette='viridis') # Use y=col para barras horizontais se houver muitas categorias
# /tmp/ipython-input-1466726164.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y=col, order=order, palette='viridis') # Use y=col para barras horizontais se houver muitas categorias
# /tmp/ipython-input-1466726164.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y=col, order=order, palette='viridis') # Use y=col para barras horizontais se houver muitas categorias
# /tmp/ipython-input-1466726164.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y=col, order=order, palette='viridis') # Use y=col para barras horizontais se houver muitas categorias
# Displayed count plots for categorical features.

# %%
 #Atributos Qualitativos vs. Atributos Qualitativos -> Tabelas de Frequência (Crosstabs)
# Exemplo: 'Gender' vs 'Frequency of Purchases'
if 'Gender' in df.columns and 'Frequency of Purchases' in df.columns:
    print("\nTabela de Frequência: Gender vs Frequency of Purchases")
    cross_tab_gf = pd.crosstab(df['Gender'], df['Frequency of Purchases'])
    print("Contagens Absolutas:")
    print(cross_tab_gf)
    print("\nPercentuais (por Linha - Gênero):")
    print(cross_tab_gf.apply(lambda r: r/r.sum()*100, axis=1).round(1))

    # Visualização da tabela de frequência
    cross_tab_gf.plot(kind='bar', stacked=False, figsize=(10,6))
    plt.title('Gender vs Frequency of Purchases')
    plt.ylabel('Contagem')
    plt.xticks(rotation=0)
    plt.show()
else:
    print("Não foi possível gerar tabela de frequência para 'Gender' vs 'Frequency of Purchases'.")
# Out:
# Tabela de Frequência: Gender vs Frequency of Purchases
# Contagens Absolutas:
# Frequency of Purchases  Annually  Bi-Weekly  Every 3 Months  Fortnightly  \
# Gender
# Female                       185        188             186          163
# Male                         387        359             398          379
#
# Frequency of Purchases  Monthly  Quarterly  Weekly
# Gender
# Female                      185        169     172
# Male                        368        394     367
#
# Percentuais (por Linha - Gênero):
# Frequency of Purchases  Annually  Bi-Weekly  Every 3 Months  Fortnightly  \
# Gender
# Female                      14.8       15.1            14.9         13.1
# Male                        14.6       13.5            15.0         14.3
#
# Frequency of Purchases  Monthly  Quarterly  Weekly
# Gender
# Female                     14.8       13.5    13.8
# Male                       13.9       14.9    13.8

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

# A. Atributos Qualitativos vs. 'Purchase Amount (USD)' (Quantitativa) -> Boxplots
# Selecionar atributos qualitativos chave (ajustado: trocado 'Location' por 'Discount Applied')
qual_features_for_bivariate = ['Gender', 'Category', 'Promo Code Used', 'Frequency of Purchases', 'Discount Applied']
# Filtrar para garantir que os atributos existem no DataFrame
qual_features_for_bivariate = [col for col in qual_features_for_bivariate if col in df.columns]

if 'Purchase Amount (USD)' in df.columns and qual_features_for_bivariate:
    print("\nGerando Boxplots: Atributos Qualitativos vs. Purchase Amount (USD)")
    num_plots = len(qual_features_for_bivariate)
    num_cols_viz = min(2, num_plots)
    num_rows_viz = math.ceil(num_plots / num_cols_viz)
    plt.figure(figsize=(8 * num_cols_viz, 6 * num_rows_viz))

    for i, col in enumerate(qual_features_for_bivariate):
        plt.subplot(num_rows_viz, num_cols_viz, i + 1)
        sns.boxplot(x=df[col], y=df['Purchase Amount (USD)'])
        plt.title(f'Purchase Amount (USD) vs {col}')
        if df[col].nunique() > 5:
            plt.xticks(rotation=45, ha='right')

    plt.tight_layout()
    plt.suptitle('Boxplots: Atributos Qualitativos vs. Valor da Compra (USD)', y=1.02, fontsize=16)
    plt.show()
else:
    print("Não foi possível gerar boxplots: 'Purchase Amount (USD)' ou atributos qualitativos chave não encontrados.")
# Out:
# Gerando Boxplots: Atributos Qualitativos vs. Purchase Amount (USD)

# %% [markdown]
# Início - Cluster

# %%
# !pip install feature-engine
# Out:
# Collecting feature-engine
#   Downloading feature_engine-1.8.3-py2.py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.11/dist-packages (from feature-engine) (2.0.2)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from feature-engine) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from feature-engine) (1.6.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from feature-engine) (1.15.3)
# Requirement already satisfied: statsmodels>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from feature-engine) (0.14.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.0->feature-engine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.0->feature-engine) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.0->feature-engine) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.0->feature-engine) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.0->feature-engine) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.11.1->feature-engine) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.11.1->feature-engine) (25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->feature-engine) (1.17.0)
# Downloading feature_engine-1.8.3-py2.py3-none-any.whl (378 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.6/378.6 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: feature-engine
# Successfully installed feature-engine-1.8.3

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#   Payment Method  Shipping Type Discount Applied Promo Code Used  \
# 0    Credit Card        Express              Yes             Yes
# 1  Bank Transfer        Express              Yes             Yes
# 2           Cash  Free Shipping              Yes             Yes
# 3         PayPal   Next Day Air              Yes             Yes
# 4           Cash  Free Shipping              Yes             Yes
#
#    Previous Purchases Preferred Payment Method Frequency of Purchases
# 0                  14                    Venmo            Fortnightly
# 1                   2                     Cash            Fortnightly
# 2                  23              Credit Card                 Weekly
# 3                  49                   PayPal                 Weekly
# 4                  31                   PayPal               Annually

# %% [markdown]
# **Objetivo do Projeto**
#
# Desenvolver um modelo de clusterização de clientes para identificar grupos com comportamentos e perfis semelhantes, a fim de direcionar campanhas de marketing personalizadas.

# %% [markdown]
# Modelagem para o cluster

# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from feature_engine.encoding import OneHotEncoder

# %%
df= df.filter(['Customer ID','Age','Purchase Amount (USD)','Category',"Item Purchased",'Season','Promo Code Used','Discount Applied','Preferred Payment Method'])
df.head(3)
# Out:
#    Customer ID  Age  Purchase Amount (USD)  Category Item Purchased  Season  \
# 0            1   55                     53  Clothing         Blouse  Winter
# 1            2   19                     64  Clothing        Sweater  Winter
# 2            3   50                     73  Clothing          Jeans  Spring
#
#   Promo Code Used Discount Applied Preferred Payment Method
# 0             Yes              Yes                    Venmo
# 1             Yes              Yes                     Cash
# 2             Yes              Yes              Credit Card

# %% [markdown]
# Modelagem perfil de compra

# %%
bins = [0, 12, 17, 20, 24, 29, 34, 39, 44, 49, 54, 64, float('inf')]
labels = [
    'Infantil', 'Adolescente', 'Jovem menor de idade',
    'Jovem universitário', 'Jovem profissional', 'Adulto inicial',
    'Adulto médio', 'Adulto avançado', 'Meia-idade inicial',
    'Meia-idade avançada', 'Pré-idoso', 'Idoso'
]
df['FaixaEtaria'] = pd.cut(df['Age'], bins=bins, labels=labels)

# %%
bool_cols = ['Promo Code Used', 'Discount Applied']
for col in bool_cols:
    df[col] = df[col].map({'Yes': 1, 'No': 0})

df.head()
# Out:
#    Customer ID  Age  Purchase Amount (USD)  Category Item Purchased  Season  \
# 0            1   55                     53  Clothing         Blouse  Winter
# 1            2   19                     64  Clothing        Sweater  Winter
# 2            3   50                     73  Clothing          Jeans  Spring
# 3            4   21                     90  Footwear        Sandals  Spring
# 4            5   45                     49  Clothing         Blouse  Spring
#
#    Promo Code Used  Discount Applied Preferred Payment Method  \
# 0                1                 1                    Venmo
# 1                1                 1                     Cash
# 2                1                 1              Credit Card
# 3                1                 1                   PayPal
# 4                1                 1                   PayPal
#
#             FaixaEtaria
# 0             Pré-idoso
# 1  Jovem menor de idade
# 2   Meia-idade avançada
# 3   Jovem universitário
# 4    Meia-idade inicial

# %%
df.dtypes
# Out:
# Customer ID                    int64
# Age                            int64
# Purchase Amount (USD)          int64
# Category                      object
# Item Purchased                object
# Season                        object
# Promo Code Used                int64
# Discount Applied               int64
# Preferred Payment Method      object
# FaixaEtaria                 category
# dtype: object

# %% [markdown]
# Modelagem perfil de compra

# %%
df_perfil_compra = pd.crosstab(df['FaixaEtaria'], df['Item Purchased'], normalize='index').reset_index()
df_perfil_compra
# Out:
# Item Purchased           FaixaEtaria  Backpack      Belt    Blouse     Boots  \
# 0               Jovem menor de idade  0.028302  0.056604  0.047170  0.037736
# 1                Jovem universitário  0.021898  0.043796  0.036496  0.014599
# 2                 Jovem profissional  0.043367  0.043367  0.040816  0.040816
# 3                     Adulto inicial  0.063361  0.041322  0.046832  0.030303
# 4                       Adulto médio  0.044321  0.047091  0.047091  0.049861
# 5                    Adulto avançado  0.046196  0.038043  0.048913  0.032609
# 6                 Meia-idade inicial  0.018868  0.064690  0.024259  0.029650
# 7                Meia-idade avançada  0.039370  0.026247  0.060367  0.052493
# 8                          Pré-idoso  0.029294  0.034621  0.041278  0.042610
# 9                              Idoso  0.032787  0.032787  0.046838  0.028103
#
# Item Purchased      Coat     Dress    Gloves   Handbag       Hat  ...  \
# 0               0.061321  0.056604  0.042453  0.037736  0.018868  ...
# 1               0.051095  0.047445  0.043796  0.043796  0.047445  ...
# 2               0.043367  0.033163  0.038265  0.033163  0.045918  ...
# 3               0.041322  0.030303  0.044077  0.030303  0.030303  ...
# 4               0.022161  0.030471  0.044321  0.024931  0.052632  ...
# 5               0.029891  0.051630  0.019022  0.035326  0.057065  ...
# 6               0.051213  0.053908  0.035040  0.037736  0.021563  ...
# 7               0.036745  0.034121  0.020997  0.047244  0.044619  ...
# 8               0.049268  0.043941  0.034621  0.045273  0.042610  ...
# 9               0.030445  0.049180  0.042155  0.049180  0.025761  ...
#
# Item Purchased     Scarf     Shirt     Shoes    Shorts     Skirt  Sneakers  \
# 0               0.042453  0.061321  0.033019  0.037736  0.056604  0.037736
# 1               0.032847  0.040146  0.025547  0.043796  0.029197  0.051095
# 2               0.043367  0.051020  0.033163  0.045918  0.061224  0.040816
# 3               0.016529  0.055096  0.041322  0.046832  0.030303  0.035813
# 4               0.052632  0.049861  0.024931  0.027701  0.027701  0.036011
# 5               0.065217  0.040761  0.027174  0.029891  0.024457  0.032609
# 6               0.037736  0.037736  0.051213  0.056604  0.045822  0.040431
# 7               0.031496  0.020997  0.052493  0.036745  0.041995  0.047244
# 8               0.039947  0.045273  0.045273  0.045273  0.043941  0.030626
# 9               0.039813  0.037471  0.037471  0.028103  0.042155  0.030445
#
# Item Purchased     Socks  Sunglasses   Sweater   T-shirt
# 0               0.042453    0.037736  0.070755  0.023585
# 1               0.043796    0.029197  0.051095  0.065693
# 2               0.035714    0.043367  0.033163  0.028061
# 3               0.055096    0.044077  0.035813  0.055096
# 4               0.019391    0.036011  0.044321  0.036011
# 5               0.040761    0.032609  0.029891  0.035326
# 6               0.029650    0.037736  0.045822  0.035040
# 7               0.047244    0.057743  0.044619  0.031496
# 8               0.039947    0.046605  0.039947  0.034621
# 9               0.053864    0.037471  0.042155  0.037471
#
# [10 rows x 26 columns]

# %%
df_perfil_compra_sem_chave = df_perfil_compra.drop(columns=["FaixaEtaria"])

# %% [markdown]
# Modelo perfil de compra

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

kmeans = KMeans(random_state=42)
visualizer = KElbowVisualizer(kmeans, k=(2, 11))
visualizer.fit(df_perfil_compra_sem_chave)
visualizer.show();

# %%
kmeans = KMeans(n_clusters=7, random_state=42)
kmeans.fit(df_perfil_compra_sem_chave)
df_perfil_compra['cluster_id_perfil_compra'] = kmeans.labels_

# %%
df_perfil_compra.head()
# Out:
# Item Purchased           FaixaEtaria  Backpack      Belt    Blouse     Boots  \
# 0               Jovem menor de idade  0.028302  0.056604  0.047170  0.037736
# 1                Jovem universitário  0.021898  0.043796  0.036496  0.014599
# 2                 Jovem profissional  0.043367  0.043367  0.040816  0.040816
# 3                     Adulto inicial  0.063361  0.041322  0.046832  0.030303
# 4                       Adulto médio  0.044321  0.047091  0.047091  0.049861
#
# Item Purchased      Coat     Dress    Gloves   Handbag       Hat  ...  \
# 0               0.061321  0.056604  0.042453  0.037736  0.018868  ...
# 1               0.051095  0.047445  0.043796  0.043796  0.047445  ...
# 2               0.043367  0.033163  0.038265  0.033163  0.045918  ...
# 3               0.041322  0.030303  0.044077  0.030303  0.030303  ...
# 4               0.022161  0.030471  0.044321  0.024931  0.052632  ...
#
# Item Purchased     Shirt     Shoes    Shorts     Skirt  Sneakers     Socks  \
# 0               0.061321  0.033019  0.037736  0.056604  0.037736  0.042453
# 1               0.040146  0.025547  0.043796  0.029197  0.051095  0.043796
# 2               0.051020  0.033163  0.045918  0.061224  0.040816  0.035714
# 3               0.055096  0.041322  0.046832  0.030303  0.035813  0.055096
# 4               0.049861  0.024931  0.027701  0.027701  0.036011  0.019391
#
# Item Purchased  Sunglasses   Sweater   T-shirt  cluster_id_perfil_compra
# 0                 0.037736  0.070755  0.023585                         1
# 1                 0.029197  0.051095  0.065693                         2
# 2                 0.043367  0.033163  0.028061                         5
# 3                 0.044077  0.035813  0.055096                         0
# 4                 0.036011  0.044321  0.036011                         6
#
# [5 rows x 27 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(34, 8))
sns.heatmap(df_perfil_compra_sem_chave.groupby(df_perfil_compra['cluster_id_perfil_compra']).mean().round(1), annot=True);

# %% [markdown]
# Analisar quais sao as faixas de idade mais contidas em cada cluster

# %%
df.head()
# Out:
#    Customer ID  Age  Purchase Amount (USD)  Category Item Purchased  Season  \
# 0            1   55                     53  Clothing         Blouse  Winter
# 1            2   19                     64  Clothing        Sweater  Winter
# 2            3   50                     73  Clothing          Jeans  Spring
# 3            4   21                     90  Footwear        Sandals  Spring
# 4            5   45                     49  Clothing         Blouse  Spring
#
#    Promo Code Used  Discount Applied Preferred Payment Method  \
# 0                1                 1                    Venmo
# 1                1                 1                     Cash
# 2                1                 1              Credit Card
# 3                1                 1                   PayPal
# 4                1                 1                   PayPal
#
#             FaixaEtaria
# 0             Pré-idoso
# 1  Jovem menor de idade
# 2   Meia-idade avançada
# 3   Jovem universitário
# 4    Meia-idade inicial

# %%
#RFV #Aqui não deveria estar pelas categorias de idade que criamos? Preciso ajustar do maior para o menor

df_perfil_compra_desconto =(df.
 filter(['Age', 'Purchase Amount (USD)', 'Discount Applied'])
 .groupby('Age')
 .agg(total_gasto = ('Purchase Amount (USD)', 'sum'),
      desconto = ("Discount Applied", "sum")
      ).reset_index()
 )
df_perfil_compra_desconto.head()
# Out:
#    Age  total_gasto  desconto
# 0   18         4139        29
# 1   19         4941        33
# 2   20         3424        32
# 3   21         4423        31
# 4   22         4011        27

# %%
#ranqueamento
df_perfil_compra_desconto['rank_pct_total_gasto'] = df_perfil_compra_desconto['total_gasto'].rank(pct=True) #.rank(pct = true) = percentual
df_perfil_compra_desconto["rank_pct_desconto"] = df_perfil_compra_desconto['desconto'].rank(pct=True)

# %%
df_perfil_compra_desconto.head()
# Out:
#    Age  total_gasto  desconto  rank_pct_total_gasto  rank_pct_desconto
# 0   18         4139        29              0.301887           0.367925
# 1   19         4941        33              0.867925           0.584906
# 2   20         3424        32              0.056604           0.547170
# 3   21         4423        31              0.584906           0.490566
# 4   22         4011        27              0.169811           0.264151

# %%
X_abt_total_desconto = df_perfil_compra_desconto[['rank_pct_total_gasto', 'rank_pct_desconto']].copy()

# %%
visualizer = KElbowVisualizer(kmeans, k=(2, 10))
visualizer.fit(X_abt_total_desconto)
visualizer.show();

# %%
kmeans = KMeans(n_clusters=6, random_state=42)
kmeans.fit(X_abt_total_desconto)
df_perfil_compra_desconto['cluster_id_gasto_desconto'] = kmeans.labels_

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(data=df_perfil_compra_desconto, x='rank_pct_total_gasto', y='rank_pct_desconto', hue='cluster_id_gasto_desconto', s=50, palette='deep');

# %% [markdown]
# Silhouette Score

# %% [markdown]
# Vamos fazer a análise do gráfico de silhueta para confirmar se K=6 é a melhor opção ou se devemos utilizar outro valor de K

# %%
from sklearn.metrics import silhouette_score

k_range = range(2, 11)
sil_scores = []

for k in k_range:
    labels = KMeans(n_clusters=k, random_state=42).fit_predict(X_abt_total_desconto)
    sil_scores.append(silhouette_score(X_abt_total_desconto, labels))

# %%
for k, s in zip(k_range, sil_scores):
    print(f"k = {k}: silhouette = {s:.4f}")
# Out:
# k = 2: silhouette = 0.5186
# k = 3: silhouette = 0.3909
# k = 4: silhouette = 0.2809
# k = 5: silhouette = 0.3697
# k = 6: silhouette = 0.4305
# k = 7: silhouette = 0.4212
# k = 8: silhouette = 0.3612
# k = 9: silhouette = 0.3598
# k = 10: silhouette = 0.3896

# %%
plt.figure(figsize=(6, 4))
plt.plot(k_range, sil_scores, marker="o")
plt.xticks(k_range)
plt.xlabel("Number of clusters (k)")
plt.ylabel("Silhouette score")
plt.title("Silhouette analysis for K-means")
plt.grid(True)
plt.show()

# %% [markdown]
# Embora K= 2, nos traria um modelo estatisticamente mais forte, nos obrigaria a a fazer a distinção somente entre 2 grupos de consumidores, o que não é caso que temos em nossa base. Como desejamos refinar a segmentação dos nossos clientes, vamos optar por k=6, já que nos permite fazer isso.

# %%
# Contagem de pessoas para k=2
k = 2
model = KMeans(n_clusters=k, random_state=42).fit(X_abt_total_desconto)

# rotule cada valor de IDADE
age2cluster = pd.DataFrame({
    'Age': df_perfil_compra_desconto['Age'],
    f'cluster{k}': model.labels_
})

#mesclar novamente os dados completos do nível do cliente
df_labeled = df.merge(age2cluster, on='Age', how='left')

print("Customer counts per cluster:")
print(df_labeled[f'cluster{k}'].value_counts().sort_index())
# Out:
# Customer counts per cluster:
# cluster2
# 0    2341
# 1    1559
# Name: count, dtype: int64

# %%
# Contagem de pessoas para k=2
k = 6
model = KMeans(n_clusters=k, random_state=42).fit(X_abt_total_desconto)

# otule cada valor de IDADE
age2cluster = pd.DataFrame({
    'Age': df_perfil_compra_desconto['Age'],
    f'cluster{k}': model.labels_
})

# mesclar novamente os dados completos do nível do cliente
df_labeled = df.merge(age2cluster, on='Age', how='left')

print("Customer counts per cluster:")
print(df_labeled[f'cluster{k}'].value_counts().sort_index())
# Out:
# Customer counts per cluster:
# cluster6
# 0    827
# 1    653
# 2    641
# 3    687
# 4    265
# 5    827
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
id2label_pt = {
    0: "Gastos altos",
    1: "Gastos baixos",
    2: "Gastos moderados",
    3: "Gastos levemente altos",
    4: "Gastos de moderados para baixo",
    5: "Gastos moderados para altos",
}

# %%
centroids = kmeans.cluster_centers_

# %%
plt.figure(figsize=(7, 6))

sns.scatterplot(
    # Changed data to the correct DataFrame
    data=df_perfil_compra_desconto,
    x='rank_pct_total_gasto',
    y='rank_pct_desconto',
    # Changed hue to the correct cluster column
    hue='cluster_id_gasto_desconto',
    palette='Set2',
    s=50,
    alpha=0.8,
    # Keep legend=False if you prefer not to show the default legend
    legend=False
)

# marca centróides e adiciona texto
for idx, (cx, cy) in enumerate(centroids):
    plt.scatter(cx, cy, c='black', s=120, marker='X')
    plt.text(cx, cy + 0.015,
             f"{idx}: {id2label_pt[idx]}",
             ha='center', va='bottom',
             fontsize=9, weight='bold')

plt.title("Gastos vs Uso de Cupons — clusters (k = 6)")
plt.xlabel("Percentil de gasto total")
plt.ylabel("Percentil de uso de cupons")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# Cluster #0: Apresentam gastos altos, estão localizados no canto superior direito
#
# Cluster #1: Apresentam gastos baixo, estão localizados no canto inferior esquerdo
#
# Cluster #2: Apresentam gastos moderados, estão localizados no lado esquerdo próximos ao centro do gráfico
#
# Cluster #3: Apresentam gastos altos, estão localizados no lado direito próximos ao centro do gráfico
#
# Cluster #4: Apresentam gastos de moderados para baixo, estão localizados no lado esquerdo próximos no centro do gráfico
#
# Cluster #5: Apresentam gastos moderados para altos, estão localizados no lado direito próximos acima do centro do gráfico

# %% [markdown]
# ### **Início de Deep Learning**

# %%
df_labeled.columns.tolist()
# Out:
# ['Customer ID',
#  'Age',
#  'Purchase Amount (USD)',
#  'Category',
#  'Item Purchased',
#  'Season',
#  'Promo Code Used',
#  'Discount Applied',
#  'Preferred Payment Method',
#  'FaixaEtaria',
#  'cluster6']

# %%
print(df_labeled['cluster6'].value_counts())
# Out:
# cluster6
# 5    827
# 0    827
# 3    687
# 1    653
# 2    641
# 4    265
# Name: count, dtype: int64

# %%
df_labeled.head()
# Out:
#    Customer ID  Age  Purchase Amount (USD)  Category Item Purchased  Season  \
# 0            1   55                     53  Clothing         Blouse  Winter
# 1            2   19                     64  Clothing        Sweater  Winter
# 2            3   50                     73  Clothing          Jeans  Spring
# 3            4   21                     90  Footwear        Sandals  Spring
# 4            5   45                     49  Clothing         Blouse  Spring
#
#    Promo Code Used  Discount Applied Preferred Payment Method  \
# 0                1                 1                    Venmo
# 1                1                 1                     Cash
# 2                1                 1              Credit Card
# 3                1                 1                   PayPal
# 4                1                 1                   PayPal
#
#             FaixaEtaria  cluster6
# 0             Pré-idoso         5
# 1  Jovem menor de idade         3
# 2   Meia-idade avançada         0
# 3   Jovem universitário         3
# 4    Meia-idade inicial         1

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.utils import to_categorical

# 1. Carregar / limpar dados
df_labeled_model = df_labeled.drop(["Customer ID", "Item Purchased"], axis=1)

# 2. Separar alvo ANTES de codificar
y = df_labeled_model["cluster6"].values          # vetor 1‑D (0‑5)
X_raw = df_labeled_model.drop("cluster6", axis=1)

# 3. Codificar variáveis categóricas
X_encoded = pd.get_dummies(X_raw, drop_first=True)

# 4. Train / validation split (estratificado)
X_train, X_val, y_train_int, y_val_int = train_test_split(
    X_encoded.values,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# 5. Escalonamento SEM vazamento
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)   # fit apenas no treino
X_val_scaled   = scaler.transform(X_val)         # transform no val

# 6. One‑hot encoding após split
y_train = to_categorical(y_train_int)
y_val   = to_categorical(y_val_int)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

input_dim = X_train.shape[1]
num_classes = y_train.shape[1]

model = Sequential([
    Dense(64, activation='relu', input_shape=(input_dim,)),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(num_classes, activation='softmax')
])

model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(
    X_train_scaled, y_train,
    validation_data=(X_val_scaled, y_val),
    epochs=100,
    batch_size=32,
    verbose=1
)

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.1951 - loss: 1.8892 - val_accuracy: 0.3654 - val_loss: 1.5852
# Epoch 2/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.3042 - loss: 1.6445 - val_accuracy: 0.4038 - val_loss: 1.4980
# Epoch 3/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.3794 - loss: 1.5475 - val_accuracy: 0.3962 - val_loss: 1.4354
# Epoch 4/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3604 - loss: 1.5008 - val_accuracy: 0.4090 - val_loss: 1.3862
# Epoch 5/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3902 - loss: 1.4453 - val_accuracy: 0.4038 - val_loss: 1.3538
# Epoch 6/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3917 - loss: 1.3985 - val_accuracy: 0.4167 - val_loss: 1.3308
# Epoch 7/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.3881 - loss: 1.4086 - val_accuracy: 0.4090 - val_loss: 1.3225
# Epoch 8/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4044 - loss: 1.3601 - val_accuracy: 0.4308 - val_loss: 1.3026
# Epoch 9/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4041 - loss: 1.3622 - val_accuracy: 0.4231 - val_loss: 1.2969
# Epoch 10/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.4116 - loss: 1.3343 - val_accuracy: 0.4167 - val_loss: 1.2952
# Epoch 11/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3904 - loss: 1.3510 - val_accuracy: 0.4154 - val_loss: 1.2875
# Epoch 12/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4078 - loss: 1.3249 - val_accuracy: 0.4218 - val_loss: 1.2803
# Epoch 13/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4064 - loss: 1.3225 - val_accuracy: 0.4154 - val_loss: 1.2820
# Epoch 14/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4079 - loss: 1.3209 - val_accuracy: 0.4231 - val_loss: 1.2794
# Epoch 15/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4224 - loss: 1.2971 - val_accuracy: 0.4205 - val_loss: 1.2803
# Epoch 16/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4117 - loss: 1.3114 - val_accuracy: 0.4128 - val_loss: 1.2738
# Epoch 17/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4210 - loss: 1.2840 - val_accuracy: 0.4231 - val_loss: 1.2740
# Epoch 18/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4027 - loss: 1.2977 - val_accuracy: 0.4167 - val_loss: 1.2732
# Epoch 19/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4221 - loss: 1.2918 - val_accuracy: 0.4179 - val_loss: 1.2722
# Epoch 20/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4037 - loss: 1.3002 - val_accuracy: 0.4218 - val_loss: 1.2728
# Epoch 21/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4179 - loss: 1.2801 - val_accuracy: 0.4218 - val_loss: 1.2726
# Epoch 22/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4120 - loss: 1.2914 - val_accuracy: 0.4179 - val_loss: 1.2700
# Epoch 23/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4227 - loss: 1.2822 - val_accuracy: 0.4295 - val_loss: 1.2624
# Epoch 24/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4197 - loss: 1.3011 - val_accuracy: 0.4179 - val_loss: 1.2688
# Epoch 25/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4152 - loss: 1.2771 - val_accuracy: 0.4179 - val_loss: 1.2626
# Epoch 26/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4170 - loss: 1.2879 - val_accuracy: 0.4115 - val_loss: 1.2637
# Epoch 27/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4446 - loss: 1.2502 - val_accuracy: 0.4205 - val_loss: 1.2734
# Epoch 28/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4134 - loss: 1.2744 - val_accuracy: 0.4205 - val_loss: 1.2609
# Epoch 29/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4230 - loss: 1.2637 - val_accuracy: 0.4128 - val_loss: 1.2696
# Epoch 30/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4275 - loss: 1.2459 - val_accuracy: 0.4192 - val_loss: 1.2643
# Epoch 31/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4210 - loss: 1.2622 - val_accuracy: 0.4244 - val_loss: 1.2626
# Epoch 32/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4216 - loss: 1.2668 - val_accuracy: 0.4192 - val_loss: 1.2668
# Epoch 33/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4366 - loss: 1.2576 - val_accuracy: 0.4167 - val_loss: 1.2701
# Epoch 34/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4356 - loss: 1.2503 - val_accuracy: 0.4179 - val_loss: 1.2709
# Epoch 35/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4122 - loss: 1.2556 - val_accuracy: 0.4179 - val_loss: 1.2674
# Epoch 36/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4397 - loss: 1.2639 - val_accuracy: 0.4167 - val_loss: 1.2689
# Epoch 37/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4079 - loss: 1.2610 - val_accuracy: 0.4154 - val_loss: 1.2697
# Epoch 38/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4295 - loss: 1.2382 - val_accuracy: 0.4090 - val_loss: 1.2643
# Epoch 39/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4374 - loss: 1.2374 - val_accuracy: 0.4179 - val_loss: 1.2674
# Epoch 40/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4398 - loss: 1.2342 - val_accuracy: 0.4167 - val_loss: 1.2687
# Epoch 41/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4305 - loss: 1.2483 - val_accuracy: 0.4205 - val_loss: 1.2683
# Epoch 42/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4366 - loss: 1.2521 - val_accuracy: 0.4103 - val_loss: 1.2681
# Epoch 43/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4418 - loss: 1.2407 - val_accuracy: 0.4244 - val_loss: 1.2679
# Epoch 44/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4350 - loss: 1.2463 - val_accuracy: 0.4282 - val_loss: 1.2647
# Epoch 45/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4361 - loss: 1.2372 - val_accuracy: 0.4295 - val_loss: 1.2677
# Epoch 46/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4341 - loss: 1.2424 - val_accuracy: 0.4346 - val_loss: 1.2597
# Epoch 47/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4372 - loss: 1.2308 - val_accuracy: 0.4346 - val_loss: 1.2599
# Epoch 48/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4687 - loss: 1.2125 - val_accuracy: 0.4423 - val_loss: 1.2582
# Epoch 49/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4486 - loss: 1.2244 - val_accuracy: 0.4423 - val_loss: 1.2602
# Epoch 50/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4410 - loss: 1.2179 - val_accuracy: 0.4321 - val_loss: 1.2604
# Epoch 51/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4193 - loss: 1.2384 - val_accuracy: 0.4295 - val_loss: 1.2647
# Epoch 52/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4382 - loss: 1.2234 - val_accuracy: 0.4179 - val_loss: 1.2631
# Epoch 53/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4358 - loss: 1.2182 - val_accuracy: 0.4205 - val_loss: 1.2595
# Epoch 54/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4452 - loss: 1.2129 - val_accuracy: 0.4167 - val_loss: 1.2561
# Epoch 55/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4399 - loss: 1.2109 - val_accuracy: 0.4333 - val_loss: 1.2591
# Epoch 56/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4488 - loss: 1.1949 - val_accuracy: 0.4295 - val_loss: 1.2516
# Epoch 57/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4426 - loss: 1.2024 - val_accuracy: 0.4346 - val_loss: 1.2560
# Epoch 58/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4474 - loss: 1.1939 - val_accuracy: 0.4308 - val_loss: 1.2525
# Epoch 59/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4607 - loss: 1.1933 - val_accuracy: 0.4397 - val_loss: 1.2488
# Epoch 60/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4634 - loss: 1.2004 - val_accuracy: 0.4205 - val_loss: 1.2476
# Epoch 61/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4423 - loss: 1.2130 - val_accuracy: 0.4256 - val_loss: 1.2529
# Epoch 62/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4590 - loss: 1.1857 - val_accuracy: 0.4321 - val_loss: 1.2541
# Epoch 63/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4612 - loss: 1.1836 - val_accuracy: 0.4244 - val_loss: 1.2454
# Epoch 64/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4590 - loss: 1.1781 - val_accuracy: 0.4282 - val_loss: 1.2426
# Epoch 65/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4517 - loss: 1.1832 - val_accuracy: 0.4346 - val_loss: 1.2409
# Epoch 66/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4429 - loss: 1.1819 - val_accuracy: 0.4282 - val_loss: 1.2417
# Epoch 67/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4637 - loss: 1.1649 - val_accuracy: 0.4333 - val_loss: 1.2383
# Epoch 68/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4540 - loss: 1.1635 - val_accuracy: 0.4346 - val_loss: 1.2346
# Epoch 69/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4309 - loss: 1.1965 - val_accuracy: 0.4333 - val_loss: 1.2291
# Epoch 70/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4718 - loss: 1.1665 - val_accuracy: 0.4244 - val_loss: 1.2191
# Epoch 71/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4643 - loss: 1.1556 - val_accuracy: 0.4346 - val_loss: 1.2152
# Epoch 72/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4766 - loss: 1.1561 - val_accuracy: 0.4295 - val_loss: 1.2131
# Epoch 73/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4653 - loss: 1.1679 - val_accuracy: 0.4397 - val_loss: 1.2074
# Epoch 74/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4723 - loss: 1.1522 - val_accuracy: 0.4423 - val_loss: 1.2070
# Epoch 75/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4648 - loss: 1.1506 - val_accuracy: 0.4385 - val_loss: 1.2046
# Epoch 76/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4712 - loss: 1.1310 - val_accuracy: 0.4410 - val_loss: 1.1957
# Epoch 77/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4573 - loss: 1.1540 - val_accuracy: 0.4436 - val_loss: 1.1975
# Epoch 78/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4740 - loss: 1.1432 - val_accuracy: 0.4513 - val_loss: 1.1921
# Epoch 79/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4664 - loss: 1.1551 - val_accuracy: 0.4308 - val_loss: 1.1853
# Epoch 80/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4819 - loss: 1.1286 - val_accuracy: 0.4538 - val_loss: 1.1767
# Epoch 81/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4831 - loss: 1.1225 - val_accuracy: 0.4577 - val_loss: 1.1882
# Epoch 82/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4594 - loss: 1.1273 - val_accuracy: 0.4564 - val_loss: 1.1756
# Epoch 83/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4998 - loss: 1.1019 - val_accuracy: 0.4474 - val_loss: 1.1774
# Epoch 84/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4894 - loss: 1.1054 - val_accuracy: 0.4615 - val_loss: 1.1554
# Epoch 85/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5005 - loss: 1.0866 - val_accuracy: 0.4808 - val_loss: 1.1485
# Epoch 86/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4905 - loss: 1.1016 - val_accuracy: 0.4577 - val_loss: 1.1445
# Epoch 87/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4997 - loss: 1.1010 - val_accuracy: 0.4731 - val_loss: 1.1298
# Epoch 88/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4907 - loss: 1.0910 - val_accuracy: 0.4808 - val_loss: 1.1259
# Epoch 89/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5081 - loss: 1.0536 - val_accuracy: 0.4846 - val_loss: 1.1163
# Epoch 90/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4968 - loss: 1.0769 - val_accuracy: 0.4679 - val_loss: 1.0975
# Epoch 91/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5175 - loss: 1.0627 - val_accuracy: 0.4885 - val_loss: 1.0973
# Epoch 92/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5180 - loss: 1.0536 - val_accuracy: 0.4795 - val_loss: 1.0960
# Epoch 93/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5115 - loss: 1.0665 - val_accuracy: 0.4821 - val_loss: 1.0756
# Epoch 94/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4874 - loss: 1.0653 - val_accuracy: 0.4872 - val_loss: 1.0646
# Epoch 95/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5016 - loss: 1.0500 - val_accuracy: 0.4962 - val_loss: 1.0627
# Epoch 96/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5214 - loss: 1.0308 - val_accuracy: 0.5128 - val_loss: 1.0491
# Epoch 97/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5221 - loss: 1.0252 - val_accuracy: 0.5090 - val_loss: 1.0407
# Epoch 98/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5244 - loss: 1.0231 - val_accuracy: 0.5064 - val_loss: 1.0363
# Epoch 99/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5020 - loss: 1.0324 - val_accuracy: 0.5269 - val_loss: 1.0244
# Epoch 100/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5154 - loss: 1.0103 - val_accuracy: 0.5205 - val_loss: 1.0131
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         1,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 6)              │           198 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,020 (46.96 KB)
#  Trainable params: 4,006 (15.65 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 8,014 (31.31 KB)

# %%
# Avaliar o modelo
val_loss, val_accuracy = model.evaluate(X_val_scaled, y_val, verbose=0)

print("\n=== Resultado Final ===")
print(f"Perda de Validação : {val_loss:.4f}")
print(f"Acurácia de Validação: {val_accuracy:.4f}  ({val_accuracy*100:.2f}%)")
# Out:
# === Resultado Final ===
# Perda de Validação : 1.0131
# Acurácia de Validação: 0.5205  (52.05%)

# %%
# Plot das curvas de perda e acurácia
fig, axs = plt.subplots(1, 2, figsize=(16, 5))

# Perda
axs[0].plot(history.history['loss'], label='Perda - Treino', color='blue')
axs[0].plot(history.history['val_loss'], label='Perda - Validação', color='orange')
axs[0].set_title('Curva de Perda por Época')
axs[0].set_xlabel('Épocas')
axs[0].set_ylabel('Perda')
axs[0].legend()
axs[0].grid(True)

# Acurácia
axs[1].plot(history.history['accuracy'], label='Acurácia - Treino', color='green')
axs[1].plot(history.history['val_accuracy'], label='Acurácia - Validação', color='red')
axs[1].set_title('Curva de Acurácia por Época')
axs[1].set_xlabel('Épocas')
axs[1].set_ylabel('Acurácia')
axs[1].legend()
axs[1].grid(True)

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# ---------- Previsões ----------
y_pred_probs   = model.predict(X_val_scaled)           # usa o conjunto escalonado
y_pred_classes = np.argmax(y_pred_probs, axis=1)
y_true_classes = np.argmax(y_val, axis=1)

# ---------- Relatório ----------
print("\n=== Classification Report (validação) ===")
print(classification_report(y_true_classes, y_pred_classes, digits=4))

# ---------- Matriz de confusão ----------
cm = confusion_matrix(y_true_classes, y_pred_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(cm,
            annot=True, fmt='d', cmap='Blues',
            xticklabels=range(cm.shape[0]),   # 0‑5
            yticklabels=range(cm.shape[0]))
plt.xlabel("Classe Predita")
plt.ylabel("Classe Real")
plt.title("Matriz de Confusão – Conjunto de Validação")
plt.show()
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# === Classification Report (validação) ===
#               precision    recall  f1-score   support
#
#            0     0.4488    0.6909    0.5442       165
#            1     0.5278    0.4351    0.4770       131
#            2     0.4571    0.1250    0.1963       128
#            3     0.5106    0.5255    0.5180       137
#            4     0.5849    0.5849    0.5849        53
#            5     0.6138    0.6988    0.6535       166
#
#     accuracy                         0.5205       780
#    macro avg     0.5238    0.5100    0.4956       780
# weighted avg     0.5187    0.5205    0.4972       780

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

# --- dimensões derivadas dos dados já escalonados ---
input_dim   = X_train_scaled.shape[1]    # nº de features após get_dummies
num_classes = y_train.shape[1]           # 6 (one‑hot)

# --- definição do modelo ---
model = Sequential([
    Dense(128, activation='relu', input_shape=(input_dim,), kernel_regularizer=l2(1e-4)),
    Dropout(0.3),
    Dense(64, activation='relu', kernel_regularizer=l2(1e-4)),
    Dropout(0.3),
    Dense(32, activation='relu', kernel_regularizer=l2(1e-4)),
    Dropout(0.3),
    Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer=Adam(learning_rate=5e-4),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

# --- callbacks ---
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)
]

# --- treinamento ---
history = model.fit(
    X_train_scaled, y_train,
    validation_data=(X_val_scaled, y_val),
    epochs=200,
    batch_size=16,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/200
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.1804 - loss: 1.8513 - val_accuracy: 0.3192 - val_loss: 1.6837 - learning_rate: 5.0000e-04
# Epoch 2/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2872 - loss: 1.7166 - val_accuracy: 0.3821 - val_loss: 1.5800 - learning_rate: 5.0000e-04
# Epoch 3/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3568 - loss: 1.6190 - val_accuracy: 0.3962 - val_loss: 1.5272 - learning_rate: 5.0000e-04
# Epoch 4/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3515 - loss: 1.5985 - val_accuracy: 0.4000 - val_loss: 1.5026 - learning_rate: 5.0000e-04
# Epoch 5/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3737 - loss: 1.5478 - val_accuracy: 0.3897 - val_loss: 1.4789 - learning_rate: 5.0000e-04
# Epoch 6/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3773 - loss: 1.5530 - val_accuracy: 0.3885 - val_loss: 1.4759 - learning_rate: 5.0000e-04
# Epoch 7/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3706 - loss: 1.5506 - val_accuracy: 0.3949 - val_loss: 1.4707 - learning_rate: 5.0000e-04
# Epoch 8/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3800 - loss: 1.5274 - val_accuracy: 0.4064 - val_loss: 1.4642 - learning_rate: 5.0000e-04
# Epoch 9/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3857 - loss: 1.5122 - val_accuracy: 0.4103 - val_loss: 1.4506 - learning_rate: 5.0000e-04
# Epoch 10/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3930 - loss: 1.4954 - val_accuracy: 0.4192 - val_loss: 1.4474 - learning_rate: 5.0000e-04
# Epoch 11/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4103 - loss: 1.4895 - val_accuracy: 0.4141 - val_loss: 1.4480 - learning_rate: 5.0000e-04
# Epoch 12/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4121 - loss: 1.4791 - val_accuracy: 0.4051 - val_loss: 1.4490 - learning_rate: 5.0000e-04
# Epoch 13/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3781 - loss: 1.4945 - val_accuracy: 0.3987 - val_loss: 1.4458 - learning_rate: 5.0000e-04
# Epoch 14/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3978 - loss: 1.4691 - val_accuracy: 0.4090 - val_loss: 1.4410 - learning_rate: 5.0000e-04
# Epoch 15/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4099 - loss: 1.4802 - val_accuracy: 0.4013 - val_loss: 1.4418 - learning_rate: 5.0000e-04
# Epoch 16/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.3956 - loss: 1.4878 - val_accuracy: 0.4179 - val_loss: 1.4373 - learning_rate: 5.0000e-04
# Epoch 17/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4039 - loss: 1.4651 - val_accuracy: 0.4077 - val_loss: 1.4388 - learning_rate: 5.0000e-04
# Epoch 18/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3949 - loss: 1.4817 - val_accuracy: 0.4051 - val_loss: 1.4364 - learning_rate: 5.0000e-04
# Epoch 19/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4226 - loss: 1.4482 - val_accuracy: 0.4205 - val_loss: 1.4361 - learning_rate: 5.0000e-04
# Epoch 20/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4138 - loss: 1.4578 - val_accuracy: 0.4115 - val_loss: 1.4380 - learning_rate: 5.0000e-04
# Epoch 21/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4114 - loss: 1.4664 - val_accuracy: 0.4167 - val_loss: 1.4371 - learning_rate: 5.0000e-04
# Epoch 22/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4121 - loss: 1.4724 - val_accuracy: 0.4103 - val_loss: 1.4374 - learning_rate: 5.0000e-04
# Epoch 23/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4132 - loss: 1.4486 - val_accuracy: 0.4205 - val_loss: 1.4319 - learning_rate: 5.0000e-04
# Epoch 24/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4186 - loss: 1.4579 - val_accuracy: 0.4128 - val_loss: 1.4339 - learning_rate: 5.0000e-04
# Epoch 25/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.4243 - loss: 1.4541 - val_accuracy: 0.4115 - val_loss: 1.4346 - learning_rate: 5.0000e-04
# Epoch 26/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4312 - loss: 1.4415 - val_accuracy: 0.4167 - val_loss: 1.4345 - learning_rate: 5.0000e-04
# Epoch 27/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4416 - loss: 1.4315 - val_accuracy: 0.4077 - val_loss: 1.4365 - learning_rate: 5.0000e-04
# Epoch 28/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4224 - loss: 1.4433 - val_accuracy: 0.4000 - val_loss: 1.4382 - learning_rate: 5.0000e-04

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# 1) Desempenho numérico (treino vs. validação)
train_loss, train_acc = model.evaluate(X_train_scaled, y_train, verbose=0)
val_loss,   val_acc   = model.evaluate(X_val_scaled,  y_val,  verbose=0)

print("Resultados")
print(f"Treino     -> loss: {train_loss:.4f} | acc: {train_acc:.4%}")
print(f"Validação  -> loss: {val_loss:.4f} | acc: {val_acc:.4%}")
# Out:
# Resultados
# Treino     -> loss: 1.3925 | acc: 44.4872%
# Validação  -> loss: 1.4319 | acc: 42.0513%

# %% [markdown]
# Comentário: Gap pequeno (≈ 4 pp) ⇒ não há overfitting grave, mas o modelo está limitado pela dificuldade intrínseca da tarefa (clusters sobrepostos + classes desbalanceadas + poucas features categóricas convertidas em dummies). Além disso deve se adicionar o fato de que a base só tem 3900 registros.

# %%
# 2) Relatório de classificação e matriz de confusão
y_pred_prob   = model.predict(X_val_scaled, verbose=0)
y_pred_labels = np.argmax(y_pred_prob, axis=1)
y_true_labels = np.argmax(y_val,       axis=1)

print("\n=== Classification Report (validação) ===")
print(classification_report(y_true_labels, y_pred_labels, digits=4))

cm = confusion_matrix(y_true_labels, y_pred_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=range(cm.shape[0]),
            yticklabels=range(cm.shape[0]))
plt.xlabel("Classe predita")
plt.ylabel("Classe real")
plt.title("Matriz de Confusão – Conjunto de Validação")
plt.show()
# Out:
# === Classification Report (validação) ===
#               precision    recall  f1-score   support
#
#            0     0.4201    0.4303    0.4251       165
#            1     0.4357    0.4656    0.4502       131
#            2     0.0000    0.0000    0.0000       128
#            3     0.3897    0.3869    0.3883       137
#            4     0.3636    0.0755    0.1250        53
#            5     0.4303    0.8373    0.5685       166
#
#     accuracy                         0.4205       780
#    macro avg     0.3399    0.3659    0.3262       780
# weighted avg     0.3468    0.4205    0.3632       780

# %% [markdown]
# Comentário:
# Erros concentrados entre os clusters 0 ↔ 5 e 1 ↔ 3 – exatamente aqueles cujos centroides estavam mais próximos nos eixos Age e Purchase Amount.
# Cluster 4 (minoritário) tem recall baixo somente 7,6%; a rede raramente o identifica. Para o cluster 5, ele recupera 83 % das instâncias reais.
# O Cluster 1 tem f1 ≈ 0,45, refletindo equilíbrio entre precisão (0,44) e recall (0,47)
# Para a classe 2 nenhum registro foi identificado corretamente. O algoritmo simplesmente não reconhece este padrão. Isso sugere que as fronteiras entre os clusters 2↔5 e 2↔1/3 são pouco definidas nos eixos que a rede enxerga

# %%
# 3) AUC macro‑média
try:
    auc_macro = roc_auc_score(y_val, y_pred_prob,
                              multi_class="ovo", average="macro")
    print(f"ROC‑AUC macro‑média: {auc_macro:.4f}")
except ValueError:
    print("ROC‑AUC não pôde ser calculado (é necessário ≥1 amostra positiva por classe).")
# Out:
# ROC‑AUC macro‑média: 0.7941

# %% [markdown]
# Comentário: O valor de 0,79 indica que o modelo consegue diferenciar os clusters consideravelmente melhor que o acaso, mas ainda há margem para melhoria coerente com a acurácia de 42 % e o fato de a classe 2 não estar sendo recuperada.

# %%
# 4) Verificar qual foi a melhor epóca
best_epoch = np.argmin(history.history["val_loss"]) + 1
print(f"\nMelhor época (menor val_loss): {best_epoch}")
# Out:
# Melhor época (menor val_loss): 23

# %% [markdown]
# Comentário: Early-Stopping parou na época 23 quando val_loss não melhorou por 10 épocas.
#
# Depois da época 10 tanto loss quanto acurácia variam pouco ⇒ adicionar mais épocas não ajudaria

# %%
# 5) Curvas de perda e acurácia (O objetivo é verificar o efeito da aplicação do early stopping)
fig, ax = plt.subplots(1, 2, figsize=(16,5))

# Perda
ax[0].plot(history.history["loss"],     label="Treino")
ax[0].plot(history.history["val_loss"], label="Validação")
ax[0].set_title("Perda por Época")
ax[0].set_xlabel("Época")
ax[0].set_ylabel("Perda")
ax[0].legend(); ax[0].grid(True)

# Acurácia
ax[1].plot(history.history["accuracy"],     label="Treino")
ax[1].plot(history.history["val_accuracy"], label="Validação")
ax[1].set_title("Acurácia por Época")
ax[1].set_xlabel("Época")
ax[1].set_ylabel("Acurácia")
ax[1].legend(); ax[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Comentário:
# Nem overfitting, nem grande performance: o modelo parece ter encontrado o máximo que consegue extrair desse conjunto de features para o alvo “cluster = classe”.
#
# Underfitting leve: as curvas continuam perto, mas longe do ideal (poderiam passar de 0,60 se as classes fossem bem separáveis).
#
# Os gráficos mostram o modelo “estacionou” em torno de 42 % de acurácia, reflexo de clusters que se sobrepõem e desbalanceamento de classe.

# %% [markdown]
# ## **Vamos testar uma "Rede Densa" com K=3**

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.utils import to_categorical

# %%
# remover colunas que não entram como feature
df_labeled_model = df_labeled.drop(["Customer ID", "Item Purchased"], axis=1)

# %%
# 1. KMeans com K=3 ---
features_cluster = pd.get_dummies(
    df_labeled_model[["Age", "Purchase Amount (USD)", "Category", "Season", "FaixaEtaria", "cluster6"]],
    drop_first=True
)
kmeans = KMeans(n_clusters=3, random_state=42, n_init="auto")
cluster3_labels = kmeans.fit_predict(features_cluster)

# %%
df_labeled_model["cluster3"] = cluster3_labels

# %%
y = df_labeled_model["cluster3"].values
X_raw = df_labeled_model.drop("cluster3", axis=1)

# %%
#codificar categóricas para o treinamento
X_encoded = pd.get_dummies(X_raw, drop_first=True)

# %%
# split estratificado
X_train, X_val, y_train_int, y_val_int = train_test_split(
    X_encoded.values,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
#  escalonamento sem vazamento
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled   = scaler.transform(X_val)

# %%
# converter para one-hot
y_train = to_categorical(y_train_int)
y_val   = to_categorical(y_val_int)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

input_dim = X_train.shape[1]
num_classes = y_train.shape[1]

model = Sequential([
    Dense(64, activation='relu', input_shape=(input_dim,)),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(num_classes, activation='softmax')
])

model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(
    X_train_scaled, y_train,
    validation_data=(X_val_scaled, y_val),
    epochs=100,
    batch_size=32,
    verbose=1
)

model.summary()
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.3868 - loss: 1.2094 - val_accuracy: 0.7641 - val_loss: 0.6717
# Epoch 2/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7050 - loss: 0.6712 - val_accuracy: 0.9090 - val_loss: 0.3131
# Epoch 3/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8454 - loss: 0.3853 - val_accuracy: 0.9410 - val_loss: 0.1882
# Epoch 4/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8994 - loss: 0.2578 - val_accuracy: 0.9513 - val_loss: 0.1383
# Epoch 5/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9043 - loss: 0.2243 - val_accuracy: 0.9590 - val_loss: 0.1126
# Epoch 6/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9227 - loss: 0.1918 - val_accuracy: 0.9641 - val_loss: 0.1044
# Epoch 7/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9428 - loss: 0.1594 - val_accuracy: 0.9718 - val_loss: 0.0908
# Epoch 8/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9549 - loss: 0.1297 - val_accuracy: 0.9692 - val_loss: 0.0849
# Epoch 9/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9472 - loss: 0.1327 - val_accuracy: 0.9679 - val_loss: 0.0779
# Epoch 10/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9504 - loss: 0.1180 - val_accuracy: 0.9679 - val_loss: 0.0764
# Epoch 11/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9530 - loss: 0.1100 - val_accuracy: 0.9679 - val_loss: 0.0733
# Epoch 12/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9576 - loss: 0.1006 - val_accuracy: 0.9718 - val_loss: 0.0679
# Epoch 13/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9595 - loss: 0.0881 - val_accuracy: 0.9705 - val_loss: 0.0638
# Epoch 14/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9640 - loss: 0.0873 - val_accuracy: 0.9705 - val_loss: 0.0627
# Epoch 15/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9636 - loss: 0.0863 - val_accuracy: 0.9705 - val_loss: 0.0620
# Epoch 16/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9628 - loss: 0.0854 - val_accuracy: 0.9808 - val_loss: 0.0566
# Epoch 17/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9747 - loss: 0.0664 - val_accuracy: 0.9718 - val_loss: 0.0592
# Epoch 18/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9697 - loss: 0.0768 - val_accuracy: 0.9718 - val_loss: 0.0554
# Epoch 19/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9728 - loss: 0.0738 - val_accuracy: 0.9756 - val_loss: 0.0557
# Epoch 20/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9727 - loss: 0.0738 - val_accuracy: 0.9705 - val_loss: 0.0569
# Epoch 21/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9754 - loss: 0.0626 - val_accuracy: 0.9769 - val_loss: 0.0526
# Epoch 22/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9754 - loss: 0.0625 - val_accuracy: 0.9705 - val_loss: 0.0588
# Epoch 23/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9765 - loss: 0.0568 - val_accuracy: 0.9756 - val_loss: 0.0516
# Epoch 24/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9774 - loss: 0.0584 - val_accuracy: 0.9795 - val_loss: 0.0486
# Epoch 25/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9782 - loss: 0.0545 - val_accuracy: 0.9808 - val_loss: 0.0512
# Epoch 26/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9828 - loss: 0.0466 - val_accuracy: 0.9731 - val_loss: 0.0568
# Epoch 27/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9844 - loss: 0.0482 - val_accuracy: 0.9808 - val_loss: 0.0468
# Epoch 28/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9799 - loss: 0.0481 - val_accuracy: 0.9821 - val_loss: 0.0473
# Epoch 29/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9797 - loss: 0.0571 - val_accuracy: 0.9744 - val_loss: 0.0585
# Epoch 30/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9833 - loss: 0.0401 - val_accuracy: 0.9833 - val_loss: 0.0444
# Epoch 31/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9790 - loss: 0.0459 - val_accuracy: 0.9795 - val_loss: 0.0495
# Epoch 32/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9801 - loss: 0.0492 - val_accuracy: 0.9795 - val_loss: 0.0520
# Epoch 33/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9846 - loss: 0.0374 - val_accuracy: 0.9756 - val_loss: 0.0511
# Epoch 34/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9829 - loss: 0.0385 - val_accuracy: 0.9731 - val_loss: 0.0533
# Epoch 35/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9857 - loss: 0.0357 - val_accuracy: 0.9718 - val_loss: 0.0501
# Epoch 36/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9833 - loss: 0.0431 - val_accuracy: 0.9795 - val_loss: 0.0450
# Epoch 37/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9849 - loss: 0.0423 - val_accuracy: 0.9808 - val_loss: 0.0449
# Epoch 38/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9878 - loss: 0.0332 - val_accuracy: 0.9769 - val_loss: 0.0485
# Epoch 39/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9880 - loss: 0.0333 - val_accuracy: 0.9808 - val_loss: 0.0453
# Epoch 40/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9865 - loss: 0.0307 - val_accuracy: 0.9846 - val_loss: 0.0462
# Epoch 41/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9846 - loss: 0.0357 - val_accuracy: 0.9782 - val_loss: 0.0520
# Epoch 42/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9846 - loss: 0.0346 - val_accuracy: 0.9795 - val_loss: 0.0472
# Epoch 43/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9888 - loss: 0.0316 - val_accuracy: 0.9808 - val_loss: 0.0460
# Epoch 44/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9909 - loss: 0.0270 - val_accuracy: 0.9808 - val_loss: 0.0485
# Epoch 45/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9858 - loss: 0.0303 - val_accuracy: 0.9782 - val_loss: 0.0518
# Epoch 46/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9888 - loss: 0.0282 - val_accuracy: 0.9795 - val_loss: 0.0496
# Epoch 47/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9874 - loss: 0.0321 - val_accuracy: 0.9808 - val_loss: 0.0461
# Epoch 48/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9843 - loss: 0.0324 - val_accuracy: 0.9833 - val_loss: 0.0488
# Epoch 49/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9865 - loss: 0.0304 - val_accuracy: 0.9756 - val_loss: 0.0513
# Epoch 50/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9904 - loss: 0.0239 - val_accuracy: 0.9744 - val_loss: 0.0544
# Epoch 51/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9901 - loss: 0.0238 - val_accuracy: 0.9808 - val_loss: 0.0490
# Epoch 52/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9934 - loss: 0.0216 - val_accuracy: 0.9795 - val_loss: 0.0478
# Epoch 53/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9905 - loss: 0.0254 - val_accuracy: 0.9821 - val_loss: 0.0459
# Epoch 54/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9920 - loss: 0.0214 - val_accuracy: 0.9833 - val_loss: 0.0473
# Epoch 55/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9860 - loss: 0.0268 - val_accuracy: 0.9782 - val_loss: 0.0527
# Epoch 56/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9923 - loss: 0.0222 - val_accuracy: 0.9795 - val_loss: 0.0506
# Epoch 57/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9899 - loss: 0.0222 - val_accuracy: 0.9808 - val_loss: 0.0498
# Epoch 58/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9919 - loss: 0.0218 - val_accuracy: 0.9756 - val_loss: 0.0512
# Epoch 59/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9905 - loss: 0.0249 - val_accuracy: 0.9833 - val_loss: 0.0518
# Epoch 60/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9932 - loss: 0.0211 - val_accuracy: 0.9782 - val_loss: 0.0504
# Epoch 61/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9890 - loss: 0.0257 - val_accuracy: 0.9808 - val_loss: 0.0500
# Epoch 62/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9860 - loss: 0.0386 - val_accuracy: 0.9769 - val_loss: 0.0556
# Epoch 63/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9929 - loss: 0.0220 - val_accuracy: 0.9782 - val_loss: 0.0597
# Epoch 64/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9936 - loss: 0.0165 - val_accuracy: 0.9808 - val_loss: 0.0431
# Epoch 65/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9915 - loss: 0.0227 - val_accuracy: 0.9769 - val_loss: 0.0538
# Epoch 66/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9918 - loss: 0.0211 - val_accuracy: 0.9808 - val_loss: 0.0544
# Epoch 67/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9921 - loss: 0.0217 - val_accuracy: 0.9795 - val_loss: 0.0519
# Epoch 68/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9911 - loss: 0.0275 - val_accuracy: 0.9795 - val_loss: 0.0486
# Epoch 69/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9890 - loss: 0.0225 - val_accuracy: 0.9821 - val_loss: 0.0486
# Epoch 70/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9959 - loss: 0.0144 - val_accuracy: 0.9795 - val_loss: 0.0449
# Epoch 71/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9922 - loss: 0.0218 - val_accuracy: 0.9795 - val_loss: 0.0507
# Epoch 72/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9933 - loss: 0.0162 - val_accuracy: 0.9808 - val_loss: 0.0501
# Epoch 73/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9893 - loss: 0.0339 - val_accuracy: 0.9756 - val_loss: 0.0592
# Epoch 74/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9961 - loss: 0.0150 - val_accuracy: 0.9782 - val_loss: 0.0495
# Epoch 75/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9899 - loss: 0.0240 - val_accuracy: 0.9795 - val_loss: 0.0532
# Epoch 76/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9932 - loss: 0.0182 - val_accuracy: 0.9769 - val_loss: 0.0572
# Epoch 77/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9951 - loss: 0.0134 - val_accuracy: 0.9731 - val_loss: 0.0704
# Epoch 78/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9950 - loss: 0.0127 - val_accuracy: 0.9744 - val_loss: 0.0617
# Epoch 79/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9937 - loss: 0.0177 - val_accuracy: 0.9795 - val_loss: 0.0562
# Epoch 80/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9946 - loss: 0.0149 - val_accuracy: 0.9859 - val_loss: 0.0477
# Epoch 81/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9922 - loss: 0.0209 - val_accuracy: 0.9808 - val_loss: 0.0499
# Epoch 82/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9930 - loss: 0.0188 - val_accuracy: 0.9782 - val_loss: 0.0574
# Epoch 83/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9921 - loss: 0.0158 - val_accuracy: 0.9756 - val_loss: 0.0612
# Epoch 84/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9938 - loss: 0.0172 - val_accuracy: 0.9795 - val_loss: 0.0616
# Epoch 85/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9952 - loss: 0.0151 - val_accuracy: 0.9795 - val_loss: 0.0531
# Epoch 86/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9918 - loss: 0.0162 - val_accuracy: 0.9795 - val_loss: 0.0555
# Epoch 87/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9941 - loss: 0.0141 - val_accuracy: 0.9782 - val_loss: 0.0556
# Epoch 88/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9962 - loss: 0.0098 - val_accuracy: 0.9744 - val_loss: 0.0603
# Epoch 89/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9940 - loss: 0.0145 - val_accuracy: 0.9769 - val_loss: 0.0582
# Epoch 90/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9951 - loss: 0.0159 - val_accuracy: 0.9769 - val_loss: 0.0542
# Epoch 91/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9937 - loss: 0.0177 - val_accuracy: 0.9795 - val_loss: 0.0574
# Epoch 92/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9931 - loss: 0.0163 - val_accuracy: 0.9744 - val_loss: 0.0649
# Epoch 93/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9925 - loss: 0.0173 - val_accuracy: 0.9769 - val_loss: 0.0607
# Epoch 94/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9937 - loss: 0.0137 - val_accuracy: 0.9769 - val_loss: 0.0615
# Epoch 95/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9911 - loss: 0.0230 - val_accuracy: 0.9756 - val_loss: 0.0567
# Epoch 96/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9957 - loss: 0.0111 - val_accuracy: 0.9769 - val_loss: 0.0553
# Epoch 97/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9919 - loss: 0.0183 - val_accuracy: 0.9718 - val_loss: 0.0624
# Epoch 98/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9953 - loss: 0.0167 - val_accuracy: 0.9731 - val_loss: 0.0738
# Epoch 99/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9943 - loss: 0.0177 - val_accuracy: 0.9795 - val_loss: 0.0574
# Epoch 100/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9960 - loss: 0.0113 - val_accuracy: 0.9795 - val_loss: 0.0571
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_14 (Dense)                │ (None, 64)             │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,915 (46.55 KB)
#  Trainable params: 3,971 (15.51 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 7,944 (31.04 KB)

# %%
# Avaliar o modelo
val_loss, val_accuracy = model.evaluate(X_val_scaled, y_val, verbose=0)

print("\n=== Resultado Final ===")
print(f"Perda de Validação : {val_loss:.4f}")
print(f"Acurácia de Validação: {val_accuracy:.4f}  ({val_accuracy*100:.2f}%)")
# Out:
# === Resultado Final ===
# Perda de Validação : 0.0571
# Acurácia de Validação: 0.9795  (97.95%)

# %%
# Plot das curvas de perda e acurácia
fig, axs = plt.subplots(1, 2, figsize=(16, 5))

# Perda
axs[0].plot(history.history['loss'], label='Perda - Treino', color='blue')
axs[0].plot(history.history['val_loss'], label='Perda - Validação', color='orange')
axs[0].set_title('Curva de Perda por Época')
axs[0].set_xlabel('Épocas')
axs[0].set_ylabel('Perda')
axs[0].legend()
axs[0].grid(True)

# Acurácia
axs[1].plot(history.history['accuracy'], label='Acurácia - Treino', color='green')
axs[1].plot(history.history['val_accuracy'], label='Acurácia - Validação', color='red')
axs[1].set_title('Curva de Acurácia por Época')
axs[1].set_xlabel('Épocas')
axs[1].set_ylabel('Acurácia')
axs[1].legend()
axs[1].grid(True)

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# ---------- Previsões ----------
y_pred_probs   = model.predict(X_val_scaled)           # usa o conjunto escalonado
y_pred_classes = np.argmax(y_pred_probs, axis=1)
y_true_classes = np.argmax(y_val, axis=1)

# ---------- Relatório ----------
print("\n=== Classification Report (validação) ===")
print(classification_report(y_true_classes, y_pred_classes, digits=4))

# ---------- Matriz de confusão ----------
cm = confusion_matrix(y_true_classes, y_pred_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(cm,
            annot=True, fmt='d', cmap='Blues',
            xticklabels=range(cm.shape[0]),   # 0‑5
            yticklabels=range(cm.shape[0]))
plt.xlabel("Classe Predita")
plt.ylabel("Classe Real")
plt.title("Matriz de Confusão – Conjunto de Validação")
plt.show()
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# === Classification Report (validação) ===
#               precision    recall  f1-score   support
#
#            0     0.9763    0.9671    0.9717       213
#            1     0.9942    0.9885    0.9914       348
#            2     0.9596    0.9772    0.9683       219
#
#     accuracy                         0.9795       780
#    macro avg     0.9767    0.9776    0.9771       780
# weighted avg     0.9796    0.9795    0.9795       780

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

# --- dimensões derivadas dos dados já escalonados ---
input_dim   = X_train_scaled.shape[1]    # nº de features após get_dummies
num_classes = y_train.shape[1]           # 6 (one‑hot)

# --- definição do modelo ---
model = Sequential([
    Dense(128, activation='relu', input_shape=(input_dim,), kernel_regularizer=l2(1e-4)),
    Dropout(0.3),
    Dense(64, activation='relu', kernel_regularizer=l2(1e-4)),
    Dropout(0.3),
    Dense(32, activation='relu', kernel_regularizer=l2(1e-4)),
    Dropout(0.3),
    Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer=Adam(learning_rate=5e-4),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

# --- callbacks ---
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)
]

# --- treinamento ---
history = model.fit(
    X_train_scaled, y_train,
    validation_data=(X_val_scaled, y_val),
    epochs=200,
    batch_size=16,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/200
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4909 - loss: 1.0701 - val_accuracy: 0.8628 - val_loss: 0.6437 - learning_rate: 5.0000e-04
# Epoch 2/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7832 - loss: 0.6941 - val_accuracy: 0.9333 - val_loss: 0.4562 - learning_rate: 5.0000e-04
# Epoch 3/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8835 - loss: 0.5470 - val_accuracy: 0.9513 - val_loss: 0.4231 - learning_rate: 5.0000e-04
# Epoch 4/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9089 - loss: 0.5156 - val_accuracy: 0.9487 - val_loss: 0.4203 - learning_rate: 5.0000e-04
# Epoch 5/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9242 - loss: 0.4914 - val_accuracy: 0.9590 - val_loss: 0.4104 - learning_rate: 5.0000e-04
# Epoch 6/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9292 - loss: 0.4843 - val_accuracy: 0.9564 - val_loss: 0.4059 - learning_rate: 5.0000e-04
# Epoch 7/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9434 - loss: 0.4720 - val_accuracy: 0.9603 - val_loss: 0.4018 - learning_rate: 5.0000e-04
# Epoch 8/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9462 - loss: 0.4583 - val_accuracy: 0.9628 - val_loss: 0.3963 - learning_rate: 5.0000e-04
# Epoch 9/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9380 - loss: 0.4590 - val_accuracy: 0.9679 - val_loss: 0.3900 - learning_rate: 5.0000e-04
# Epoch 10/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9479 - loss: 0.4456 - val_accuracy: 0.9641 - val_loss: 0.3900 - learning_rate: 5.0000e-04
# Epoch 11/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9621 - loss: 0.4377 - val_accuracy: 0.9628 - val_loss: 0.3865 - learning_rate: 5.0000e-04
# Epoch 12/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9556 - loss: 0.4327 - val_accuracy: 0.9667 - val_loss: 0.3825 - learning_rate: 5.0000e-04
# Epoch 13/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9578 - loss: 0.4299 - val_accuracy: 0.9628 - val_loss: 0.3810 - learning_rate: 5.0000e-04
# Epoch 14/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9645 - loss: 0.4183 - val_accuracy: 0.9679 - val_loss: 0.3752 - learning_rate: 5.0000e-04
# Epoch 15/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9698 - loss: 0.4122 - val_accuracy: 0.9705 - val_loss: 0.3729 - learning_rate: 5.0000e-04
# Epoch 16/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9698 - loss: 0.4011 - val_accuracy: 0.9679 - val_loss: 0.3688 - learning_rate: 5.0000e-04
# Epoch 17/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9644 - loss: 0.4079 - val_accuracy: 0.9628 - val_loss: 0.3691 - learning_rate: 5.0000e-04
# Epoch 18/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9737 - loss: 0.3976 - val_accuracy: 0.9641 - val_loss: 0.3682 - learning_rate: 5.0000e-04
# Epoch 19/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9678 - loss: 0.3980 - val_accuracy: 0.9667 - val_loss: 0.3642 - learning_rate: 5.0000e-04
# Epoch 20/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9724 - loss: 0.3889 - val_accuracy: 0.9667 - val_loss: 0.3630 - learning_rate: 5.0000e-04
# Epoch 21/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9764 - loss: 0.3833 - val_accuracy: 0.9718 - val_loss: 0.3586 - learning_rate: 5.0000e-04
# Epoch 22/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9806 - loss: 0.3807 - val_accuracy: 0.9628 - val_loss: 0.3607 - learning_rate: 5.0000e-04
# Epoch 23/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9794 - loss: 0.3807 - val_accuracy: 0.9692 - val_loss: 0.3576 - learning_rate: 5.0000e-04
# Epoch 24/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9852 - loss: 0.3687 - val_accuracy: 0.9705 - val_loss: 0.3576 - learning_rate: 5.0000e-04
# Epoch 25/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9749 - loss: 0.3734 - val_accuracy: 0.9641 - val_loss: 0.3587 - learning_rate: 5.0000e-04
# Epoch 26/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9792 - loss: 0.3695 - val_accuracy: 0.9679 - val_loss: 0.3554 - learning_rate: 5.0000e-04
# Epoch 27/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9818 - loss: 0.3704 - val_accuracy: 0.9705 - val_loss: 0.3544 - learning_rate: 5.0000e-04
# Epoch 28/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9862 - loss: 0.3601 - val_accuracy: 0.9705 - val_loss: 0.3519 - learning_rate: 5.0000e-04
# Epoch 29/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9861 - loss: 0.3591 - val_accuracy: 0.9692 - val_loss: 0.3576 - learning_rate: 5.0000e-04
# Epoch 30/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9855 - loss: 0.3640 - val_accuracy: 0.9756 - val_loss: 0.3537 - learning_rate: 5.0000e-04
# Epoch 31/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9836 - loss: 0.3632 - val_accuracy: 0.9731 - val_loss: 0.3480 - learning_rate: 5.0000e-04
# Epoch 32/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9836 - loss: 0.3580 - val_accuracy: 0.9744 - val_loss: 0.3475 - learning_rate: 5.0000e-04
# Epoch 33/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9832 - loss: 0.3617 - val_accuracy: 0.9756 - val_loss: 0.3502 - learning_rate: 5.0000e-04
# Epoch 34/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9879 - loss: 0.3573 - val_accuracy: 0.9731 - val_loss: 0.3483 - learning_rate: 5.0000e-04
# Epoch 35/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9864 - loss: 0.3507 - val_accuracy: 0.9744 - val_loss: 0.3470 - learning_rate: 5.0000e-04
# Epoch 36/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9871 - loss: 0.3567 - val_accuracy: 0.9718 - val_loss: 0.3514 - learning_rate: 5.0000e-04
# Epoch 37/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9892 - loss: 0.3484 - val_accuracy: 0.9718 - val_loss: 0.3526 - learning_rate: 5.0000e-04
# Epoch 38/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9862 - loss: 0.3524 - val_accuracy: 0.9756 - val_loss: 0.3505 - learning_rate: 5.0000e-04
# Epoch 39/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9877 - loss: 0.3525 - val_accuracy: 0.9705 - val_loss: 0.3526 - learning_rate: 5.0000e-04
# Epoch 40/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9891 - loss: 0.3485 - val_accuracy: 0.9718 - val_loss: 0.3470 - learning_rate: 5.0000e-04
# Epoch 41/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9901 - loss: 0.3484 - val_accuracy: 0.9731 - val_loss: 0.3453 - learning_rate: 2.5000e-04
# Epoch 42/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9883 - loss: 0.3488 - val_accuracy: 0.9718 - val_loss: 0.3487 - learning_rate: 2.5000e-04
# Epoch 43/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9949 - loss: 0.3404 - val_accuracy: 0.9705 - val_loss: 0.3482 - learning_rate: 2.5000e-04
# Epoch 44/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9899 - loss: 0.3445 - val_accuracy: 0.9782 - val_loss: 0.3481 - learning_rate: 2.5000e-04
# Epoch 45/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9899 - loss: 0.3464 - val_accuracy: 0.9782 - val_loss: 0.3444 - learning_rate: 2.5000e-04
# Epoch 46/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9884 - loss: 0.3481 - val_accuracy: 0.9667 - val_loss: 0.3512 - learning_rate: 2.5000e-04
# Epoch 47/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9905 - loss: 0.3451 - val_accuracy: 0.9731 - val_loss: 0.3482 - learning_rate: 2.5000e-04
# Epoch 48/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9920 - loss: 0.3407 - val_accuracy: 0.9718 - val_loss: 0.3483 - learning_rate: 2.5000e-04
# Epoch 49/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9895 - loss: 0.3418 - val_accuracy: 0.9769 - val_loss: 0.3438 - learning_rate: 2.5000e-04
# Epoch 50/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9914 - loss: 0.3428 - val_accuracy: 0.9718 - val_loss: 0.3489 - learning_rate: 2.5000e-04
# Epoch 51/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9891 - loss: 0.3439 - val_accuracy: 0.9744 - val_loss: 0.3484 - learning_rate: 2.5000e-04
# Epoch 52/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9908 - loss: 0.3397 - val_accuracy: 0.9769 - val_loss: 0.3474 - learning_rate: 2.5000e-04
# Epoch 53/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9913 - loss: 0.3433 - val_accuracy: 0.9756 - val_loss: 0.3446 - learning_rate: 2.5000e-04
# Epoch 54/200
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9955 - loss: 0.3360 - val_accuracy: 0.9769 - val_loss: 0.3453 - learning_rate: 2.5000e-04

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# 1) Desempenho numérico (treino vs. validação)
train_loss, train_acc = model.evaluate(X_train_scaled, y_train, verbose=0)
val_loss,   val_acc   = model.evaluate(X_val_scaled,  y_val,  verbose=0)

print("Resultados")
print(f"Treino     -> loss: {train_loss:.4f} | acc: {train_acc:.4%}")
print(f"Validação  -> loss: {val_loss:.4f} | acc: {val_acc:.4%}")
# Out:
# Resultados
# Treino     -> loss: 0.3104 | acc: 99.7115%
# Validação  -> loss: 0.3438 | acc: 97.6923%

# %%
# 2) Relatório de classificação e matriz de confusão
y_pred_prob   = model.predict(X_val_scaled, verbose=0)
y_pred_labels = np.argmax(y_pred_prob, axis=1)
y_true_labels = np.argmax(y_val,       axis=1)

print("\n=== Classification Report (validação) ===")
print(classification_report(y_true_labels, y_pred_labels, digits=4))

cm = confusion_matrix(y_true_labels, y_pred_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=range(cm.shape[0]),
            yticklabels=range(cm.shape[0]))
plt.xlabel("Classe predita")
plt.ylabel("Classe real")
plt.title("Matriz de Confusão – Conjunto de Validação")
plt.show()
# Out:
# === Classification Report (validação) ===
#               precision    recall  f1-score   support
#
#            0     0.9717    0.9671    0.9694       213
#            1     0.9884    0.9828    0.9856       348
#            2     0.9640    0.9772    0.9705       219
#
#     accuracy                         0.9769       780
#    macro avg     0.9747    0.9757    0.9752       780
# weighted avg     0.9770    0.9769    0.9769       780

# %%
# 3) AUC macro‑média
try:
    auc_macro = roc_auc_score(y_val, y_pred_prob,
                              multi_class="ovo", average="macro")
    print(f"ROC‑AUC macro‑média: {auc_macro:.4f}")
except ValueError:
    print("ROC‑AUC não pôde ser calculado (é necessário ≥1 amostra positiva por classe).")
# Out:
# ROC‑AUC macro‑média: 0.9990

# %%
# 4) Verificar qual foi a melhor epóca
best_epoch = np.argmin(history.history["val_loss"]) + 1
print(f"\nMelhor época (menor val_loss): {best_epoch}")
# Out:
# Melhor época (menor val_loss): 49

# %%
# 5) Curvas de perda e acurácia (O objetivo é verificar o efeito da aplicação do early stopping)
fig, ax = plt.subplots(1, 2, figsize=(16,5))

# Perda
ax[0].plot(history.history["loss"],     label="Treino")
ax[0].plot(history.history["val_loss"], label="Validação")
ax[0].set_title("Perda por Época")
ax[0].set_xlabel("Época")
ax[0].set_ylabel("Perda")
ax[0].legend(); ax[0].grid(True)

# Acurácia
ax[1].plot(history.history["accuracy"],     label="Treino")
ax[1].plot(history.history["val_accuracy"], label="Validação")
ax[1].set_title("Acurácia por Época")
ax[1].set_xlabel("Época")
ax[1].set_ylabel("Acurácia")
ax[1].legend(); ax[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Comentário: A acurácia passou para 97,44%, enquanto que a ROC-AUC para 99%, o indica que para cada classe one-vs-rest, o modelo quase sempre atribui pontuação mais alta ao exemplo correto, ou seja, sinal de clusters bem definidos,já a perda (cross-entropy) de 0,354. O desequilibrio de classes que havia com K=6, desapareceu quando adotamos K=6, embora não tenhamos feito o balanceamento de classes. Com somente 3 clusters ficou mais fácil para o treinamento da rede
#
# A troca para K = 3 tornou o problema muito mais bem comportado: acurácia 97 % e AUC 0,998 mostram que os grupos agora são fáceis de distinguir.
#
# Não há urgência em balanceamento de classes; elas já vêm quase equilibradas

# %%
# 1. Criação da nova coluna 'cluster3' como Series
cluster3_series = pd.Series(cluster3_labels, name="cluster3", index=df_labeled.index)

# 2. Concatenar e agrupar por 'cluster3'
df_clustered = pd.concat([df_labeled, cluster3_series], axis=1)

# 3. Selecionar apenas colunas numéricas para calcular a média
numeric_cols = df_clustered.select_dtypes(include=[np.number]).columns

# %%
# 4. Calcular value counts
cluster_value_counts = df_clustered[numeric_cols].groupby("cluster3").value_counts()

# Exibir value_counts
display(cluster_value_counts)
# Out:
# cluster3  Customer ID  Age  Purchase Amount (USD)  Promo Code Used  Discount Applied  cluster6
# 0         3            50   73                     1                1                 0           1
#           7            63   85                     1                1                 3           1
#           13           61   72                     1                1                 2           1
#           16           64   81                     1                1                 5           1
#           20           66   90                     1                1                 2           1
#                                                                                                  ..
# 2         3883         35   95                     0                0                 5           1
#           3887         37   92                     0                0                 0           1
#           3891         35   81                     0                0                 5           1
#           3893         35   86                     0                0                 5           1
#           3894         21   64                     0                0                 3           1
# Name: count, Length: 3900, dtype: int64

# %%
display(cluster_means[['Purchase Amount (USD)', 'Age']])
# Out:
#           Purchase Amount (USD)        Age
# cluster3
# 0                     79.521087  57.270853
# 1                     37.104871  44.820057
# 2                     76.731618  29.915441

# %%
# Crosstab do cluster3 e FaixaEtaria
crosstab_cluster3_faixaetaria = pd.crosstab(df_clustered['cluster3'], df_clustered['FaixaEtaria'])

# crosstab
display(crosstab_cluster3_faixaetaria)

# Percentual de cada cluster
print("\nPercentages within each cluster:")
display(crosstab_cluster3_faixaetaria.apply(lambda r: r/r.sum(), axis=1))
# Out:
# FaixaEtaria  Jovem menor de idade  Jovem universitário  Jovem profissional  \
# cluster3
# 0                               0                    0                   0
# 1                              82                   97                 157
# 2                             130                  177                 235
#
# FaixaEtaria  Adulto inicial  Adulto médio  Adulto avançado  \
# cluster3
# 0                         0             0               43
# 1                       158           164              180
# 2                       205           197              145
#
# FaixaEtaria  Meia-idade inicial  Meia-idade avançada  Pré-idoso  Idoso
# cluster3
# 0                           169                  214        396    245
# 1                           198                  167        355    182
# 2                             4                    0          0      0
# Percentages within each cluster:
# FaixaEtaria  Jovem menor de idade  Jovem universitário  Jovem profissional  \
# cluster3
# 0                        0.000000             0.000000            0.000000
# 1                        0.047126             0.055747            0.090230
# 2                        0.118939             0.161940            0.215005
#
# FaixaEtaria  Adulto inicial  Adulto médio  Adulto avançado  \
# cluster3
# 0                  0.000000      0.000000         0.040300
# 1                  0.090805      0.094253         0.103448
# 2                  0.187557      0.180238         0.132662
#
# FaixaEtaria  Meia-idade inicial  Meia-idade avançada  Pré-idoso     Idoso
# cluster3
# 0                      0.158388             0.200562   0.371134  0.229616
# 1                      0.113793             0.095977   0.204023  0.104598
# 2                      0.003660             0.000000   0.000000  0.000000

# %%
counts = df_clustered["cluster3"].value_counts().sort_index()
props = df_clustered["cluster3"].value_counts(normalize=True).sort_index()
print("Contagem por cluster:\n", counts)
print("\nProporção por cluster:\n", props)
# Out:
# Contagem por cluster:
#  cluster3
# 0    1067
# 1    1740
# 2    1093
# Name: count, dtype: int64
#
# Proporção por cluster:
#  cluster3
# 0    0.273590
# 1    0.446154
# 2    0.280256
# Name: proportion, dtype: float64

# %%
# 1.4. Distribuições por cluster (exemplo: histograma de Age e Purchase Amount)
import matplotlib.pyplot as plt

for col in ["Age", "Purchase Amount (USD)"]:
    plt.figure(figsize=(10, 4))
    for cluster in sorted(df_clustered["cluster3"].unique()):
        subset = df_clustered[df_clustered["cluster3"] == cluster]
        plt.hist(subset[col].dropna(), bins=30, alpha=0.5, label=f"Cluster {cluster}", density=True)
    plt.title(f"Distribuição de {col} por cluster")
    plt.legend()
    plt.tight_layout()
    plt.show()

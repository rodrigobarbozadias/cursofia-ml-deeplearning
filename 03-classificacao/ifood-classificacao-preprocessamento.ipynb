# %% [markdown]
# ## Parte 3 - Classificação - Pré-processamento
#
# ---
# <img align="center" width="150" src="https://logodownload.org/wp-content/uploads/2017/05/ifood-logo-0.png">

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
import numpy as np
import pandas as pd

# %% [markdown]
# ## Lendos os Dados

# %%
df_abt_train = pd.read_csv('/content/drive/MyDrive/datasets/ifood/abt_classificacao_ifood_train.csv')
df_abt_train.head(2)

# %%
df_abt_oot = pd.read_csv('/content/drive/MyDrive/datasets/ifood/abt_classificacao_ifood_oot.csv')
df_abt_oot.head(2)

# %% [markdown]
# **`Q1`** Identifique as varáveis para modelagem: `key_vars, num_vars, cat_vars,
# target, features`.

# %% [markdown]
# **`Q2`** Crie `X_train, y_train, X_oot, y_oot`. Utilize para as features todas as variáveis (numéricas e categóricas).

# %% [markdown]
# **`Q3`**  Treine uma árvore de decisão na base de treino usando Stratified K-Fold e avalie utilizando a métrica **AUC** na base Out of Time.
#
# - Utilize o parametro `random_state=42` na árvore de decisão.
# - Utilize os seguintes parâmetros `n_splits=5, shuffle=True, random_state=42` para Stratified K-Fold.
# - Lembre-se de realizar o pré-processamento dos dados

# %%
# !pip install feature-engine

# %% [markdown]
# **`Q4`** Treine uma Regressão Logistica na base de treino usando Stratified K-Fold e avalie utilizando a métrica **AUC** na base Out of Time.
#
# - Utilize o parametro `random_state=42` na regressão logistica.
# - Utilize os seguintes parâmetros `n_splits=5, shuffle=True, random_state=42` para Stratified K-Fold.
# - Lembre-se de realizar o pré-processamento dos dados

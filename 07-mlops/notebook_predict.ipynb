# %%
# !pip install feature_engine

# %%
import pandas as pd
import feature_engine
import joblib

# %% [markdown]
# ## Carrega a ABT para sofrer o predict

# %%
df_previsao= pd.read_csv("/content/drive/MyDrive/Aula Fev Março Abri Maio 2024/03 - Aprendizagem Supervisionada - Classificação/Tópico 1 - Introdução/propensao_revenda_abt.csv")
df_previsao.shape
# Out:
# (5369, 9)

# %%
df_previsao.columns
# Out:
# Index(['data_ref_safra', 'seller_id', 'uf', 'tot_orders_12m', 'tot_items_12m',
#        'tot_items_dist_12m', 'receita_12m', 'recencia',
#        'nao_revendeu_next_6m'],
#       dtype='object')

# %%
df_previsao= df_previsao.drop(columns=["nao_revendeu_next_6m"], axis=1)

# %%
df_previsao.head()
# Out:
#   data_ref_safra                         seller_id  uf  tot_orders_12m  \
# 0     2018-01-01  0015a82c2db000af6aaaf3ae2ecb0532  SP               3
# 1     2018-01-01  001cca7ae9ae17fb1caed9dfb1094831  ES             171
# 2     2018-01-01  002100f778ceb8431b7a1020ff7ab48f  SP              38
# 3     2018-01-01  003554e2dce176b5555353e4f3555ac8  GO               1
# 4     2018-01-01  004c9cd9d87a3c30c522c48c4fc07416  SP             130
#
#    tot_items_12m  tot_items_dist_12m  receita_12m  recencia
# 0              3                   1      2685.00        74
# 1            207                   9     21275.23         2
# 2             42                  15       781.80         2
# 3              1                   1       120.00        16
# 4            141                  75     16228.88         8

# %% [markdown]
# ## Carrega o modelo treinado

# %%
model = joblib.load("/content/drive/MyDrive/modelo_churn_20240326.pkl")

# %%
previsão= df_previsao.filter(["uf", 	"tot_orders_12m" ,	"tot_items_12m", 	"tot_items_dist_12m" ,	"receita_12m" ,	"recencia"])

# %% [markdown]
# ## Realiza a previsão com o modelo na ABT precidt

# %%
df_previsao["previsão"]= model.predict(previsão)

# %% [markdown]
# ## Salva o resultado

# %%
df_previsao["previsão_proba"]= model.predict_proba(previsão)[:,1]

# %%
df_previsao.head()
# Out:
#   data_ref_safra                         seller_id  uf  tot_orders_12m  \
# 0     2018-01-01  0015a82c2db000af6aaaf3ae2ecb0532  SP               3
# 1     2018-01-01  001cca7ae9ae17fb1caed9dfb1094831  ES             171
# 2     2018-01-01  002100f778ceb8431b7a1020ff7ab48f  SP              38
# 3     2018-01-01  003554e2dce176b5555353e4f3555ac8  GO               1
# 4     2018-01-01  004c9cd9d87a3c30c522c48c4fc07416  SP             130
#
#    tot_items_12m  tot_items_dist_12m  receita_12m  recencia  previsão  \
# 0              3                   1      2685.00        74         1
# 1            207                   9     21275.23         2         0
# 2             42                  15       781.80         2         0
# 3              1                   1       120.00        16         1
# 4            141                  75     16228.88         8         0
#
#    previsão_proba
# 0            0.77
# 1            0.01
# 2            0.03
# 3            0.79
# 4            0.00
